# %%
import PredictorES as pe

# %%
pe.es_predict('localhost',9200,5)
# Out:
# 5 Elemente hochgeladen
# 10 Elemente hochgeladen
# 15 Elemente hochgeladen
# 20 Elemente hochgeladen

# %%
import PredictorJson as pj

# %%
pj.simplepredict('20200101-queues-sample.json','output.json')

# %%
import PredictorItemsES as pi

# %%
pi.es_predict('localhost',9200,20,25)
# Out:
# Fetching data complete:  2.3155651092529297
# Dataset created:  116.83138298988342
# Prediction complete:  168.09607195854187
# 20 Elemente hochgeladen
# 40 Elemente hochgeladen
# 60 Elemente hochgeladen
# 80 Elemente hochgeladen
# Upload complete:  169.8506178855896

# %%
import Predictor_Items_Cen_Pic as icp
# Out:
# Using TensorFlow backend.

# %%
icp.predict_items('localhost',9200, 10, "2020-06-08","2020-06-12")
# Out:
# 10 Elemente hochgeladen
# 20 Elemente hochgeladen
# 30 Elemente hochgeladen
# 40 Elemente hochgeladen
# 50 Elemente hochgeladen
# 60 Elemente hochgeladen
# 70 Elemente hochgeladen
# 80 Elemente hochgeladen
# 90 Elemente hochgeladen
# 100 Elemente hochgeladen
# 110 Elemente hochgeladen
# 120 Elemente hochgeladen
# 130 Elemente hochgeladen
# 140 Elemente hochgeladen
