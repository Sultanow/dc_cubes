# %%
import PredictorES as pe

# %%
pe.es_predict('localhost',9200,5)
# Out:
# 5 Elemente hochgeladen
# 10 Elemente hochgeladen
# 15 Elemente hochgeladen
# 20 Elemente hochgeladen

# %%
import PredictorJson as pj

# %%
pj.simplepredict('20200101-queues-sample.json','output.json')

# %%
import PredictorItemsES as pi
# Out:
# Using TensorFlow backend.

# %%
pi.es_predict('localhost',9200,20,25)
# Out:
# Fetching data complete:  0.04146099090576172
# Dataset created:  8.348894119262695
# /Library/Python/3.7/site-packages/sklearn/base.py:334: UserWarning: Trying to unpickle estimator StandardScaler from version 0.22.1 when using version 0.23.1. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# Prediction complete:  23.782764196395874
# 20 Elemente hochgeladen
# 40 Elemente hochgeladen
# 60 Elemente hochgeladen
# Upload complete:  25.006859064102173

# %%
416/60
# Out:
# 6.933333333333334

# %%
239/60
# Out:
# 3.9833333333333334
