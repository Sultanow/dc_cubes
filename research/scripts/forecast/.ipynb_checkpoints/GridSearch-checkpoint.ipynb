# %%
import pandas as pd
import numpy as np
import pickle
import time
import copy

from numpy import array
from datetime import timedelta  
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM, GRU
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from fbprophet import Prophet
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from pmdarima import auto_arima
from datetime import timedelta 

from keras.wrappers.scikit_learn import KerasRegressor
from sklearn.model_selection import GridSearchCV

import plotly
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode
# Out:
# Using TensorFlow backend.

# %%
timestamp = "timestamp"
predictionColumn = "cpuusage_ps"

# %%
# split a multivariate sequence into samples
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
def create_lstm(numberOfHiddenLayers=3, numberOfCells=50, activation="relu", n_history=1, pred_horizon=1, numberOfFeatures=1):
    model = Sequential()
    model.add(LSTM(numberOfCells, activation=activation, return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    for i in range(numberOfHiddenLayers-1):
        model.add(LSTM(numberOfCells, activation=activation, return_sequences=True))
        
    model.add(LSTM(numberOfCells, activation=activation, return_sequences=False))    
    model.add(Dense(pred_horizon, activation=activation))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    return model

def create_gru(numberOfHiddenLayers=3, numberOfCells=50, activation="relu", n_history=1, pred_horizon=1, numberOfFeatures=1):
    model = Sequential()
    model.add(GRU(numberOfCells, activation=activation, return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    for i in range(numberOfHiddenLayers-1):
        model.add(GRU(numberOfCells, activation=activation, return_sequences=True))
        
    model.add(GRU(numberOfCells, activation=activation, return_sequences=False))    
    model.add(Dense(pred_horizon, activation=activation))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    return model

def create_mlp(numberOfHiddenLayers=3, numberOfNeurons=50, activation="relu", n_history=1, pred_horizon=1, n_input=1):
    model = Sequential()
    model.add(Dense(numberOfNeurons, activation=activation, input_dim=n_input))
    
    for i in range(numberOfHiddenLayers):
        model.add(Dense(numberOfNeurons, activation=activation))
        
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    return model

def create_cnn(numberOfHiddenConvPoolLayers = 1, filters=[75], kernelSize = 3, poolSize = 2, activation = "relu",
               numberOfLstmLayers = 1, numberOfLstmCells=50, lstmActivation = "tanh", 
               n_history=1, pred_horizon=1, numberOfFeatures = 1):
    model = Sequential()
    model.add(Conv1D(filters=filters[0], kernel_size=kernelSize, activation=activation, input_shape=(n_history, numberOfFeatures)))
    model.add(MaxPooling1D(pool_size=poolSize))
    
    for i in range(numberOfHiddenConvPoolLayers - 1):
        model.add(Conv1D(filters=filters[i], kernel_size=kernelSize, activation=activation))
        model.add(MaxPooling1D(pool_size=poolSize))
    
    for j in range(numberOfLstmLayers-1):
        model.add(LSTM(numberOfLstmCells, activation=lstmActivation,return_sequences=True))
    if (numberOfLstmLayers > 0):
        model.add(LSTM(numberOfLstmCells, activation=lstmActivation))
        
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    return model

# %%
def lstm_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def lstm_split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

def train_lstm(df, n_history, pred_horizon, paramDict):
    # data split / preprocessing
    x, y, scalerX, scalerY = lstm_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("lstm_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)

    model = KerasRegressor(build_fn = create_lstm)
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('grid_lstm_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    grid = GridSearchCV(estimator=model, param_grid=paramDict, cv = 5, n_jobs=8)
    grid_result = grid.fit(x_train, y_train, validation_split=0.1, epochs= 100, callbacks=[es,mc])
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    fitTimes = grid_result.cv_results_['mean_fit_time']
    for mean, stdev, param, fitTime in zip(means, stds, params, fitTimes):
        print("%f (%f) with: %r, fitted in %f" % (mean, stdev, param, fitTime))

    print('''*** Model fitted ***''')
    return None

# %%
def gru_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def gru_split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

def train_gru(df, n_history, pred_horizon, paramDict):
    # data split / preprocessing
    x, y, scalerX, scalerY = gru_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = gru_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("gru_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)

    model = KerasRegressor(build_fn = create_gru)

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('grid_gru_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    grid = GridSearchCV(estimator=model, param_grid=paramDict, cv = 5, n_jobs=8)
    grid_result = grid.fit(x_train, y_train, validation_split=0.1, epochs= 100, callbacks=[es,mc])
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    fitTimes = grid_result.cv_results_['mean_fit_time']
    for mean, stdev, param, fitTime in zip(means, stds, params, fitTimes):
        print("%f (%f) with: %r, fitted in %f" % (mean, stdev, param, fitTime))

    print('''*** Model fitted ***''')
    return None

# %%
def mlp_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
         
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_mlp(df, n_history, pred_horizon, paramDict):
    x, y, scalerX, scalerY = mlp_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    n_input = x_train.shape[1] * x_train.shape[2]
    x_train = x_train.reshape((x_train.shape[0], n_input))
    n_neurons = int((n_input + pred_horizon)/2)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("mlp_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = KerasRegressor(build_fn = create_mlp)

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('grid_mlp_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    grid = GridSearchCV(estimator=model, param_grid=paramDict, cv = 5, n_jobs=8)
    grid_result = grid.fit(x_train, y_train, validation_split=0.1, epochs= 100, callbacks=[es,mc])
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    fitTimes = grid_result.cv_results_['mean_fit_time']
    for mean, stdev, param, fitTime in zip(means, stds, params, fitTimes):
        print("%f (%f) with: %r, fitted in %f" % (mean, stdev, param, fitTime))

    print('''*** Model fitted ***''')
    return None

# %%
def cnn_data_preprocessing(df, n_history, pred_horizon, paramDict):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def train_cnn(df, pred_horizon, n_history):
    x, y, scalerX, scalerY = cnn_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("lstm_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = KerasRegressor(build_fn = create_cnn)

    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('grid_cnn_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    grid = GridSearchCV(estimator=model, param_grid=paramDict, cv = 5, n_jobs=8)
    grid_result = grid.fit(x_train, y_train, validation_split=0.1, epochs= 100, callbacks=[es,mc])
    print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
    print("grid.cv_results_\n\n")
    print(grid.cv_results_)
    print("grid.best_estimator\n\n")
    print(grid.best_estimator_)
    print("grid.best_params\n\n")
    print(grid.best_params_)
    
    means = grid_result.cv_results_['mean_test_score']
    stds = grid_result.cv_results_['std_test_score']
    params = grid_result.cv_results_['params']
    fitTimes = grid_result.cv_results_['mean_fit_time']
    for mean, stdev, param, fitTime in zip(means, stds, params, fitTimes):
        print("%f (%f) with: %r, fitted in %f" % (mean, stdev, param, fitTime))

    print('''*** Model fitted ***''')   
    return None

# %%
# Declaration
skip_csv_rows = 0
measureInterval = 15 #min
daysToPredict = 5
pred_horizon = (60//measureInterval) * 24 * daysToPredict #5 days (4*24*5), timestep = 15min
hours_history = 8
n_history = (60//measureInterval)*hours_history 

# Read data from pickle file
with open("./4week_transformed_droppedErrors_filled.pkl", "rb") as pickleFile:
    df = pickle.load(pickleFile)

# %%
df = df.reset_index()

# %%
df[predictionColumn] = pd.to_numeric(df[predictionColumn])

# %%
paramCellCount = [50]
paramHiddenLayers = [4,6,10]
paramActivation = ["tanh"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfCells = paramCellCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
starttime = time.time()
train_lstm(df.copy().reset_index(), n_history=n_history, pred_horizon=pred_horizon, paramDict = paramDict)
print("training lstm took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3033 - mse: 1.3033 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86963, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00002: val_loss improved from 0.86963 to 0.86943, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3008 - mse: 1.3008 - val_loss: 0.8711 - val_mse: 0.8711
#
# Epoch 00003: val_loss did not improve from 0.86943
# Epoch 4/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2979 - mse: 1.2979 - val_loss: 0.8746 - val_mse: 0.8746
#
# Epoch 00004: val_loss did not improve from 0.86943
# Epoch 5/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2976 - mse: 1.2976 - val_loss: 0.8739 - val_mse: 0.8739
#
# Epoch 00005: val_loss did not improve from 0.86943
# Epoch 6/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2970 - mse: 1.2970 - val_loss: 0.8763 - val_mse: 0.8763
#
# Epoch 00006: val_loss did not improve from 0.86943
# Epoch 7/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2954 - mse: 1.2954 - val_loss: 0.8757 - val_mse: 0.8757
#
# Epoch 00007: val_loss did not improve from 0.86943
# Epoch 8/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2931 - mse: 1.2931 - val_loss: 0.8770 - val_mse: 0.8770
#
# Epoch 00008: val_loss did not improve from 0.86943
# Epoch 9/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2736 - mse: 1.2736 - val_loss: 0.8891 - val_mse: 0.8891
#
# Epoch 00009: val_loss did not improve from 0.86943
# Epoch 10/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2513 - mse: 1.2513 - val_loss: 0.8516 - val_mse: 0.8516
#
# Epoch 00010: val_loss improved from 0.86943 to 0.85163, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 11/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2173 - mse: 1.2173 - val_loss: 0.7776 - val_mse: 0.7776
#
# Epoch 00011: val_loss improved from 0.85163 to 0.77761, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 12/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1855 - mse: 1.1855 - val_loss: 0.7898 - val_mse: 0.7898
#
# Epoch 00012: val_loss did not improve from 0.77761
# Epoch 13/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1683 - mse: 1.1683 - val_loss: 0.7532 - val_mse: 0.7532
#
# Epoch 00013: val_loss improved from 0.77761 to 0.75320, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 14/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1458 - mse: 1.1458 - val_loss: 0.7428 - val_mse: 0.7428
#
# Epoch 00014: val_loss improved from 0.75320 to 0.74285, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 15/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1365 - mse: 1.1365 - val_loss: 0.7397 - val_mse: 0.7397
#
# Epoch 00015: val_loss improved from 0.74285 to 0.73970, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 16/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1224 - mse: 1.1224 - val_loss: 0.7372 - val_mse: 0.7372
#
# Epoch 00016: val_loss improved from 0.73970 to 0.73717, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 17/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1115 - mse: 1.1115 - val_loss: 0.7333 - val_mse: 0.7333
#
# Epoch 00017: val_loss improved from 0.73717 to 0.73326, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 18/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1024 - mse: 1.1024 - val_loss: 0.7321 - val_mse: 0.7321
#
# Epoch 00018: val_loss improved from 0.73326 to 0.73210, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 19/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0963 - mse: 1.0963 - val_loss: 0.7225 - val_mse: 0.7225
#
# Epoch 00019: val_loss improved from 0.73210 to 0.72252, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 20/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0890 - mse: 1.0890 - val_loss: 0.7192 - val_mse: 0.7192
#
# Epoch 00020: val_loss improved from 0.72252 to 0.71920, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 21/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0803 - mse: 1.0803 - val_loss: 0.7224 - val_mse: 0.7224
#
# Epoch 00021: val_loss did not improve from 0.71920
# Epoch 22/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0740 - mse: 1.0740 - val_loss: 0.7271 - val_mse: 0.7271
#
# Epoch 00022: val_loss did not improve from 0.71920
# Epoch 23/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0786 - mse: 1.0786 - val_loss: 0.7105 - val_mse: 0.7105
#
# Epoch 00023: val_loss improved from 0.71920 to 0.71046, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 24/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0660 - mse: 1.0660 - val_loss: 0.7073 - val_mse: 0.7073
#
# Epoch 00024: val_loss improved from 0.71046 to 0.70731, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 25/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0583 - mse: 1.0583 - val_loss: 0.7051 - val_mse: 0.7051
#
# Epoch 00025: val_loss improved from 0.70731 to 0.70507, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 26/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0539 - mse: 1.0539 - val_loss: 0.7056 - val_mse: 0.7056
#
# Epoch 00026: val_loss did not improve from 0.70507
# Epoch 27/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0493 - mse: 1.0493 - val_loss: 0.7047 - val_mse: 0.7047
#
# Epoch 00027: val_loss improved from 0.70507 to 0.70469, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 28/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.7026 - val_mse: 0.7026
#
# Epoch 00028: val_loss improved from 0.70469 to 0.70264, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 29/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0386 - mse: 1.0386 - val_loss: 0.6975 - val_mse: 0.6975
#
# Epoch 00029: val_loss improved from 0.70264 to 0.69753, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 30/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0344 - mse: 1.0344 - val_loss: 0.6932 - val_mse: 0.6932
#
# Epoch 00030: val_loss improved from 0.69753 to 0.69318, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 31/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0312 - mse: 1.0312 - val_loss: 0.6890 - val_mse: 0.6890
#
# Epoch 00031: val_loss improved from 0.69318 to 0.68904, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 32/100
# 1619/1619 [==============================] - 6s 3ms/step - loss: 1.0382 - mse: 1.0382 - val_loss: 0.7890 - val_mse: 0.7890
#
# Epoch 00032: val_loss did not improve from 0.68904
# Epoch 33/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0426 - mse: 1.0426 - val_loss: 0.6907 - val_mse: 0.6907
#
# Epoch 00033: val_loss did not improve from 0.68904
# Epoch 34/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0264 - mse: 1.0264 - val_loss: 0.6887 - val_mse: 0.6887
#
# Epoch 00034: val_loss improved from 0.68904 to 0.68869, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 35/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0224 - mse: 1.0224 - val_loss: 0.6877 - val_mse: 0.6877
#
# Epoch 00035: val_loss improved from 0.68869 to 0.68775, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 36/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0195 - mse: 1.0195 - val_loss: 0.6851 - val_mse: 0.6851
#
# Epoch 00036: val_loss improved from 0.68775 to 0.68508, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 37/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0340 - mse: 1.0340 - val_loss: 0.6861 - val_mse: 0.6861
#
# Epoch 00037: val_loss did not improve from 0.68508
# Epoch 38/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0344 - mse: 1.0344 - val_loss: 0.6836 - val_mse: 0.6836
#
# Epoch 00038: val_loss improved from 0.68508 to 0.68357, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 39/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0194 - mse: 1.0194 - val_loss: 0.6856 - val_mse: 0.6856
#
# Epoch 00039: val_loss did not improve from 0.68357
# Epoch 40/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0176 - mse: 1.0176 - val_loss: 0.6835 - val_mse: 0.6835
#
# Epoch 00040: val_loss improved from 0.68357 to 0.68354, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 41/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0138 - mse: 1.0138 - val_loss: 0.6826 - val_mse: 0.6826
#
# Epoch 00041: val_loss improved from 0.68354 to 0.68263, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 42/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0119 - mse: 1.0119 - val_loss: 0.6810 - val_mse: 0.6810
#
# Epoch 00042: val_loss improved from 0.68263 to 0.68105, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 43/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0113 - mse: 1.0113 - val_loss: 0.6809 - val_mse: 0.6809
#
# Epoch 00043: val_loss improved from 0.68105 to 0.68089, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 44/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0104 - mse: 1.0104 - val_loss: 0.6805 - val_mse: 0.6805
#
# Epoch 00044: val_loss improved from 0.68089 to 0.68050, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 45/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0107 - mse: 1.0107 - val_loss: 0.6826 - val_mse: 0.6826
#
# Epoch 00045: val_loss did not improve from 0.68050
# Epoch 46/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0087 - mse: 1.0087 - val_loss: 0.6818 - val_mse: 0.6818
#
# Epoch 00046: val_loss did not improve from 0.68050
# Epoch 47/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0079 - mse: 1.0079 - val_loss: 0.6861 - val_mse: 0.6861
#
# Epoch 00047: val_loss did not improve from 0.68050
# Epoch 48/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0145 - mse: 1.0145 - val_loss: 0.6821 - val_mse: 0.6821
#
# Epoch 00048: val_loss did not improve from 0.68050
# Epoch 49/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0146 - mse: 1.0146 - val_loss: 0.6839 - val_mse: 0.6839
#
# Epoch 00049: val_loss did not improve from 0.68050
# Epoch 50/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0065 - mse: 1.0065 - val_loss: 0.6795 - val_mse: 0.6795
#
# Epoch 00050: val_loss improved from 0.68050 to 0.67948, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 51/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0048 - mse: 1.0048 - val_loss: 0.6803 - val_mse: 0.6803
#
# Epoch 00051: val_loss did not improve from 0.67948
# Epoch 52/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0039 - mse: 1.0039 - val_loss: 0.6795 - val_mse: 0.6795
#
# Epoch 00052: val_loss improved from 0.67948 to 0.67946, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 53/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0031 - mse: 1.0031 - val_loss: 0.6777 - val_mse: 0.6777
#
# Epoch 00053: val_loss improved from 0.67946 to 0.67770, saving model to grid_lstm_multistep_multivariate.h5
# Epoch 54/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0031 - mse: 1.0031 - val_loss: 0.6803 - val_mse: 0.6803
#
# Epoch 00054: val_loss did not improve from 0.67770
# Epoch 55/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0034 - mse: 1.0034 - val_loss: 0.6780 - val_mse: 0.6780
#
# Epoch 00055: val_loss did not improve from 0.67770
# Epoch 56/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0123 - mse: 1.0123 - val_loss: 0.6872 - val_mse: 0.6872
#
# Epoch 00056: val_loss did not improve from 0.67770
# Epoch 57/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0429 - mse: 1.0429 - val_loss: 0.9069 - val_mse: 0.9069
#
# Epoch 00057: val_loss did not improve from 0.67770
# Epoch 58/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0873 - mse: 1.0873 - val_loss: 0.7193 - val_mse: 0.7193
#
# Epoch 00058: val_loss did not improve from 0.67770
# Epoch 59/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0230 - mse: 1.0230 - val_loss: 0.6856 - val_mse: 0.6856
#
# Epoch 00059: val_loss did not improve from 0.67770
# Epoch 60/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0089 - mse: 1.0089 - val_loss: 0.6855 - val_mse: 0.6855
#
# Epoch 00060: val_loss did not improve from 0.67770
# Epoch 61/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0049 - mse: 1.0049 - val_loss: 0.6850 - val_mse: 0.6850
#
# Epoch 00061: val_loss did not improve from 0.67770
# Epoch 62/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0036 - mse: 1.0036 - val_loss: 0.6832 - val_mse: 0.6832
#
# Epoch 00062: val_loss did not improve from 0.67770
# Epoch 63/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0024 - mse: 1.0024 - val_loss: 0.6822 - val_mse: 0.6822
#
# Epoch 00063: val_loss did not improve from 0.67770
# Epoch 64/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0041 - mse: 1.0041 - val_loss: 0.6833 - val_mse: 0.6833
#
# Epoch 00064: val_loss did not improve from 0.67770
# Epoch 65/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0018 - mse: 1.0018 - val_loss: 0.6832 - val_mse: 0.6832
#
# Epoch 00065: val_loss did not improve from 0.67770
# Epoch 66/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0007 - mse: 1.0007 - val_loss: 0.6838 - val_mse: 0.6838
#
# Epoch 00066: val_loss did not improve from 0.67770
# Epoch 67/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0001 - mse: 1.0001 - val_loss: 0.6832 - val_mse: 0.6832
#
# Epoch 00067: val_loss did not improve from 0.67770
# Epoch 68/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9997 - mse: 0.9997 - val_loss: 0.6833 - val_mse: 0.6833
#
# Epoch 00068: val_loss did not improve from 0.67770
# Epoch 00068: early stopping
# Best: -1.230536 using {'activation': 'tanh', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}
# -1.230536 (1.143590) with: {'activation': 'tanh', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}, fitted in 285.477633
# -1.248476 (1.111581) with: {'activation': 'tanh', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 6, 'pred_horizon': 480}, fitted in 504.950363
# -1.232973 (1.050519) with: {'activation': 'tanh', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 10, 'pred_horizon': 480}, fitted in 1094.173155
# *** Model fitted ***
# training lstm took  2140.3045942783356

# %%
paramCellCount = [50]
paramHiddenLayers = [4,5,7]
paramActivation = ["relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfCells = paramCellCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for activation function relu vs tanh. Best: relu
starttime = time.time()
train_gru(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training GRU took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3211 - mse: 1.3211 - val_loss: 0.8722 - val_mse: 0.8722
#
# Epoch 00001: val_loss improved from inf to 0.87217, saving model to grid_gru_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3018 - mse: 1.3018 - val_loss: 0.8714 - val_mse: 0.8714
#
# Epoch 00002: val_loss improved from 0.87217 to 0.87144, saving model to grid_gru_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3016 - mse: 1.3016 - val_loss: 0.8714 - val_mse: 0.8714
#
# Epoch 00003: val_loss did not improve from 0.87144
# Epoch 4/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3014 - mse: 1.3014 - val_loss: 0.8759 - val_mse: 0.8759
#
# Epoch 00004: val_loss did not improve from 0.87144
# Epoch 5/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3014 - mse: 1.3014 - val_loss: 0.8724 - val_mse: 0.8724
#
# Epoch 00005: val_loss did not improve from 0.87144
# Epoch 6/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3012 - mse: 1.3012 - val_loss: 0.8762 - val_mse: 0.8762
#
# Epoch 00006: val_loss did not improve from 0.87144
# Epoch 7/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3012 - mse: 1.3012 - val_loss: 0.8759 - val_mse: 0.8759
#
# Epoch 00007: val_loss did not improve from 0.87144
# Epoch 8/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3010 - mse: 1.3010 - val_loss: 0.8750 - val_mse: 0.8750
#
# Epoch 00008: val_loss did not improve from 0.87144
# Epoch 9/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3009 - mse: 1.3009 - val_loss: 0.8807 - val_mse: 0.8807
#
# Epoch 00009: val_loss did not improve from 0.87144
# Epoch 10/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3008 - mse: 1.3008 - val_loss: 0.8860 - val_mse: 0.8860
#
# Epoch 00010: val_loss did not improve from 0.87144
# Epoch 11/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3008 - mse: 1.3008 - val_loss: 0.8814 - val_mse: 0.8814
#
# Epoch 00011: val_loss did not improve from 0.87144
# Epoch 12/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3006 - mse: 1.3006 - val_loss: 0.8803 - val_mse: 0.8803
#
# Epoch 00012: val_loss did not improve from 0.87144
# Epoch 13/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3003 - mse: 1.3003 - val_loss: 0.8859 - val_mse: 0.8859
#
# Epoch 00013: val_loss did not improve from 0.87144
# Epoch 14/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3002 - mse: 1.3002 - val_loss: 0.8834 - val_mse: 0.8834
#
# Epoch 00014: val_loss did not improve from 0.87144
# Epoch 15/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3002 - mse: 1.3002 - val_loss: 0.8926 - val_mse: 0.8926
#
# Epoch 00015: val_loss did not improve from 0.87144
# Epoch 16/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2998 - mse: 1.2998 - val_loss: 0.8942 - val_mse: 0.8942
#
# Epoch 00016: val_loss did not improve from 0.87144
# Epoch 17/100
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2999 - mse: 1.2999 - val_loss: 0.8918 - val_mse: 0.8918
#
# Epoch 00017: val_loss did not improve from 0.87144
# Epoch 00017: early stopping
# Best: -1.253749 using {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'tanh', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}, fitted in 412.789439
# -1.253749 (1.089363) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}, fitted in 518.959704
# *** Model fitted ***
# training GRU took  928.7071752548218

# %%
paramCellCount = [50]
paramHiddenLayers = [4,5,7]
paramActivation = ["relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfCells = paramCellCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for cell count. Best: 50
starttime = time.time()
train_gru(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training GRU took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.7027 - mse: 1.7027 - val_loss: 0.8741 - val_mse: 0.8741
#
# Epoch 00001: val_loss improved from inf to 0.87413, saving model to grid_gru_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3025 - mse: 1.3025 - val_loss: 0.8724 - val_mse: 0.8724
#
# Epoch 00002: val_loss improved from 0.87413 to 0.87236, saving model to grid_gru_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3018 - mse: 1.3018 - val_loss: 0.8715 - val_mse: 0.8715
#
# Epoch 00003: val_loss improved from 0.87236 to 0.87146, saving model to grid_gru_multistep_multivariate.h5
# Epoch 4/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3015 - mse: 1.3015 - val_loss: 0.8726 - val_mse: 0.8726
#
# Epoch 00004: val_loss did not improve from 0.87146
# Epoch 5/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3012 - mse: 1.3012 - val_loss: 0.8708 - val_mse: 0.8708
#
# Epoch 00005: val_loss improved from 0.87146 to 0.87078, saving model to grid_gru_multistep_multivariate.h5
# Epoch 6/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3003 - mse: 1.3003 - val_loss: 0.8688 - val_mse: 0.8688
#
# Epoch 00006: val_loss improved from 0.87078 to 0.86879, saving model to grid_gru_multistep_multivariate.h5
# Epoch 7/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2977 - mse: 1.2977 - val_loss: 0.8672 - val_mse: 0.8672
#
# Epoch 00007: val_loss improved from 0.86879 to 0.86720, saving model to grid_gru_multistep_multivariate.h5
# Epoch 8/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2911 - mse: 1.2911 - val_loss: 0.8559 - val_mse: 0.8559
#
# Epoch 00008: val_loss improved from 0.86720 to 0.85594, saving model to grid_gru_multistep_multivariate.h5
# Epoch 9/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2815 - mse: 1.2815 - val_loss: 0.8256 - val_mse: 0.8256
#
# Epoch 00009: val_loss improved from 0.85594 to 0.82564, saving model to grid_gru_multistep_multivariate.h5
# Epoch 10/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2626 - mse: 1.2626 - val_loss: 0.8113 - val_mse: 0.8113
#
# Epoch 00010: val_loss improved from 0.82564 to 0.81135, saving model to grid_gru_multistep_multivariate.h5
# Epoch 11/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2587 - mse: 1.2587 - val_loss: 0.8297 - val_mse: 0.8297
#
# Epoch 00011: val_loss did not improve from 0.81135
# Epoch 12/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2530 - mse: 1.2530 - val_loss: 0.8076 - val_mse: 0.8076
#
# Epoch 00012: val_loss improved from 0.81135 to 0.80764, saving model to grid_gru_multistep_multivariate.h5
# Epoch 13/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2467 - mse: 1.2467 - val_loss: 0.7961 - val_mse: 0.7961
#
# Epoch 00013: val_loss improved from 0.80764 to 0.79614, saving model to grid_gru_multistep_multivariate.h5
# Epoch 14/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2441 - mse: 1.2441 - val_loss: 0.7941 - val_mse: 0.7941
#
# Epoch 00014: val_loss improved from 0.79614 to 0.79408, saving model to grid_gru_multistep_multivariate.h5
# Epoch 15/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2429 - mse: 1.2429 - val_loss: 0.7920 - val_mse: 0.7920
#
# Epoch 00015: val_loss improved from 0.79408 to 0.79199, saving model to grid_gru_multistep_multivariate.h5
# Epoch 16/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2424 - mse: 1.2424 - val_loss: 0.7924 - val_mse: 0.7924
#
# Epoch 00016: val_loss did not improve from 0.79199
# Epoch 17/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2422 - mse: 1.2422 - val_loss: 0.7920 - val_mse: 0.7920
#
# Epoch 00017: val_loss did not improve from 0.79199
# Epoch 18/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2422 - mse: 1.2422 - val_loss: 0.7919 - val_mse: 0.7919
#
# Epoch 00018: val_loss improved from 0.79199 to 0.79190, saving model to grid_gru_multistep_multivariate.h5
# Epoch 19/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7922 - val_mse: 0.7922
#
# Epoch 00019: val_loss did not improve from 0.79190
# Epoch 20/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7923 - val_mse: 0.7923
#
# Epoch 00020: val_loss did not improve from 0.79190
# Epoch 21/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7920 - val_mse: 0.7920
#
# Epoch 00021: val_loss did not improve from 0.79190
# Epoch 22/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2420 - mse: 1.2420 - val_loss: 0.7921 - val_mse: 0.7921
#
# Epoch 00022: val_loss did not improve from 0.79190
# Epoch 23/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7922 - val_mse: 0.7922
#
# Epoch 00023: val_loss did not improve from 0.79190
# Epoch 24/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7924 - val_mse: 0.7924
#
# Epoch 00024: val_loss did not improve from 0.79190
# Epoch 25/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7925 - val_mse: 0.7925
#
# Epoch 00025: val_loss did not improve from 0.79190
# Epoch 26/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2420 - mse: 1.2420 - val_loss: 0.7925 - val_mse: 0.7925
#
# Epoch 00026: val_loss did not improve from 0.79190
# Epoch 27/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2420 - mse: 1.2420 - val_loss: 0.7924 - val_mse: 0.7924
#
# Epoch 00027: val_loss did not improve from 0.79190
# Epoch 28/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2420 - mse: 1.2420 - val_loss: 0.7931 - val_mse: 0.7931
#
# Epoch 00028: val_loss did not improve from 0.79190
# Epoch 29/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7946 - val_mse: 0.7946
#
# Epoch 00029: val_loss did not improve from 0.79190
# Epoch 30/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2421 - mse: 1.2421 - val_loss: 0.7933 - val_mse: 0.7933
#
# Epoch 00030: val_loss did not improve from 0.79190
# Epoch 31/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2422 - mse: 1.2422 - val_loss: 0.7918 - val_mse: 0.7918
#
# Epoch 00031: val_loss improved from 0.79190 to 0.79180, saving model to grid_gru_multistep_multivariate.h5
# Epoch 32/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2418 - mse: 1.2418 - val_loss: 0.7928 - val_mse: 0.7928
#
# Epoch 00032: val_loss did not improve from 0.79180
# Epoch 33/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2417 - mse: 1.2417 - val_loss: 0.7922 - val_mse: 0.7922
#
# Epoch 00033: val_loss did not improve from 0.79180
# Epoch 34/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2416 - mse: 1.2416 - val_loss: 0.7922 - val_mse: 0.7922
#
# Epoch 00034: val_loss did not improve from 0.79180
# Epoch 35/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2415 - mse: 1.2415 - val_loss: 0.7924 - val_mse: 0.7924
#
# Epoch 00035: val_loss did not improve from 0.79180
# Epoch 36/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2486 - mse: 1.2486 - val_loss: 0.8099 - val_mse: 0.8099
#
# Epoch 00036: val_loss did not improve from 0.79180
# Epoch 37/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2433 - mse: 1.2433 - val_loss: 0.7908 - val_mse: 0.7908
#
# Epoch 00037: val_loss improved from 0.79180 to 0.79081, saving model to grid_gru_multistep_multivariate.h5
# Epoch 38/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2401 - mse: 1.2401 - val_loss: 0.7894 - val_mse: 0.7894
#
# Epoch 00038: val_loss improved from 0.79081 to 0.78941, saving model to grid_gru_multistep_multivariate.h5
# Epoch 39/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2394 - mse: 1.2394 - val_loss: 0.7896 - val_mse: 0.7896
#
# Epoch 00039: val_loss did not improve from 0.78941
# Epoch 40/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2389 - mse: 1.2389 - val_loss: 0.7901 - val_mse: 0.7901
#
# Epoch 00040: val_loss did not improve from 0.78941
# Epoch 41/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2387 - mse: 1.2387 - val_loss: 0.7891 - val_mse: 0.7891
#
# Epoch 00041: val_loss improved from 0.78941 to 0.78908, saving model to grid_gru_multistep_multivariate.h5
# Epoch 42/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2379 - mse: 1.2379 - val_loss: 0.7879 - val_mse: 0.7879
#
# Epoch 00042: val_loss improved from 0.78908 to 0.78791, saving model to grid_gru_multistep_multivariate.h5
# Epoch 43/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2378 - mse: 1.2378 - val_loss: 0.7884 - val_mse: 0.7884
#
# Epoch 00043: val_loss did not improve from 0.78791
# Epoch 44/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2377 - mse: 1.2377 - val_loss: 0.7888 - val_mse: 0.7888
#
# Epoch 00044: val_loss did not improve from 0.78791
# Epoch 45/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2378 - mse: 1.2378 - val_loss: 0.7896 - val_mse: 0.7896
#
# Epoch 00045: val_loss did not improve from 0.78791
# Epoch 46/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2378 - mse: 1.2378 - val_loss: 0.7887 - val_mse: 0.7887
#
# Epoch 00046: val_loss did not improve from 0.78791
# Epoch 47/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2376 - mse: 1.2376 - val_loss: 0.7898 - val_mse: 0.7898
#
# Epoch 00047: val_loss did not improve from 0.78791
# Epoch 48/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2376 - mse: 1.2376 - val_loss: 0.7894 - val_mse: 0.7894
#
# Epoch 00048: val_loss did not improve from 0.78791
# Epoch 49/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2378 - mse: 1.2378 - val_loss: 0.8011 - val_mse: 0.8011
#
# Epoch 00049: val_loss did not improve from 0.78791
# Epoch 50/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2388 - mse: 1.2388 - val_loss: 0.7909 - val_mse: 0.7909
#
# Epoch 00050: val_loss did not improve from 0.78791
# Epoch 51/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2372 - mse: 1.2372 - val_loss: 0.7894 - val_mse: 0.7894
#
# Epoch 00051: val_loss did not improve from 0.78791
# Epoch 52/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2363 - mse: 1.2363 - val_loss: 0.7860 - val_mse: 0.7860
#
# Epoch 00052: val_loss improved from 0.78791 to 0.78602, saving model to grid_gru_multistep_multivariate.h5
# Epoch 53/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2359 - mse: 1.2359 - val_loss: 0.7884 - val_mse: 0.7884
#
# Epoch 00053: val_loss did not improve from 0.78602
# Epoch 54/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2358 - mse: 1.2358 - val_loss: 0.7875 - val_mse: 0.7875
#
# Epoch 00054: val_loss did not improve from 0.78602
# Epoch 55/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2357 - mse: 1.2357 - val_loss: 0.7867 - val_mse: 0.7867
#
# Epoch 00055: val_loss did not improve from 0.78602
# Epoch 56/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2356 - mse: 1.2356 - val_loss: 0.7866 - val_mse: 0.7866
#
# Epoch 00056: val_loss did not improve from 0.78602
# Epoch 57/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2355 - mse: 1.2355 - val_loss: 0.7886 - val_mse: 0.7886
#
# Epoch 00057: val_loss did not improve from 0.78602
# Epoch 58/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2356 - mse: 1.2356 - val_loss: 0.7878 - val_mse: 0.7878
#
# Epoch 00058: val_loss did not improve from 0.78602
# Epoch 59/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2354 - mse: 1.2354 - val_loss: 0.7876 - val_mse: 0.7876
#
# Epoch 00059: val_loss did not improve from 0.78602
# Epoch 60/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2353 - mse: 1.2353 - val_loss: 0.7943 - val_mse: 0.7943
#
# Epoch 00060: val_loss did not improve from 0.78602
# Epoch 61/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2353 - mse: 1.2353 - val_loss: 0.7888 - val_mse: 0.7888
#
# Epoch 00061: val_loss did not improve from 0.78602
# Epoch 62/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2352 - mse: 1.2352 - val_loss: 0.7868 - val_mse: 0.7868
#
# Epoch 00062: val_loss did not improve from 0.78602
# Epoch 63/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2348 - mse: 1.2348 - val_loss: 0.7900 - val_mse: 0.7900
#
# Epoch 00063: val_loss did not improve from 0.78602
# Epoch 64/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2347 - mse: 1.2347 - val_loss: 0.7883 - val_mse: 0.7883
#
# Epoch 00064: val_loss did not improve from 0.78602
# Epoch 65/100
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2345 - mse: 1.2345 - val_loss: 0.7923 - val_mse: 0.7923
#
# Epoch 00065: val_loss did not improve from 0.78602
# Epoch 66/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2348 - mse: 1.2348 - val_loss: 0.7892 - val_mse: 0.7892
#
# Epoch 00066: val_loss did not improve from 0.78602
# Epoch 67/100
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.2345 - mse: 1.2345 - val_loss: 0.7888 - val_mse: 0.7888
#
# Epoch 00067: val_loss did not improve from 0.78602
# Epoch 00067: early stopping
# Best: -1.192224 using {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 1, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}, fitted in 95.151721
# nan (nan) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 10, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}, fitted in 252.770440
# nan (nan) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 30, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}, fitted in 389.258257
# -1.192224 (1.114220) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}, fitted in 889.242476
# -1.201217 (1.105482) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 80, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 2, 'pred_horizon': 480}, fitted in 889.128241
# *** Model fitted ***
# training GRU took  2291.817639350891

# %%
paramCellCount = [50]
paramHiddenLayers = [4,5,7]
paramActivation = ["relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfCells = paramCellCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for hidden layer count. Best: 5
starttime = time.time()
train_gru(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training GRU took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3026 - mse: 1.3026 - val_loss: 0.8710 - val_mse: 0.8710
#
# Epoch 00001: val_loss improved from inf to 0.87099, saving model to grid_gru_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3019 - mse: 1.3019 - val_loss: 0.8715 - val_mse: 0.8715
#
# Epoch 00002: val_loss did not improve from 0.87099
# Epoch 3/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3016 - mse: 1.3016 - val_loss: 0.8710 - val_mse: 0.8710
#
# Epoch 00003: val_loss did not improve from 0.87099
# Epoch 4/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3015 - mse: 1.3015 - val_loss: 0.8713 - val_mse: 0.8713
#
# Epoch 00004: val_loss did not improve from 0.87099
# Epoch 5/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3011 - mse: 1.3011 - val_loss: 0.8715 - val_mse: 0.8715
#
# Epoch 00005: val_loss did not improve from 0.87099
# Epoch 6/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3010 - mse: 1.3010 - val_loss: 0.8701 - val_mse: 0.8701
#
# Epoch 00006: val_loss improved from 0.87099 to 0.87012, saving model to grid_gru_multistep_multivariate.h5
# Epoch 7/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3011 - mse: 1.3011 - val_loss: 0.8750 - val_mse: 0.8750
#
# Epoch 00007: val_loss did not improve from 0.87012
# Epoch 8/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2999 - mse: 1.2999 - val_loss: 0.8732 - val_mse: 0.8732
#
# Epoch 00008: val_loss did not improve from 0.87012
# Epoch 9/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2993 - mse: 1.2993 - val_loss: 0.8740 - val_mse: 0.8740
#
# Epoch 00009: val_loss did not improve from 0.87012
# Epoch 10/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3003 - mse: 1.3003 - val_loss: 0.8679 - val_mse: 0.8679
#
# Epoch 00010: val_loss improved from 0.87012 to 0.86787, saving model to grid_gru_multistep_multivariate.h5
# Epoch 11/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3026 - mse: 1.3026 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00011: val_loss did not improve from 0.86787
# Epoch 12/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3026 - mse: 1.3026 - val_loss: 0.8718 - val_mse: 0.8718
#
# Epoch 00012: val_loss did not improve from 0.86787
# Epoch 13/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3021 - mse: 1.3021 - val_loss: 0.8719 - val_mse: 0.8719
#
# Epoch 00013: val_loss did not improve from 0.86787
# Epoch 14/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3009 - mse: 1.3009 - val_loss: 0.8727 - val_mse: 0.8727
#
# Epoch 00014: val_loss did not improve from 0.86787
# Epoch 15/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3001 - mse: 1.3001 - val_loss: 0.8767 - val_mse: 0.8767
#
# Epoch 00015: val_loss did not improve from 0.86787
# Epoch 16/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2995 - mse: 1.2995 - val_loss: 0.8739 - val_mse: 0.8739
#
# Epoch 00016: val_loss did not improve from 0.86787
# Epoch 17/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2980 - mse: 1.2980 - val_loss: 0.8762 - val_mse: 0.8762
#
# Epoch 00017: val_loss did not improve from 0.86787
# Epoch 18/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2972 - mse: 1.2972 - val_loss: 0.8777 - val_mse: 0.8777
#
# Epoch 00018: val_loss did not improve from 0.86787
# Epoch 19/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2968 - mse: 1.2968 - val_loss: 0.8824 - val_mse: 0.8824
#
# Epoch 00019: val_loss did not improve from 0.86787
# Epoch 20/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2978 - mse: 1.2978 - val_loss: 0.8738 - val_mse: 0.8738
#
# Epoch 00020: val_loss did not improve from 0.86787
# Epoch 21/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2969 - mse: 1.2969 - val_loss: 0.8911 - val_mse: 0.8911
#
# Epoch 00021: val_loss did not improve from 0.86787
# Epoch 22/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2969 - mse: 1.2969 - val_loss: 0.8957 - val_mse: 0.8957
#
# Epoch 00022: val_loss did not improve from 0.86787
# Epoch 23/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2962 - mse: 1.2962 - val_loss: 0.8858 - val_mse: 0.8858
#
# Epoch 00023: val_loss did not improve from 0.86787
# Epoch 24/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3033 - mse: 1.3033 - val_loss: 0.8709 - val_mse: 0.8709
#
# Epoch 00024: val_loss did not improve from 0.86787
# Epoch 25/100
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3021 - mse: 1.3021 - val_loss: 0.8740 - val_mse: 0.8740
#
# Epoch 00025: val_loss did not improve from 0.86787
# Epoch 00025: early stopping
# Best: -1.284117 using {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 5, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 4, 'pred_horizon': 480}, fitted in 311.672380
# -1.284117 (1.100035) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 5, 'pred_horizon': 480}, fitted in 524.476942
# -1.302860 (1.167065) with: {'activation': 'relu', 'n_history': 32, 'numberOfCells': 50, 'numberOfFeatures': 61, 'numberOfHiddenLayers': 7, 'pred_horizon': 480}, fitted in 703.827212
# *** Model fitted ***
# training GRU took  1511.3409337997437

# %%
paramNeuronCount = [n_neurons*2]
paramHiddenLayers = [3]
paramActivation = ["sigmoid", "tanh", "relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramInputDim = [n_input]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfNeurons = paramNeuronCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, n_input = paramInputDim)
# Grid Search for: activation func relu vs tanh vs sigmoid. Best: relu
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 22s 14ms/step - loss: 431.5223 - mse: 431.5222 - val_loss: 0.8700 - val_mse: 0.8700
#
# Epoch 00001: val_loss improved from inf to 0.86997, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 21s 13ms/step - loss: 1.3037 - mse: 1.3037 - val_loss: 0.8692 - val_mse: 0.8692
#
# Epoch 00002: val_loss improved from 0.86997 to 0.86924, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3036 - mse: 1.3036 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00003: val_loss did not improve from 0.86924
# Epoch 4/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3050 - mse: 1.3050 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00004: val_loss did not improve from 0.86924
# Epoch 5/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3032 - mse: 1.3032 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00005: val_loss did not improve from 0.86924
# Epoch 6/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3083 - mse: 1.3083 - val_loss: 0.8753 - val_mse: 0.8753
#
# Epoch 00006: val_loss did not improve from 0.86924
# Epoch 7/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3063 - mse: 1.3063 - val_loss: 0.8808 - val_mse: 0.8808
#
# Epoch 00007: val_loss did not improve from 0.86924
# Epoch 8/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3058 - mse: 1.3058 - val_loss: 0.8707 - val_mse: 0.8707
#
# Epoch 00008: val_loss did not improve from 0.86924
# Epoch 9/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3110 - mse: 1.3110 - val_loss: 0.9666 - val_mse: 0.9666
#
# Epoch 00009: val_loss did not improve from 0.86924
# Epoch 10/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3072 - mse: 1.3072 - val_loss: 0.8902 - val_mse: 0.8902
#
# Epoch 00010: val_loss did not improve from 0.86924
# Epoch 11/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3062 - mse: 1.3062 - val_loss: 0.8692 - val_mse: 0.8692
#
# Epoch 00011: val_loss improved from 0.86924 to 0.86923, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 12/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3043 - mse: 1.3043 - val_loss: 0.8754 - val_mse: 0.8754
#
# Epoch 00012: val_loss did not improve from 0.86923
# Epoch 13/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3039 - mse: 1.3039 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00013: val_loss did not improve from 0.86923
# Epoch 14/100
# 1619/1619 [==============================] - 22s 14ms/step - loss: 1.3113 - mse: 1.3113 - val_loss: 1.0682 - val_mse: 1.0682
#
# Epoch 00014: val_loss did not improve from 0.86923
# Epoch 15/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3072 - mse: 1.3072 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00015: val_loss did not improve from 0.86923
# Epoch 16/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3024 - mse: 1.3024 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00016: val_loss did not improve from 0.86923
# Epoch 17/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3025 - mse: 1.3025 - val_loss: 1.0054 - val_mse: 1.0054
#
# Epoch 00017: val_loss did not improve from 0.86923
# Epoch 18/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3132 - mse: 1.3132 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00018: val_loss did not improve from 0.86923
# Epoch 19/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3063 - mse: 1.3063 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00019: val_loss did not improve from 0.86923
# Epoch 20/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3041 - mse: 1.3041 - val_loss: 0.8912 - val_mse: 0.8912
#
# Epoch 00020: val_loss did not improve from 0.86923
# Epoch 21/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3116 - mse: 1.3116 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00021: val_loss did not improve from 0.86923
# Epoch 22/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3032 - mse: 1.3032 - val_loss: 0.8693 - val_mse: 0.8693
#
# Epoch 00022: val_loss did not improve from 0.86923
# Epoch 23/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3113 - mse: 1.3113 - val_loss: 1.0031 - val_mse: 1.0031
#
# Epoch 00023: val_loss did not improve from 0.86923
# Epoch 24/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3031 - mse: 1.3031 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00024: val_loss did not improve from 0.86923
# Epoch 25/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3046 - mse: 1.3046 - val_loss: 0.9120 - val_mse: 0.9120
#
# Epoch 00025: val_loss did not improve from 0.86923
# Epoch 26/100
# 1619/1619 [==============================] - 22s 13ms/step - loss: 1.3033 - mse: 1.3033 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00026: val_loss did not improve from 0.86923
# Epoch 00026: early stopping
# Best: -1.261832 using {'activation': 'relu', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}, fitted in 2040.328570
# -1.411281 (1.073106) with: {'activation': 'tanh', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}, fitted in 5204.539128
# -1.261832 (1.095436) with: {'activation': 'relu', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}, fitted in 4359.991114
# *** Model fitted ***
# training mlp took  9852.836947441101

# %%
paramNeuronCount = [n_neurons*2]
paramHiddenLayers = [3]
paramActivation = ["sigmoid", "tanh", "relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramInputDim = [n_input]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfNeurons = paramNeuronCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, n_input = paramInputDim)
# Grid Search for hidden layers. Best: 3
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3318 - mse: 1.3318 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86958, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.3031 - mse: 1.3031 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00002: val_loss improved from 0.86958 to 0.86937, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00003: val_loss did not improve from 0.86937
# Epoch 4/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00004: val_loss did not improve from 0.86937
# Epoch 5/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00005: val_loss did not improve from 0.86937
# Epoch 6/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00006: val_loss did not improve from 0.86937
# Epoch 7/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00007: val_loss did not improve from 0.86937
# Epoch 8/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00008: val_loss did not improve from 0.86937
# Epoch 9/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00009: val_loss did not improve from 0.86937
# Epoch 10/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00010: val_loss did not improve from 0.86937
# Epoch 11/100
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00011: val_loss did not improve from 0.86937
# Epoch 12/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00012: val_loss did not improve from 0.86937
# Epoch 13/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00013: val_loss did not improve from 0.86937
# Epoch 14/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00014: val_loss did not improve from 0.86937
# Epoch 15/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00015: val_loss did not improve from 0.86937
# Epoch 16/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00016: val_loss did not improve from 0.86937
# Epoch 17/100
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00017: val_loss did not improve from 0.86937
# Epoch 00017: early stopping
# Best: -1.264817 using {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 1216, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 1, 'numberOfNeurons': 1216, 'pred_horizon': 480}, fitted in 403.746514
# -1.264817 (1.097372) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 1216, 'pred_horizon': 480}, fitted in 898.487702
# -1.264943 (1.097400) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 5, 'numberOfNeurons': 1216, 'pred_horizon': 480}, fitted in 1662.386278
# -1.264872 (1.097353) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 7, 'numberOfNeurons': 1216, 'pred_horizon': 480}, fitted in 1562.249362
# *** Model fitted ***
# training mlp took  3249.314745426178

# %%
paramNeuronCount = [n_neurons*2]
paramHiddenLayers = [3]
paramActivation = ["sigmoid", "tanh", "relu"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramInputDim = [n_input]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]

paramDict = dict(numberOfHiddenLayers = paramHiddenLayers, numberOfNeurons = paramNeuronCount, activation = paramActivation, 
                 n_history = paramHistory, pred_horizon = paramPredHorizon, n_input = paramInputDim)
# Grid Search for: neuron count. Best: n_neurons*2
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3653 - mse: 1.3653 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00001: val_loss improved from inf to 0.86937, saving model to grid_mlp_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00002: val_loss did not improve from 0.86937
# Epoch 3/100
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00003: val_loss did not improve from 0.86937
# Epoch 4/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00004: val_loss did not improve from 0.86937
# Epoch 5/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00005: val_loss did not improve from 0.86937
# Epoch 6/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00006: val_loss did not improve from 0.86937
# Epoch 7/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00007: val_loss did not improve from 0.86937
# Epoch 8/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00008: val_loss did not improve from 0.86937
# Epoch 9/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00009: val_loss did not improve from 0.86937
# Epoch 10/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00010: val_loss did not improve from 0.86937
# Epoch 11/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00011: val_loss did not improve from 0.86937
# Epoch 12/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00012: val_loss did not improve from 0.86937
# Epoch 13/100
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00013: val_loss did not improve from 0.86937
# Epoch 14/100
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00014: val_loss did not improve from 0.86937
# Epoch 15/100
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00015: val_loss did not improve from 0.86937
# Epoch 16/100
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00016: val_loss did not improve from 0.86937
# Epoch 00016: early stopping
# Best: -1.264974 using {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 10, 'pred_horizon': 480}, fitted in 57.054315
# nan (nan) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 608, 'pred_horizon': 480}, fitted in 234.308398
# nan (nan) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 1216, 'pred_horizon': 480}, fitted in 1030.017903
# -1.264974 (1.097518) with: {'activation': 'sigmoid', 'n_history': 32, 'n_input': 1952, 'numberOfHiddenLayers': 3, 'numberOfNeurons': 2432, 'pred_horizon': 480}, fitted in 2302.883691
# *** Model fitted ***
# training mlp took  3809.2332072257996

# %%
paramNumberOfHiddenConvPoolLayers = [2]
paramFilters = [(150,40)]# tuples instead of 2d array [[],[]] because of a bug: https://github.com/keras-team/keras/issues/13586
paramKernelSize = [2]
paramPoolSize = [2]
paramActivation = ["tanh"]
paramNumberOfLstmLayers = [1]
paramNumberOfLstmCells = [75]
paramLstmActivation = ["tanh"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]
paramDict = dict(numberOfHiddenConvPoolLayers = paramNumberOfHiddenConvPoolLayers, filters=paramFilters, kernelSize = paramKernelSize,
                poolSize = paramPoolSize, activation=paramActivation,
                numberOfLstmLayers = paramNumberOfLstmLayers, numberOfLstmCells=paramNumberOfLstmCells, lstmActivation=paramLstmActivation,
                n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for: KernelSize, PoolSize Best: kernelSize=2, poolSize=2
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 1s 868us/step - loss: 1.3036 - mse: 1.3036 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00001: val_loss improved from inf to 0.86950, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 1s 432us/step - loss: 1.3031 - mse: 1.3031 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00002: val_loss did not improve from 0.86950
# Epoch 3/100
# 1619/1619 [==============================] - 1s 400us/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00003: val_loss did not improve from 0.86950
# Epoch 4/100
# 1619/1619 [==============================] - 1s 389us/step - loss: 1.3027 - mse: 1.3027 - val_loss: 0.8688 - val_mse: 0.8688
#
# Epoch 00004: val_loss improved from 0.86950 to 0.86877, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 5/100
# 1619/1619 [==============================] - 1s 454us/step - loss: 1.3009 - mse: 1.3009 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00005: val_loss did not improve from 0.86877
# Epoch 6/100
# 1619/1619 [==============================] - 1s 447us/step - loss: 1.2988 - mse: 1.2988 - val_loss: 0.8722 - val_mse: 0.8722
#
# Epoch 00006: val_loss did not improve from 0.86877
# Epoch 7/100
# 1619/1619 [==============================] - 1s 447us/step - loss: 1.2974 - mse: 1.2974 - val_loss: 0.8720 - val_mse: 0.8720
#
# Epoch 00007: val_loss did not improve from 0.86877
# Epoch 8/100
# 1619/1619 [==============================] - 1s 453us/step - loss: 1.2970 - mse: 1.2970 - val_loss: 0.8705 - val_mse: 0.8705
#
# Epoch 00008: val_loss did not improve from 0.86877
# Epoch 9/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 1.2966 - mse: 1.2966 - val_loss: 0.8736 - val_mse: 0.8736
#
# Epoch 00009: val_loss did not improve from 0.86877
# Epoch 10/100
# 1619/1619 [==============================] - 1s 446us/step - loss: 1.2964 - mse: 1.2964 - val_loss: 0.8729 - val_mse: 0.8729
#
# Epoch 00010: val_loss did not improve from 0.86877
# Epoch 11/100
# 1619/1619 [==============================] - 1s 447us/step - loss: 1.2958 - mse: 1.2958 - val_loss: 0.8716 - val_mse: 0.8716
#
# Epoch 00011: val_loss did not improve from 0.86877
# Epoch 12/100
# 1619/1619 [==============================] - 1s 452us/step - loss: 1.2899 - mse: 1.2899 - val_loss: 0.8722 - val_mse: 0.8722
#
# Epoch 00012: val_loss did not improve from 0.86877
# Epoch 13/100
# 1619/1619 [==============================] - 1s 445us/step - loss: 1.2623 - mse: 1.2623 - val_loss: 0.8153 - val_mse: 0.8153
#
# Epoch 00013: val_loss improved from 0.86877 to 0.81526, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 14/100
# 1619/1619 [==============================] - 1s 444us/step - loss: 1.2076 - mse: 1.2076 - val_loss: 0.7180 - val_mse: 0.7180
#
# Epoch 00014: val_loss improved from 0.81526 to 0.71799, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 15/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 1.1501 - mse: 1.1500 - val_loss: 0.6772 - val_mse: 0.6772
#
# Epoch 00015: val_loss improved from 0.71799 to 0.67724, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 16/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 1.1233 - mse: 1.1233 - val_loss: 0.6546 - val_mse: 0.6546
#
# Epoch 00016: val_loss improved from 0.67724 to 0.65459, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 17/100
# 1619/1619 [==============================] - 1s 448us/step - loss: 1.1155 - mse: 1.1155 - val_loss: 0.6488 - val_mse: 0.6488
#
# Epoch 00017: val_loss improved from 0.65459 to 0.64876, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 18/100
# 1619/1619 [==============================] - 1s 445us/step - loss: 1.1034 - mse: 1.1034 - val_loss: 0.6702 - val_mse: 0.6702
#
# Epoch 00018: val_loss did not improve from 0.64876
# Epoch 19/100
# 1619/1619 [==============================] - 1s 441us/step - loss: 1.1000 - mse: 1.1000 - val_loss: 0.6589 - val_mse: 0.6589
#
# Epoch 00019: val_loss did not improve from 0.64876
# Epoch 20/100
# 1619/1619 [==============================] - 1s 441us/step - loss: 1.0966 - mse: 1.0966 - val_loss: 0.6759 - val_mse: 0.6759
#
# Epoch 00020: val_loss did not improve from 0.64876
# Epoch 21/100
# 1619/1619 [==============================] - 1s 441us/step - loss: 1.1094 - mse: 1.1094 - val_loss: 0.7198 - val_mse: 0.7198
#
# Epoch 00021: val_loss did not improve from 0.64876
# Epoch 22/100
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.0926 - mse: 1.0926 - val_loss: 0.6525 - val_mse: 0.6525
#
# Epoch 00022: val_loss did not improve from 0.64876
# Epoch 23/100
# 1619/1619 [==============================] - 1s 439us/step - loss: 1.0354 - mse: 1.0354 - val_loss: 0.6163 - val_mse: 0.6163
#
# Epoch 00023: val_loss improved from 0.64876 to 0.61631, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 24/100
# 1619/1619 [==============================] - 1s 441us/step - loss: 0.9794 - mse: 0.9794 - val_loss: 0.5850 - val_mse: 0.5850
#
# Epoch 00024: val_loss improved from 0.61631 to 0.58504, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 25/100
# 1619/1619 [==============================] - 1s 445us/step - loss: 0.9397 - mse: 0.9397 - val_loss: 0.5674 - val_mse: 0.5674
#
# Epoch 00025: val_loss improved from 0.58504 to 0.56743, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 26/100
# 1619/1619 [==============================] - 1s 441us/step - loss: 0.9167 - mse: 0.9167 - val_loss: 0.5624 - val_mse: 0.5624
#
# Epoch 00026: val_loss improved from 0.56743 to 0.56242, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 27/100
# 1619/1619 [==============================] - 1s 442us/step - loss: 0.9049 - mse: 0.9049 - val_loss: 0.5541 - val_mse: 0.5541
#
# Epoch 00027: val_loss improved from 0.56242 to 0.55405, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 28/100
# 1619/1619 [==============================] - 1s 444us/step - loss: 0.8994 - mse: 0.8994 - val_loss: 0.5502 - val_mse: 0.5502
#
# Epoch 00028: val_loss improved from 0.55405 to 0.55016, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 29/100
# 1619/1619 [==============================] - 1s 447us/step - loss: 0.8965 - mse: 0.8965 - val_loss: 0.5465 - val_mse: 0.5465
#
# Epoch 00029: val_loss improved from 0.55016 to 0.54650, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 30/100
# 1619/1619 [==============================] - 1s 443us/step - loss: 0.8949 - mse: 0.8949 - val_loss: 0.5460 - val_mse: 0.5460
#
# Epoch 00030: val_loss improved from 0.54650 to 0.54595, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 31/100
# 1619/1619 [==============================] - 1s 442us/step - loss: 0.8946 - mse: 0.8946 - val_loss: 0.5531 - val_mse: 0.5531
#
# Epoch 00031: val_loss did not improve from 0.54595
# Epoch 32/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 0.8934 - mse: 0.8934 - val_loss: 0.5408 - val_mse: 0.5408
#
# Epoch 00032: val_loss improved from 0.54595 to 0.54077, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 33/100
# 1619/1619 [==============================] - 1s 452us/step - loss: 0.8931 - mse: 0.8931 - val_loss: 0.5621 - val_mse: 0.5621
#
# Epoch 00033: val_loss did not improve from 0.54077
# Epoch 34/100
# 1619/1619 [==============================] - 1s 458us/step - loss: 0.8928 - mse: 0.8928 - val_loss: 0.5479 - val_mse: 0.5479
#
# Epoch 00034: val_loss did not improve from 0.54077
# Epoch 35/100
# 1619/1619 [==============================] - 1s 455us/step - loss: 0.8923 - mse: 0.8923 - val_loss: 0.5303 - val_mse: 0.5303
#
# Epoch 00035: val_loss improved from 0.54077 to 0.53030, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 36/100
# 1619/1619 [==============================] - 1s 457us/step - loss: 0.8920 - mse: 0.8920 - val_loss: 0.5516 - val_mse: 0.5516
#
# Epoch 00036: val_loss did not improve from 0.53030
# Epoch 37/100
# 1619/1619 [==============================] - 1s 459us/step - loss: 0.8917 - mse: 0.8917 - val_loss: 0.5610 - val_mse: 0.5610
#
# Epoch 00037: val_loss did not improve from 0.53030
# Epoch 38/100
# 1619/1619 [==============================] - 1s 455us/step - loss: 0.8915 - mse: 0.8915 - val_loss: 0.5608 - val_mse: 0.5608
#
# Epoch 00038: val_loss did not improve from 0.53030
# Epoch 39/100
# 1619/1619 [==============================] - 1s 460us/step - loss: 0.8913 - mse: 0.8913 - val_loss: 0.5548 - val_mse: 0.5548
#
# Epoch 00039: val_loss did not improve from 0.53030
# Epoch 40/100
# 1619/1619 [==============================] - 1s 464us/step - loss: 0.8910 - mse: 0.8910 - val_loss: 0.5735 - val_mse: 0.5735
#
# Epoch 00040: val_loss did not improve from 0.53030
# Epoch 41/100
# 1619/1619 [==============================] - 1s 456us/step - loss: 0.8910 - mse: 0.8910 - val_loss: 0.5592 - val_mse: 0.5592
#
# Epoch 00041: val_loss did not improve from 0.53030
# Epoch 42/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 0.8920 - mse: 0.8920 - val_loss: 0.5464 - val_mse: 0.5464
#
# Epoch 00042: val_loss did not improve from 0.53030
# Epoch 43/100
# 1619/1619 [==============================] - 1s 451us/step - loss: 0.8907 - mse: 0.8907 - val_loss: 0.5807 - val_mse: 0.5807
#
# Epoch 00043: val_loss did not improve from 0.53030
# Epoch 44/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 0.8903 - mse: 0.8903 - val_loss: 0.5899 - val_mse: 0.5899
#
# Epoch 00044: val_loss did not improve from 0.53030
# Epoch 45/100
# 1619/1619 [==============================] - 1s 455us/step - loss: 0.8908 - mse: 0.8908 - val_loss: 0.5514 - val_mse: 0.5514
#
# Epoch 00045: val_loss did not improve from 0.53030
# Epoch 46/100
# 1619/1619 [==============================] - 1s 449us/step - loss: 0.8900 - mse: 0.8900 - val_loss: 0.5648 - val_mse: 0.5648
#
# Epoch 00046: val_loss did not improve from 0.53030
# Epoch 47/100
# 1619/1619 [==============================] - 1s 442us/step - loss: 0.8913 - mse: 0.8913 - val_loss: 0.5455 - val_mse: 0.5455
#
# Epoch 00047: val_loss did not improve from 0.53030
# Epoch 48/100
# 1619/1619 [==============================] - 1s 446us/step - loss: 0.9188 - mse: 0.9188 - val_loss: 0.4510 - val_mse: 0.4510
#
# Epoch 00048: val_loss improved from 0.53030 to 0.45101, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 49/100
# 1619/1619 [==============================] - 1s 449us/step - loss: 0.8933 - mse: 0.8933 - val_loss: 0.4694 - val_mse: 0.4694
#
# Epoch 00049: val_loss did not improve from 0.45101
# Epoch 50/100
# 1619/1619 [==============================] - 1s 470us/step - loss: 0.8900 - mse: 0.8900 - val_loss: 0.4616 - val_mse: 0.4616
#
# Epoch 00050: val_loss did not improve from 0.45101
# Epoch 51/100
# 1619/1619 [==============================] - 1s 454us/step - loss: 0.8927 - mse: 0.8927 - val_loss: 0.4687 - val_mse: 0.4687
#
# Epoch 00051: val_loss did not improve from 0.45101
# Epoch 52/100
# 1619/1619 [==============================] - 1s 451us/step - loss: 0.8999 - mse: 0.8999 - val_loss: 0.5291 - val_mse: 0.5291
#
# Epoch 00052: val_loss did not improve from 0.45101
# Epoch 53/100
# 1619/1619 [==============================] - 1s 449us/step - loss: 0.8919 - mse: 0.8919 - val_loss: 0.4583 - val_mse: 0.4583
#
# Epoch 00053: val_loss did not improve from 0.45101
# Epoch 54/100
# 1619/1619 [==============================] - 1s 452us/step - loss: 0.8911 - mse: 0.8911 - val_loss: 0.4596 - val_mse: 0.4596
#
# Epoch 00054: val_loss did not improve from 0.45101
# Epoch 55/100
# 1619/1619 [==============================] - 1s 449us/step - loss: 0.8902 - mse: 0.8902 - val_loss: 0.4644 - val_mse: 0.4644
#
# Epoch 00055: val_loss did not improve from 0.45101
# Epoch 56/100
# 1619/1619 [==============================] - 1s 446us/step - loss: 0.8916 - mse: 0.8916 - val_loss: 0.4366 - val_mse: 0.4366
#
# Epoch 00056: val_loss improved from 0.45101 to 0.43658, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 57/100
# 1619/1619 [==============================] - 1s 448us/step - loss: 0.8915 - mse: 0.8915 - val_loss: 0.4544 - val_mse: 0.4544
#
# Epoch 00057: val_loss did not improve from 0.43658
# Epoch 58/100
# 1619/1619 [==============================] - 1s 451us/step - loss: 0.8903 - mse: 0.8903 - val_loss: 0.4572 - val_mse: 0.4572
#
# Epoch 00058: val_loss did not improve from 0.43658
# Epoch 59/100
# 1619/1619 [==============================] - 1s 447us/step - loss: 0.8894 - mse: 0.8894 - val_loss: 0.4698 - val_mse: 0.4698
#
# Epoch 00059: val_loss did not improve from 0.43658
# Epoch 60/100
# 1619/1619 [==============================] - 1s 450us/step - loss: 0.8898 - mse: 0.8898 - val_loss: 0.4630 - val_mse: 0.4630
#
# Epoch 00060: val_loss did not improve from 0.43658
# Epoch 61/100
# 1619/1619 [==============================] - 1s 449us/step - loss: 0.8908 - mse: 0.8908 - val_loss: 0.4618 - val_mse: 0.4618
#
# Epoch 00061: val_loss did not improve from 0.43658
# Epoch 62/100
# 1619/1619 [==============================] - 1s 451us/step - loss: 0.8908 - mse: 0.8908 - val_loss: 0.4588 - val_mse: 0.4588
#
# Epoch 00062: val_loss did not improve from 0.43658
# Epoch 63/100
# 1619/1619 [==============================] - 1s 452us/step - loss: 0.8889 - mse: 0.8889 - val_loss: 0.4610 - val_mse: 0.4610
#
# Epoch 00063: val_loss did not improve from 0.43658
# Epoch 64/100
# 1619/1619 [==============================] - 1s 455us/step - loss: 0.8905 - mse: 0.8905 - val_loss: 0.4588 - val_mse: 0.4588
#
# Epoch 00064: val_loss did not improve from 0.43658
# Epoch 65/100
# 1619/1619 [==============================] - 1s 454us/step - loss: 0.8903 - mse: 0.8903 - val_loss: 0.4573 - val_mse: 0.4573
#
# Epoch 00065: val_loss did not improve from 0.43658
# Epoch 66/100
# 1619/1619 [==============================] - 1s 453us/step - loss: 0.8877 - mse: 0.8877 - val_loss: 0.4648 - val_mse: 0.4648
#
# Epoch 00066: val_loss did not improve from 0.43658
# Epoch 67/100
# 1619/1619 [==============================] - 1s 456us/step - loss: 0.8876 - mse: 0.8876 - val_loss: 0.4617 - val_mse: 0.4617
#
# Epoch 00067: val_loss did not improve from 0.43658
# Epoch 68/100
# 1619/1619 [==============================] - 1s 459us/step - loss: 0.8873 - mse: 0.8873 - val_loss: 0.4638 - val_mse: 0.4638
#
# Epoch 00068: val_loss did not improve from 0.43658
# Epoch 69/100
# 1619/1619 [==============================] - 1s 461us/step - loss: 0.8869 - mse: 0.8869 - val_loss: 0.4647 - val_mse: 0.4647
#
# Epoch 00069: val_loss did not improve from 0.43658
# Epoch 70/100
# 1619/1619 [==============================] - 1s 466us/step - loss: 0.8859 - mse: 0.8859 - val_loss: 0.4694 - val_mse: 0.4694
#
# Epoch 00070: val_loss did not improve from 0.43658
# Epoch 71/100
# 1619/1619 [==============================] - 1s 456us/step - loss: 0.8898 - mse: 0.8898 - val_loss: 0.4600 - val_mse: 0.4600
#
# Epoch 00071: val_loss did not improve from 0.43658
# Epoch 00071: early stopping
# Best: -1.132137 using {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 1, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 1, 'pred_horizon': 480}, fitted in 191.396719
# -1.161734 (1.012176) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 1, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 126.754972
# nan (nan) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 1, 'pred_horizon': 480}, fitted in 286.305880
# -1.132137 (1.204132) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 196.763560
# nan (nan) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 3, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 1, 'pred_horizon': 480}, fitted in 192.341344
# -1.222620 (1.118754) with: {'activation': 'tanh', 'filters': (75, 38), 'kernelSize': 3, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 117.483752
# *** Model fitted ***
# training cnn took  870.9920573234558

# %%
paramNumberOfHiddenConvPoolLayers = [2]
paramFilters = [(150,40)]# tuples instead of 2d array [[],[]] because of a bug: https://github.com/keras-team/keras/issues/13586
paramKernelSize = [2]
paramPoolSize = [2]
paramActivation = ["tanh"]
paramNumberOfLstmLayers = [1]
paramNumberOfLstmCells = [75]
paramLstmActivation = ["tanh"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]
paramDict = dict(numberOfHiddenConvPoolLayers = paramNumberOfHiddenConvPoolLayers, filters=paramFilters, kernelSize = paramKernelSize,
                poolSize = paramPoolSize, activation=paramActivation,
                numberOfLstmLayers = paramNumberOfLstmLayers, numberOfLstmCells=paramNumberOfLstmCells, lstmActivation=paramLstmActivation,
                n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for:  activation (ConvPool+lstm) tanh vs relu . Best: tanh for both
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 2s 954us/step - loss: 1.3046 - val_loss: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86964, saving model to cnn_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 1.3031 - val_loss: 0.8699
#
# Epoch 00002: val_loss did not improve from 0.86964
# Epoch 3/200
# 1619/1619 [==============================] - 1s 410us/step - loss: 1.3030 - val_loss: 0.8698
#
# Epoch 00003: val_loss did not improve from 0.86964
# Epoch 4/200
# 1619/1619 [==============================] - 1s 406us/step - loss: 1.3030 - val_loss: 0.8691
#
# Epoch 00004: val_loss improved from 0.86964 to 0.86908, saving model to cnn_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 1s 415us/step - loss: 1.3028 - val_loss: 0.8694
#
# Epoch 00005: val_loss did not improve from 0.86908
# Epoch 6/200
# 1619/1619 [==============================] - 1s 435us/step - loss: 1.3023 - val_loss: 0.8682
#
# Epoch 00006: val_loss improved from 0.86908 to 0.86823, saving model to cnn_multistep_multivariate.h5
# Epoch 7/200
# 1619/1619 [==============================] - 1s 448us/step - loss: 1.3025 - val_loss: 0.8688
#
# Epoch 00007: val_loss did not improve from 0.86823
# Epoch 8/200
# 1619/1619 [==============================] - 1s 418us/step - loss: 1.3018 - val_loss: 0.8681
#
# Epoch 00008: val_loss improved from 0.86823 to 0.86807, saving model to cnn_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.3016 - val_loss: 0.8702
#
# Epoch 00009: val_loss did not improve from 0.86807
# Epoch 10/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.3012 - val_loss: 0.8694
#
# Epoch 00010: val_loss did not improve from 0.86807
# Epoch 11/200
# 1619/1619 [==============================] - 1s 409us/step - loss: 1.2999 - val_loss: 0.8689
#
# Epoch 00011: val_loss did not improve from 0.86807
# Epoch 12/200
# 1619/1619 [==============================] - 1s 427us/step - loss: 1.2990 - val_loss: 0.8721
#
# Epoch 00012: val_loss did not improve from 0.86807
# Epoch 13/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 1.2981 - val_loss: 0.8705
#
# Epoch 00013: val_loss did not improve from 0.86807
# Epoch 14/200
# 1619/1619 [==============================] - 1s 430us/step - loss: 1.2972 - val_loss: 0.8707
#
# Epoch 00014: val_loss did not improve from 0.86807
# Epoch 15/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.2966 - val_loss: 0.8696
#
# Epoch 00015: val_loss did not improve from 0.86807
# Epoch 16/200
# 1619/1619 [==============================] - 1s 436us/step - loss: 1.2813 - val_loss: 0.8417
#
# Epoch 00016: val_loss improved from 0.86807 to 0.84171, saving model to cnn_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 1.2356 - val_loss: 0.7851
#
# Epoch 00017: val_loss improved from 0.84171 to 0.78507, saving model to cnn_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 1s 436us/step - loss: 1.1390 - val_loss: 0.6405
#
# Epoch 00018: val_loss improved from 0.78507 to 0.64055, saving model to cnn_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 1s 432us/step - loss: 1.0195 - val_loss: 0.5246
#
# Epoch 00019: val_loss improved from 0.64055 to 0.52457, saving model to cnn_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 0.9480 - val_loss: 0.4610
#
# Epoch 00020: val_loss improved from 0.52457 to 0.46100, saving model to cnn_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 1s 444us/step - loss: 0.9141 - val_loss: 0.4359
#
# Epoch 00021: val_loss improved from 0.46100 to 0.43591, saving model to cnn_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 1s 439us/step - loss: 0.9027 - val_loss: 0.4266
#
# Epoch 00022: val_loss improved from 0.43591 to 0.42657, saving model to cnn_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 1s 437us/step - loss: 0.8970 - val_loss: 0.4206
#
# Epoch 00023: val_loss improved from 0.42657 to 0.42057, saving model to cnn_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 1s 429us/step - loss: 0.8941 - val_loss: 0.4189
#
# Epoch 00024: val_loss improved from 0.42057 to 0.41890, saving model to cnn_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 1s 427us/step - loss: 0.8940 - val_loss: 0.4273
#
# Epoch 00025: val_loss did not improve from 0.41890
# Epoch 26/200
# 1619/1619 [==============================] - 1s 432us/step - loss: 0.8919 - val_loss: 0.3997
#
# Epoch 00026: val_loss improved from 0.41890 to 0.39968, saving model to cnn_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 1s 434us/step - loss: 0.8932 - val_loss: 0.4032
#
# Epoch 00027: val_loss did not improve from 0.39968
# Epoch 28/200
# 1619/1619 [==============================] - 1s 421us/step - loss: 0.8896 - val_loss: 0.4027
#
# Epoch 00028: val_loss did not improve from 0.39968
# Epoch 29/200
# 1619/1619 [==============================] - 1s 423us/step - loss: 0.8879 - val_loss: 0.3952
#
# Epoch 00029: val_loss improved from 0.39968 to 0.39524, saving model to cnn_multistep_multivariate.h5
# Epoch 30/200
# 1619/1619 [==============================] - 1s 434us/step - loss: 0.8870 - val_loss: 0.3889
#
# Epoch 00030: val_loss improved from 0.39524 to 0.38894, saving model to cnn_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 1s 421us/step - loss: 0.8866 - val_loss: 0.3869
#
# Epoch 00031: val_loss improved from 0.38894 to 0.38689, saving model to cnn_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 0.8858 - val_loss: 0.3860
#
# Epoch 00032: val_loss improved from 0.38689 to 0.38598, saving model to cnn_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 1s 429us/step - loss: 0.8852 - val_loss: 0.3852
#
# Epoch 00033: val_loss improved from 0.38598 to 0.38515, saving model to cnn_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 1s 418us/step - loss: 0.8849 - val_loss: 0.3847
#
# Epoch 00034: val_loss improved from 0.38515 to 0.38475, saving model to cnn_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 1s 423us/step - loss: 0.8837 - val_loss: 0.3902
#
# Epoch 00035: val_loss did not improve from 0.38475
# Epoch 36/200
# 1619/1619 [==============================] - 1s 410us/step - loss: 0.8831 - val_loss: 0.3897
#
# Epoch 00036: val_loss did not improve from 0.38475
# Epoch 37/200
# 1619/1619 [==============================] - 1s 420us/step - loss: 0.8822 - val_loss: 0.3896
#
# Epoch 00037: val_loss did not improve from 0.38475
# Epoch 38/200
# 1619/1619 [==============================] - 1s 413us/step - loss: 0.8814 - val_loss: 0.3915
#
# Epoch 00038: val_loss did not improve from 0.38475
# Epoch 39/200
# 1619/1619 [==============================] - 1s 406us/step - loss: 0.8809 - val_loss: 0.3934
#
# Epoch 00039: val_loss did not improve from 0.38475
# Epoch 40/200
# 1619/1619 [==============================] - 1s 419us/step - loss: 0.8798 - val_loss: 0.3997
#
# Epoch 00040: val_loss did not improve from 0.38475
# Epoch 41/200
# 1619/1619 [==============================] - 1s 409us/step - loss: 0.8791 - val_loss: 0.4139
#
# Epoch 00041: val_loss did not improve from 0.38475
# Epoch 42/200
# 1619/1619 [==============================] - 1s 405us/step - loss: 0.8846 - val_loss: 0.4106
#
# Epoch 00042: val_loss did not improve from 0.38475
# Epoch 43/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 0.8769 - val_loss: 0.4094
#
# Epoch 00043: val_loss did not improve from 0.38475
# Epoch 44/200
# 1619/1619 [==============================] - 1s 486us/step - loss: 0.8744 - val_loss: 0.4160
#
# Epoch 00044: val_loss did not improve from 0.38475
# Epoch 45/200
# 1619/1619 [==============================] - 1s 477us/step - loss: 0.8726 - val_loss: 0.4191
#
# Epoch 00045: val_loss did not improve from 0.38475
# Epoch 46/200
# 1619/1619 [==============================] - 1s 480us/step - loss: 0.8702 - val_loss: 0.4335
#
# Epoch 00046: val_loss did not improve from 0.38475
# Epoch 47/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8686 - val_loss: 0.4266
#
# Epoch 00047: val_loss did not improve from 0.38475
# Epoch 48/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8682 - val_loss: 0.4311
#
# Epoch 00048: val_loss did not improve from 0.38475
# Epoch 49/200
# 1619/1619 [==============================] - 1s 546us/step - loss: 0.8645 - val_loss: 0.4387
#
# Epoch 00049: val_loss did not improve from 0.38475
# Epoch 50/200
# 1619/1619 [==============================] - 1s 515us/step - loss: 0.8616 - val_loss: 0.4379
#
# Epoch 00050: val_loss did not improve from 0.38475
# Epoch 51/200
# 1619/1619 [==============================] - 1s 480us/step - loss: 0.8588 - val_loss: 0.4392
#
# Epoch 00051: val_loss did not improve from 0.38475
# Epoch 52/200
# 1619/1619 [==============================] - 1s 474us/step - loss: 0.8690 - val_loss: 0.5981
#
# Epoch 00052: val_loss did not improve from 0.38475
# Epoch 53/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8602 - val_loss: 0.4489
#
# Epoch 00053: val_loss did not improve from 0.38475
# Epoch 54/200
# 1619/1619 [==============================] - 1s 489us/step - loss: 0.8533 - val_loss: 0.4607
#
# Epoch 00054: val_loss did not improve from 0.38475
# Epoch 55/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8502 - val_loss: 0.4575
#
# Epoch 00055: val_loss did not improve from 0.38475
# Epoch 56/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.8471 - val_loss: 0.4415
#
# Epoch 00056: val_loss did not improve from 0.38475
# Epoch 57/200
# 1619/1619 [==============================] - 1s 482us/step - loss: 0.8441 - val_loss: 0.4457
#
# Epoch 00057: val_loss did not improve from 0.38475
# Epoch 58/200
# 1619/1619 [==============================] - 1s 485us/step - loss: 0.8538 - val_loss: 0.4790
#
# Epoch 00058: val_loss did not improve from 0.38475
# Epoch 59/200
# 1619/1619 [==============================] - 1s 517us/step - loss: 0.8499 - val_loss: 0.4727
#
# Epoch 00059: val_loss did not improve from 0.38475
# Epoch 60/200
# 1619/1619 [==============================] - 1s 490us/step - loss: 0.8381 - val_loss: 0.4758
#
# Epoch 00060: val_loss did not improve from 0.38475
# Epoch 61/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.8350 - val_loss: 0.4816
#
# Epoch 00061: val_loss did not improve from 0.38475
# Epoch 62/200
# 1619/1619 [==============================] - 1s 487us/step - loss: 0.8318 - val_loss: 0.4915
#
# Epoch 00062: val_loss did not improve from 0.38475
# Epoch 63/200
# 1619/1619 [==============================] - 1s 489us/step - loss: 0.8288 - val_loss: 0.4708
#
# Epoch 00063: val_loss did not improve from 0.38475
# Epoch 64/200
# 1619/1619 [==============================] - 1s 521us/step - loss: 0.8269 - val_loss: 0.4872
#
# Epoch 00064: val_loss did not improve from 0.38475
# Epoch 65/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.8235 - val_loss: 0.4743
#
# Epoch 00065: val_loss did not improve from 0.38475
# Epoch 66/200
# 1619/1619 [==============================] - 1s 520us/step - loss: 0.8204 - val_loss: 0.4873
#
# Epoch 00066: val_loss did not improve from 0.38475
# Epoch 67/200
# 1619/1619 [==============================] - 1s 583us/step - loss: 0.8179 - val_loss: 0.4714
#
# Epoch 00067: val_loss did not improve from 0.38475
# Epoch 68/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.8139 - val_loss: 0.4959
#
# Epoch 00068: val_loss did not improve from 0.38475
# Epoch 69/200
# 1619/1619 [==============================] - 1s 498us/step - loss: 0.8108 - val_loss: 0.4689
#
# Epoch 00069: val_loss did not improve from 0.38475
# Epoch 70/200
# 1619/1619 [==============================] - 1s 487us/step - loss: 0.8118 - val_loss: 0.4922
#
# Epoch 00070: val_loss did not improve from 0.38475
# Epoch 71/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.8056 - val_loss: 0.4936
#
# Epoch 00071: val_loss did not improve from 0.38475
# Epoch 72/200
# 1619/1619 [==============================] - 1s 516us/step - loss: 0.8021 - val_loss: 0.5017
#
# Epoch 00072: val_loss did not improve from 0.38475
# Epoch 73/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.8002 - val_loss: 0.5365
#
# Epoch 00073: val_loss did not improve from 0.38475
# Epoch 74/200
# 1619/1619 [==============================] - 1s 506us/step - loss: 0.7970 - val_loss: 0.5278
#
# Epoch 00074: val_loss did not improve from 0.38475
# Epoch 75/200
# 1619/1619 [==============================] - 1s 503us/step - loss: 0.7935 - val_loss: 0.5293
#
# Epoch 00075: val_loss did not improve from 0.38475
# Epoch 76/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7906 - val_loss: 0.4961
#
# Epoch 00076: val_loss did not improve from 0.38475
# Epoch 77/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7888 - val_loss: 0.4771
#
# Epoch 00077: val_loss did not improve from 0.38475
# Epoch 78/200
# 1619/1619 [==============================] - 1s 511us/step - loss: 0.7892 - val_loss: 0.5004
#
# Epoch 00078: val_loss did not improve from 0.38475
# Epoch 79/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7909 - val_loss: 0.5199
#
# Epoch 00079: val_loss did not improve from 0.38475
# Epoch 80/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7855 - val_loss: 0.5553
#
# Epoch 00080: val_loss did not improve from 0.38475
# Epoch 81/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7797 - val_loss: 0.5109
#
# Epoch 00081: val_loss did not improve from 0.38475
# Epoch 82/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7768 - val_loss: 0.5325
#
# Epoch 00082: val_loss did not improve from 0.38475
# Epoch 83/200
# 1619/1619 [==============================] - 1s 518us/step - loss: 0.7740 - val_loss: 0.5299
#
# Epoch 00083: val_loss did not improve from 0.38475
# Epoch 84/200
# 1619/1619 [==============================] - 1s 524us/step - loss: 0.7717 - val_loss: 0.5800
#
# Epoch 00084: val_loss did not improve from 0.38475
# Epoch 85/200
# 1619/1619 [==============================] - 1s 511us/step - loss: 0.7695 - val_loss: 0.5887
#
# Epoch 00085: val_loss did not improve from 0.38475
# Epoch 86/200
# 1619/1619 [==============================] - 1s 534us/step - loss: 0.7673 - val_loss: 0.5446
#
# Epoch 00086: val_loss did not improve from 0.38475
# Epoch 87/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7646 - val_loss: 0.5709
#
# Epoch 00087: val_loss did not improve from 0.38475
# Epoch 88/200
# 1619/1619 [==============================] - 1s 505us/step - loss: 0.7637 - val_loss: 0.5712
#
# Epoch 00088: val_loss did not improve from 0.38475
# Epoch 89/200
# 1619/1619 [==============================] - 1s 503us/step - loss: 0.7608 - val_loss: 0.5672
#
# Epoch 00089: val_loss did not improve from 0.38475
# Epoch 90/200
# 1619/1619 [==============================] - 1s 514us/step - loss: 0.7726 - val_loss: 0.7322
#
# Epoch 00090: val_loss did not improve from 0.38475
# Epoch 91/200
# 1619/1619 [==============================] - 1s 660us/step - loss: 0.7731 - val_loss: 0.4671
#
# Epoch 00091: val_loss did not improve from 0.38475
# Epoch 92/200
# 1619/1619 [==============================] - 1s 573us/step - loss: 0.7593 - val_loss: 0.5589
#
# Epoch 00092: val_loss did not improve from 0.38475
# Epoch 93/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.7536 - val_loss: 0.5773
#
# Epoch 00093: val_loss did not improve from 0.38475
# Epoch 94/200
# 1619/1619 [==============================] - 1s 490us/step - loss: 0.7508 - val_loss: 0.5746
#
# Epoch 00094: val_loss did not improve from 0.38475
# Epoch 95/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7482 - val_loss: 0.6013
#
# Epoch 00095: val_loss did not improve from 0.38475
# Epoch 96/200
# 1619/1619 [==============================] - 1s 493us/step - loss: 0.7463 - val_loss: 0.5840
#
# Epoch 00096: val_loss did not improve from 0.38475
# Epoch 97/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.7441 - val_loss: 0.5839
#
# Epoch 00097: val_loss did not improve from 0.38475
# Epoch 98/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7437 - val_loss: 0.5372
#
# Epoch 00098: val_loss did not improve from 0.38475
# Epoch 99/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.7423 - val_loss: 0.5960
#
# Epoch 00099: val_loss did not improve from 0.38475
# Epoch 100/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7391 - val_loss: 0.5796
#
# Epoch 00100: val_loss did not improve from 0.38475
# Epoch 101/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7370 - val_loss: 0.5874
#
# Epoch 00101: val_loss did not improve from 0.38475
# Epoch 102/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7346 - val_loss: 0.5844
#
# Epoch 00102: val_loss did not improve from 0.38475
# Epoch 103/200
# 1619/1619 [==============================] - 1s 517us/step - loss: 0.7326 - val_loss: 0.6173
#
# Epoch 00103: val_loss did not improve from 0.38475
# Epoch 104/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7307 - val_loss: 0.6148
#
# Epoch 00104: val_loss did not improve from 0.38475
# Epoch 105/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.7294 - val_loss: 0.5818
#
# Epoch 00105: val_loss did not improve from 0.38475
# Epoch 106/200
# 1619/1619 [==============================] - 1s 550us/step - loss: 0.7281 - val_loss: 0.6250
#
# Epoch 00106: val_loss did not improve from 0.38475
# Epoch 107/200
# 1619/1619 [==============================] - 1s 580us/step - loss: 0.7259 - val_loss: 0.5696
#
# Epoch 00107: val_loss did not improve from 0.38475
# Epoch 108/200
# 1619/1619 [==============================] - 1s 518us/step - loss: 0.7237 - val_loss: 0.5860
#
# Epoch 00108: val_loss did not improve from 0.38475
# Epoch 109/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7230 - val_loss: 0.6153
#
# Epoch 00109: val_loss did not improve from 0.38475
# Epoch 110/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7204 - val_loss: 0.5800
#
# Epoch 00110: val_loss did not improve from 0.38475
# Epoch 111/200
# 1619/1619 [==============================] - 1s 499us/step - loss: 0.7195 - val_loss: 0.6322
#
# Epoch 00111: val_loss did not improve from 0.38475
# Epoch 112/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.7210 - val_loss: 0.6933
#
# Epoch 00112: val_loss did not improve from 0.38475
# Epoch 113/200
# 1619/1619 [==============================] - 1s 536us/step - loss: 0.7203 - val_loss: 0.6518
#
# Epoch 00113: val_loss did not improve from 0.38475
# Epoch 114/200
# 1619/1619 [==============================] - 1s 552us/step - loss: 0.7363 - val_loss: 0.6529
#
# Epoch 00114: val_loss did not improve from 0.38475
# Epoch 115/200
# 1619/1619 [==============================] - 1s 556us/step - loss: 0.7179 - val_loss: 0.6474
#
# Epoch 00115: val_loss did not improve from 0.38475
# Epoch 116/200
# 1619/1619 [==============================] - 1s 493us/step - loss: 0.7137 - val_loss: 0.6215
#
# Epoch 00116: val_loss did not improve from 0.38475
# Epoch 117/200
# 1619/1619 [==============================] - 1s 514us/step - loss: 0.7098 - val_loss: 0.6146
#
# Epoch 00117: val_loss did not improve from 0.38475
# Epoch 118/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7081 - val_loss: 0.6337
#
# Epoch 00118: val_loss did not improve from 0.38475
# Epoch 119/200
# 1619/1619 [==============================] - 1s 530us/step - loss: 0.7063 - val_loss: 0.6260
#
# Epoch 00119: val_loss did not improve from 0.38475
# Epoch 120/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7046 - val_loss: 0.6202
#
# Epoch 00120: val_loss did not improve from 0.38475
# Epoch 121/200
# 1619/1619 [==============================] - 1s 512us/step - loss: 0.7038 - val_loss: 0.5983
#
# Epoch 00121: val_loss did not improve from 0.38475
# Epoch 122/200
# 1619/1619 [==============================] - 1s 551us/step - loss: 0.7026 - val_loss: 0.6656
#
# Epoch 00122: val_loss did not improve from 0.38475
# Epoch 123/200
# 1619/1619 [==============================] - 1s 554us/step - loss: 0.7004 - val_loss: 0.6685
#
# Epoch 00123: val_loss did not improve from 0.38475
# Epoch 124/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.6987 - val_loss: 0.6644
#
# Epoch 00124: val_loss did not improve from 0.38475
# Epoch 125/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.6974 - val_loss: 0.6302
#
# Epoch 00125: val_loss did not improve from 0.38475
# Epoch 126/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.6955 - val_loss: 0.6508
#
# Epoch 00126: val_loss did not improve from 0.38475
# Epoch 127/200
# 1619/1619 [==============================] - 1s 491us/step - loss: 0.6937 - val_loss: 0.6407
#
# Epoch 00127: val_loss did not improve from 0.38475
# Epoch 128/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.6923 - val_loss: 0.6918
#
# Epoch 00128: val_loss did not improve from 0.38475
# Epoch 129/200
# 1619/1619 [==============================] - 1s 488us/step - loss: 0.6938 - val_loss: 0.6333
#
# Epoch 00129: val_loss did not improve from 0.38475
# Epoch 130/200
# 1619/1619 [==============================] - 1s 485us/step - loss: 0.6937 - val_loss: 0.7251
#
# Epoch 00130: val_loss did not improve from 0.38475
# Epoch 131/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.6895 - val_loss: 0.6668
#
# Epoch 00131: val_loss did not improve from 0.38475
# Epoch 132/200
# 1619/1619 [==============================] - 1s 488us/step - loss: 0.6871 - val_loss: 0.6692
#
# Epoch 00132: val_loss did not improve from 0.38475
# Epoch 133/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.6857 - val_loss: 0.6703
#
# Epoch 00133: val_loss did not improve from 0.38475
# Epoch 134/200
# 1619/1619 [==============================] - 1s 483us/step - loss: 0.6846 - val_loss: 0.6907
#
# Epoch 00134: val_loss did not improve from 0.38475
# Epoch 00134: early stopping
# *** Model fitted ***
# training cnn took  109.71351504325867

# %%
paramNumberOfHiddenConvPoolLayers = [2]
paramFilters = [(150,40)]# tuples instead of 2d array [[],[]] because of a bug: https://github.com/keras-team/keras/issues/13586
paramKernelSize = [2]
paramPoolSize = [2]
paramActivation = ["tanh"]
paramNumberOfLstmLayers = [1]
paramNumberOfLstmCells = [75]
paramLstmActivation = ["tanh"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]
paramDict = dict(numberOfHiddenConvPoolLayers = paramNumberOfHiddenConvPoolLayers, filters=paramFilters, kernelSize = paramKernelSize,
                poolSize = paramPoolSize, activation=paramActivation,
                numberOfLstmLayers = paramNumberOfLstmLayers, numberOfLstmCells=paramNumberOfLstmCells, lstmActivation=paramLstmActivation,
                n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for: number of hidden ConvPool layers and filters. Best: 2 layers, filter: (150,40)
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# C:\ProgramData\Anaconda3\lib\site-packages\joblib\externals\loky\process_executor.py:706: UserWarning:
#
# A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 1s 918us/step - loss: 1.3037 - mse: 1.3037 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86957, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 1s 473us/step - loss: 1.3031 - mse: 1.3031 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00002: val_loss did not improve from 0.86957
# Epoch 3/100
# 1619/1619 [==============================] - 1s 461us/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00003: val_loss did not improve from 0.86957
# Epoch 4/100
# 1619/1619 [==============================] - 1s 460us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00004: val_loss did not improve from 0.86957
# Epoch 5/100
# 1619/1619 [==============================] - 1s 493us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8700 - val_mse: 0.8700
#
# Epoch 00005: val_loss did not improve from 0.86957
# Epoch 6/100
# 1619/1619 [==============================] - 1s 528us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00006: val_loss did not improve from 0.86957
# Epoch 7/100
# 1619/1619 [==============================] - 1s 530us/step - loss: 1.3028 - mse: 1.3028 - val_loss: 0.8706 - val_mse: 0.8706
#
# Epoch 00007: val_loss did not improve from 0.86957
# Epoch 8/100
# 1619/1619 [==============================] - 1s 527us/step - loss: 1.3026 - mse: 1.3026 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00008: val_loss did not improve from 0.86957
# Epoch 9/100
# 1619/1619 [==============================] - 1s 515us/step - loss: 1.3008 - mse: 1.3008 - val_loss: 0.8690 - val_mse: 0.8690
#
# Epoch 00009: val_loss improved from 0.86957 to 0.86898, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 10/100
# 1619/1619 [==============================] - 1s 518us/step - loss: 1.2989 - mse: 1.2989 - val_loss: 0.8687 - val_mse: 0.8687
#
# Epoch 00010: val_loss improved from 0.86898 to 0.86873, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 11/100
# 1619/1619 [==============================] - 1s 526us/step - loss: 1.2981 - mse: 1.2981 - val_loss: 0.8718 - val_mse: 0.8718
#
# Epoch 00011: val_loss did not improve from 0.86873
# Epoch 12/100
# 1619/1619 [==============================] - 1s 517us/step - loss: 1.2971 - mse: 1.2971 - val_loss: 0.8703 - val_mse: 0.8703
#
# Epoch 00012: val_loss did not improve from 0.86873
# Epoch 13/100
# 1619/1619 [==============================] - 1s 529us/step - loss: 1.2971 - mse: 1.2971 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00013: val_loss did not improve from 0.86873
# Epoch 14/100
# 1619/1619 [==============================] - 1s 519us/step - loss: 1.2970 - mse: 1.2970 - val_loss: 0.8714 - val_mse: 0.8714
#
# Epoch 00014: val_loss did not improve from 0.86873
# Epoch 15/100
# 1619/1619 [==============================] - 1s 519us/step - loss: 1.2964 - mse: 1.2964 - val_loss: 0.8702 - val_mse: 0.8702
#
# Epoch 00015: val_loss did not improve from 0.86873
# Epoch 16/100
# 1619/1619 [==============================] - 1s 518us/step - loss: 1.2957 - mse: 1.2957 - val_loss: 0.8700 - val_mse: 0.8700
#
# Epoch 00016: val_loss did not improve from 0.86873
# Epoch 17/100
# 1619/1619 [==============================] - 1s 519us/step - loss: 1.2830 - mse: 1.2830 - val_loss: 0.8739 - val_mse: 0.8739
#
# Epoch 00017: val_loss did not improve from 0.86873
# Epoch 18/100
# 1619/1619 [==============================] - 1s 522us/step - loss: 1.2459 - mse: 1.2459 - val_loss: 0.8273 - val_mse: 0.8273
#
# Epoch 00018: val_loss improved from 0.86873 to 0.82729, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 19/100
# 1619/1619 [==============================] - 1s 521us/step - loss: 1.1976 - mse: 1.1976 - val_loss: 0.6957 - val_mse: 0.6957
#
# Epoch 00019: val_loss improved from 0.82729 to 0.69575, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 20/100
# 1619/1619 [==============================] - 1s 509us/step - loss: 1.1214 - mse: 1.1214 - val_loss: 0.6340 - val_mse: 0.6340
#
# Epoch 00020: val_loss improved from 0.69575 to 0.63400, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 21/100
# 1619/1619 [==============================] - 1s 513us/step - loss: 1.0612 - mse: 1.0612 - val_loss: 0.5707 - val_mse: 0.5707
#
# Epoch 00021: val_loss improved from 0.63400 to 0.57071, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 22/100
# 1619/1619 [==============================] - 1s 513us/step - loss: 1.0156 - mse: 1.0156 - val_loss: 0.5949 - val_mse: 0.5949
#
# Epoch 00022: val_loss did not improve from 0.57071
# Epoch 23/100
# 1619/1619 [==============================] - 1s 514us/step - loss: 0.9897 - mse: 0.9897 - val_loss: 0.4992 - val_mse: 0.4992
#
# Epoch 00023: val_loss improved from 0.57071 to 0.49923, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 24/100
# 1619/1619 [==============================] - 1s 520us/step - loss: 0.9538 - mse: 0.9538 - val_loss: 0.4778 - val_mse: 0.4778
#
# Epoch 00024: val_loss improved from 0.49923 to 0.47775, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 25/100
# 1619/1619 [==============================] - 1s 519us/step - loss: 0.9311 - mse: 0.9311 - val_loss: 0.4555 - val_mse: 0.4555
#
# Epoch 00025: val_loss improved from 0.47775 to 0.45549, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 26/100
# 1619/1619 [==============================] - 1s 516us/step - loss: 0.9157 - mse: 0.9157 - val_loss: 0.4526 - val_mse: 0.4526
#
# Epoch 00026: val_loss improved from 0.45549 to 0.45260, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 27/100
# 1619/1619 [==============================] - 1s 521us/step - loss: 0.9060 - mse: 0.9060 - val_loss: 0.4508 - val_mse: 0.4508
#
# Epoch 00027: val_loss improved from 0.45260 to 0.45081, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 28/100
# 1619/1619 [==============================] - 1s 522us/step - loss: 0.9001 - mse: 0.9001 - val_loss: 0.4469 - val_mse: 0.4469
#
# Epoch 00028: val_loss improved from 0.45081 to 0.44688, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 29/100
# 1619/1619 [==============================] - 1s 516us/step - loss: 0.8968 - mse: 0.8968 - val_loss: 0.4516 - val_mse: 0.4516
#
# Epoch 00029: val_loss did not improve from 0.44688
# Epoch 30/100
# 1619/1619 [==============================] - 1s 520us/step - loss: 0.8955 - mse: 0.8955 - val_loss: 0.4532 - val_mse: 0.4532
#
# Epoch 00030: val_loss did not improve from 0.44688
# Epoch 31/100
# 1619/1619 [==============================] - 1s 518us/step - loss: 0.8938 - mse: 0.8938 - val_loss: 0.4640 - val_mse: 0.4640
#
# Epoch 00031: val_loss did not improve from 0.44688
# Epoch 32/100
# 1619/1619 [==============================] - 1s 498us/step - loss: 0.8932 - mse: 0.8932 - val_loss: 0.4593 - val_mse: 0.4593
#
# Epoch 00032: val_loss did not improve from 0.44688
# Epoch 33/100
# 1619/1619 [==============================] - 1s 517us/step - loss: 0.8919 - mse: 0.8919 - val_loss: 0.4561 - val_mse: 0.4561
#
# Epoch 00033: val_loss did not improve from 0.44688
# Epoch 34/100
# 1619/1619 [==============================] - 1s 508us/step - loss: 0.8912 - mse: 0.8912 - val_loss: 0.4614 - val_mse: 0.4614
#
# Epoch 00034: val_loss did not improve from 0.44688
# Epoch 35/100
# 1619/1619 [==============================] - 1s 505us/step - loss: 0.8934 - mse: 0.8934 - val_loss: 0.4551 - val_mse: 0.4551
#
# Epoch 00035: val_loss did not improve from 0.44688
# Epoch 36/100
# 1619/1619 [==============================] - 1s 516us/step - loss: 0.8920 - mse: 0.8920 - val_loss: 0.4615 - val_mse: 0.4615
#
# Epoch 00036: val_loss did not improve from 0.44688
# Epoch 37/100
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.8912 - mse: 0.8912 - val_loss: 0.4714 - val_mse: 0.4714
#
# Epoch 00037: val_loss did not improve from 0.44688
# Epoch 38/100
# 1619/1619 [==============================] - 1s 506us/step - loss: 0.8902 - mse: 0.8902 - val_loss: 0.4777 - val_mse: 0.4777
#
# Epoch 00038: val_loss did not improve from 0.44688
# Epoch 39/100
# 1619/1619 [==============================] - 1s 512us/step - loss: 0.8918 - mse: 0.8918 - val_loss: 0.4683 - val_mse: 0.4683
#
# Epoch 00039: val_loss did not improve from 0.44688
# Epoch 40/100
# 1619/1619 [==============================] - 1s 512us/step - loss: 0.8917 - mse: 0.8917 - val_loss: 0.4727 - val_mse: 0.4727
#
# Epoch 00040: val_loss did not improve from 0.44688
# Epoch 41/100
# 1619/1619 [==============================] - 1s 507us/step - loss: 0.8906 - mse: 0.8906 - val_loss: 0.4729 - val_mse: 0.4729
#
# Epoch 00041: val_loss did not improve from 0.44688
# Epoch 42/100
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.8904 - mse: 0.8904 - val_loss: 0.4714 - val_mse: 0.4714
#
# Epoch 00042: val_loss did not improve from 0.44688
# Epoch 43/100
# 1619/1619 [==============================] - 1s 512us/step - loss: 0.8887 - mse: 0.8887 - val_loss: 0.4674 - val_mse: 0.4674
#
# Epoch 00043: val_loss did not improve from 0.44688
# Epoch 00043: early stopping
# Best: -1.128869 using {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'tanh', 'filters': (150, 75), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 47.832391
# -1.208000 (1.142695) with: {'activation': 'tanh', 'filters': (120, 50), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 86.003367
# -1.228094 (1.090350) with: {'activation': 'tanh', 'filters': (100, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 99.585655
# -1.128869 (1.048420) with: {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 50, 'numberOfLstmLayers': 2, 'poolSize': 2, 'pred_horizon': 480}, fitted in 81.894666
# *** Model fitted ***
# training cnn took  343.4194390773773

# %%
paramNumberOfHiddenConvPoolLayers = [2]
paramFilters = [(150,40)]# tuples instead of 2d array [[],[]] because of a bug: https://github.com/keras-team/keras/issues/13586
paramKernelSize = [2]
paramPoolSize = [2]
paramActivation = ["tanh"]
paramNumberOfLstmLayers = [1]
paramNumberOfLstmCells = [75]
paramLstmActivation = ["tanh"]
paramHistory = [n_history]
paramPredHorizon = [pred_horizon]
paramNumberOfFeatrues = [numberOfFeatures]
paramDict = dict(numberOfHiddenConvPoolLayers = paramNumberOfHiddenConvPoolLayers, filters=paramFilters, kernelSize = paramKernelSize,
                poolSize = paramPoolSize, activation=paramActivation,
                numberOfLstmLayers = paramNumberOfLstmLayers, numberOfLstmCells=paramNumberOfLstmCells, lstmActivation=paramLstmActivation,
                n_history = paramHistory, pred_horizon = paramPredHorizon, numberOfFeatures = paramNumberOfFeatrues)
# Grid Search for: number of lstm layers/cells/activation . Best: 1 layer, 75 cells, tanh
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history, paramDict = paramDict)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/100
# 1619/1619 [==============================] - 1s 652us/step - loss: 1.3056 - mse: 1.3056 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86961, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 2/100
# 1619/1619 [==============================] - 1s 492us/step - loss: 1.3031 - mse: 1.3031 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00002: val_loss improved from 0.86961 to 0.86959, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 3/100
# 1619/1619 [==============================] - 1s 391us/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00003: val_loss did not improve from 0.86959
# Epoch 4/100
# 1619/1619 [==============================] - 1s 387us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00004: val_loss did not improve from 0.86959
# Epoch 5/100
# 1619/1619 [==============================] - 1s 515us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00005: val_loss did not improve from 0.86959
# Epoch 6/100
# 1619/1619 [==============================] - 1s 470us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00006: val_loss did not improve from 0.86959
# Epoch 7/100
# 1619/1619 [==============================] - 1s 402us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00007: val_loss did not improve from 0.86959
# Epoch 8/100
# 1619/1619 [==============================] - 1s 479us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8699 - val_mse: 0.8699
#
# Epoch 00008: val_loss did not improve from 0.86959
# Epoch 9/100
# 1619/1619 [==============================] - 1s 410us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00009: val_loss did not improve from 0.86959
# Epoch 10/100
# 1619/1619 [==============================] - 1s 400us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00010: val_loss did not improve from 0.86959
# Epoch 11/100
# 1619/1619 [==============================] - 1s 388us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8697 - val_mse: 0.8697
#
# Epoch 00011: val_loss did not improve from 0.86959
# Epoch 12/100
# 1619/1619 [==============================] - 1s 398us/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00012: val_loss did not improve from 0.86959
# Epoch 13/100
# 1619/1619 [==============================] - 1s 398us/step - loss: 1.2981 - mse: 1.2981 - val_loss: 0.8512 - val_mse: 0.8512
#
# Epoch 00013: val_loss improved from 0.86959 to 0.85116, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 14/100
# 1619/1619 [==============================] - 1s 472us/step - loss: 1.2803 - mse: 1.2803 - val_loss: 0.8047 - val_mse: 0.8047
#
# Epoch 00014: val_loss improved from 0.85116 to 0.80468, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 15/100
# 1619/1619 [==============================] - 1s 410us/step - loss: 1.2642 - mse: 1.2642 - val_loss: 0.8275 - val_mse: 0.8275
#
# Epoch 00015: val_loss did not improve from 0.80468
# Epoch 16/100
# 1619/1619 [==============================] - 1s 451us/step - loss: 1.2405 - mse: 1.2405 - val_loss: 0.7574 - val_mse: 0.7574
#
# Epoch 00016: val_loss improved from 0.80468 to 0.75741, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 17/100
# 1619/1619 [==============================] - 1s 376us/step - loss: 1.2023 - mse: 1.2023 - val_loss: 0.6921 - val_mse: 0.6921
#
# Epoch 00017: val_loss improved from 0.75741 to 0.69215, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 18/100
# 1619/1619 [==============================] - 1s 409us/step - loss: 1.1487 - mse: 1.1487 - val_loss: 0.6726 - val_mse: 0.6726
#
# Epoch 00018: val_loss improved from 0.69215 to 0.67261, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 19/100
# 1619/1619 [==============================] - 1s 413us/step - loss: 1.1185 - mse: 1.1185 - val_loss: 0.6541 - val_mse: 0.6541
#
# Epoch 00019: val_loss improved from 0.67261 to 0.65405, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 20/100
# 1619/1619 [==============================] - 1s 387us/step - loss: 1.1000 - mse: 1.1000 - val_loss: 0.5968 - val_mse: 0.5968
#
# Epoch 00020: val_loss improved from 0.65405 to 0.59677, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 21/100
# 1619/1619 [==============================] - 1s 411us/step - loss: 1.0538 - mse: 1.0538 - val_loss: 0.5344 - val_mse: 0.5344
#
# Epoch 00021: val_loss improved from 0.59677 to 0.53440, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 22/100
# 1619/1619 [==============================] - 1s 490us/step - loss: 0.9784 - mse: 0.9784 - val_loss: 0.4777 - val_mse: 0.4777
#
# Epoch 00022: val_loss improved from 0.53440 to 0.47767, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 23/100
# 1619/1619 [==============================] - 1s 377us/step - loss: 0.9264 - mse: 0.9264 - val_loss: 0.4666 - val_mse: 0.4666
#
# Epoch 00023: val_loss improved from 0.47767 to 0.46661, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 24/100
# 1619/1619 [==============================] - 1s 372us/step - loss: 0.9024 - mse: 0.9024 - val_loss: 0.4337 - val_mse: 0.4337
#
# Epoch 00024: val_loss improved from 0.46661 to 0.43372, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 25/100
# 1619/1619 [==============================] - 1s 375us/step - loss: 0.8966 - mse: 0.8966 - val_loss: 0.4553 - val_mse: 0.4553
#
# Epoch 00025: val_loss did not improve from 0.43372
# Epoch 26/100
# 1619/1619 [==============================] - 1s 383us/step - loss: 0.8929 - mse: 0.8929 - val_loss: 0.4694 - val_mse: 0.4694
#
# Epoch 00026: val_loss did not improve from 0.43372
# Epoch 27/100
# 1619/1619 [==============================] - 1s 375us/step - loss: 0.8941 - mse: 0.8941 - val_loss: 0.4452 - val_mse: 0.4452
#
# Epoch 00027: val_loss did not improve from 0.43372
# Epoch 28/100
# 1619/1619 [==============================] - 1s 427us/step - loss: 0.8901 - mse: 0.8901 - val_loss: 0.4706 - val_mse: 0.4706
#
# Epoch 00028: val_loss did not improve from 0.43372
# Epoch 29/100
# 1619/1619 [==============================] - 1s 427us/step - loss: 0.8866 - mse: 0.8866 - val_loss: 0.4334 - val_mse: 0.4334
#
# Epoch 00029: val_loss improved from 0.43372 to 0.43341, saving model to grid_cnn_multistep_multivariate.h5
# Epoch 30/100
# 1619/1619 [==============================] - 1s 406us/step - loss: 0.8855 - mse: 0.8855 - val_loss: 0.4899 - val_mse: 0.4899
#
# Epoch 00030: val_loss did not improve from 0.43341
# Epoch 31/100
# 1619/1619 [==============================] - 1s 422us/step - loss: 0.8844 - mse: 0.8844 - val_loss: 0.4593 - val_mse: 0.4593
#
# Epoch 00031: val_loss did not improve from 0.43341
# Epoch 32/100
# 1619/1619 [==============================] - 1s 435us/step - loss: 0.8896 - mse: 0.8896 - val_loss: 0.4765 - val_mse: 0.4765
#
# Epoch 00032: val_loss did not improve from 0.43341
# Epoch 33/100
# 1619/1619 [==============================] - 1s 436us/step - loss: 0.8828 - mse: 0.8828 - val_loss: 0.4592 - val_mse: 0.4592
#
# Epoch 00033: val_loss did not improve from 0.43341
# Epoch 34/100
# 1619/1619 [==============================] - 1s 467us/step - loss: 0.8801 - mse: 0.8801 - val_loss: 0.4986 - val_mse: 0.4986
#
# Epoch 00034: val_loss did not improve from 0.43341
# Epoch 35/100
# 1619/1619 [==============================] - 1s 463us/step - loss: 0.8746 - mse: 0.8746 - val_loss: 0.4887 - val_mse: 0.4887
#
# Epoch 00035: val_loss did not improve from 0.43341
# Epoch 36/100
# 1619/1619 [==============================] - 1s 503us/step - loss: 0.8723 - mse: 0.8723 - val_loss: 0.4933 - val_mse: 0.4933
#
# Epoch 00036: val_loss did not improve from 0.43341
# Epoch 37/100
# 1619/1619 [==============================] - 1s 475us/step - loss: 0.8670 - mse: 0.8670 - val_loss: 0.5296 - val_mse: 0.5296
#
# Epoch 00037: val_loss did not improve from 0.43341
# Epoch 38/100
# 1619/1619 [==============================] - 1s 470us/step - loss: 0.8858 - mse: 0.8858 - val_loss: 0.4505 - val_mse: 0.4505
#
# Epoch 00038: val_loss did not improve from 0.43341
# Epoch 39/100
# 1619/1619 [==============================] - 1s 487us/step - loss: 0.8679 - mse: 0.8679 - val_loss: 0.4794 - val_mse: 0.4794
#
# Epoch 00039: val_loss did not improve from 0.43341
# Epoch 40/100
# 1619/1619 [==============================] - 1s 477us/step - loss: 0.8639 - mse: 0.8639 - val_loss: 0.5023 - val_mse: 0.5023
#
# Epoch 00040: val_loss did not improve from 0.43341
# Epoch 41/100
# 1619/1619 [==============================] - 1s 477us/step - loss: 0.8608 - mse: 0.8608 - val_loss: 0.5247 - val_mse: 0.5247
#
# Epoch 00041: val_loss did not improve from 0.43341
# Epoch 42/100
# 1619/1619 [==============================] - 1s 422us/step - loss: 0.8569 - mse: 0.8569 - val_loss: 0.4926 - val_mse: 0.4926
#
# Epoch 00042: val_loss did not improve from 0.43341
# Epoch 43/100
# 1619/1619 [==============================] - 1s 409us/step - loss: 0.8525 - mse: 0.8525 - val_loss: 0.5087 - val_mse: 0.5087
#
# Epoch 00043: val_loss did not improve from 0.43341
# Epoch 44/100
# 1619/1619 [==============================] - 1s 411us/step - loss: 0.8499 - mse: 0.8499 - val_loss: 0.4990 - val_mse: 0.4990
#
# Epoch 00044: val_loss did not improve from 0.43341
# Epoch 00044: early stopping
# Best: nan using {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}
# grid.cv_results_
#
#
# {'mean_fit_time': array([28.25241723, 54.43998699]), 'std_fit_time': array([22.52725407, 28.07934513]), 'mean_score_time': array([0.03866024, 0.06583261]), 'std_score_time': array([0.04824319, 0.03782184]), 'param_activation': masked_array(data=['tanh', 'tanh'],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_filters': masked_array(data=[(150, 40), (150, 40)],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_kernelSize': masked_array(data=[2, 3],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_lstmActivation': masked_array(data=['tanh', 'tanh'],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_n_history': masked_array(data=[32, 32],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_numberOfFeatures': masked_array(data=[61, 61],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_numberOfHiddenConvPoolLayers': masked_array(data=[2, 2],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_numberOfLstmCells': masked_array(data=[75, 75],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_numberOfLstmLayers': masked_array(data=[1, 1],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_poolSize': masked_array(data=[2, 2],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'param_pred_horizon': masked_array(data=[480, 480],
#              mask=[False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}, {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 3, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}], 'split0_test_score': array([        nan, -0.41073605]), 'split1_test_score': array([-0.01839703,         nan]), 'split2_test_score': array([        nan, -0.42596774]), 'split3_test_score': array([        nan, -2.99942806]), 'split4_test_score': array([-1.21311163, -1.18007446]), 'mean_test_score': array([nan, nan]), 'std_test_score': array([nan, nan]), 'rank_test_score': array([1, 2])}
# grid.best_estimator
#
#
# <keras.wrappers.scikit_learn.KerasRegressor object at 0x000001DAC51D6988>
# grid.best_params
#
#
# {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}
# nan (nan) with: {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 2, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}, fitted in 28.252417
# nan (nan) with: {'activation': 'tanh', 'filters': (150, 40), 'kernelSize': 3, 'lstmActivation': 'tanh', 'n_history': 32, 'numberOfFeatures': 61, 'numberOfHiddenConvPoolLayers': 2, 'numberOfLstmCells': 75, 'numberOfLstmLayers': 1, 'poolSize': 2, 'pred_horizon': 480}, fitted in 54.439987
# *** Model fitted ***
# training cnn took  135.39828610420227
