# %%
import pandas as pd
import numpy as np
import pickle
import time

from numpy import array
from datetime import timedelta  
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from fbprophet import Prophet
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from pmdarima import auto_arima
from datetime import timedelta 

import plotly
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode
# Out:
# Using TensorFlow backend.

# %%
timestamp = "timestamp"
predictionColumn = "cpuusage_ps"

# %%
def plot_real_data_train(df, n_history):
    data = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    data.columns = ['date','Train Data']
    data.set_index('date', inplace=True)
    return data

def plot_real_data_test(df, pred_horizon):
    data = df.reset_index()[[timestamp, predictionColumn]]
    data = data.tail(pred_horizon)
    data.columns = ['date','Test Data']
    data.set_index('date', inplace=True)
    return data

# %%
plotly.offline.init_notebook_mode(connected=True)

def plot_data(df, plotTitle):
    map_plotly_series = dict()
    for columnName in df.columns:
        s = go.Scatter(
            x=df.index,
            y=df[columnName],
            name = columnName,
            hoverinfo='none',
            opacity = 0.8)
        map_plotly_series[columnName] = s
    data = list(map_plotly_series.values())
    layout = dict(
        title = plotTitle,
        xaxis = dict(
            range = [df.index.min(),df.index.max()])
    )
    fig = dict(data=data, layout=layout)
    plotly.offline.plot(fig, filename = plotTitle + '.html')
    return None
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def generate_index_forecast(df, df_forecast, pred_horizon):
    minutesBetweenMeasures = 15
    temp = df.reset_index()[[timestamp]]
    lastTrainDataTimeStamp = temp.tail(pred_horizon)[timestamp].iloc[0]
    nextTimeStamp = lastTrainDataTimeStamp
    for i in df_forecast.index:
        nextTimeStamp = nextTimeStamp + timedelta(minutes=minutesBetweenMeasures)
        df_forecast.at[i, 'date'] = nextTimeStamp
    df_forecast.set_index('date', inplace=True)
    return df_forecast

# %%
# split a multivariate sequence into samples
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
def lstm_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def lstm_split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

def train_lstm(df, n_history, pred_horizon):
    # data split / preprocessing
    x, y, scalerX, scalerY = lstm_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("lstm_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)

    # model definition
    model = Sequential()
    model.add(LSTM(75, activation='tanh', return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    mc = ModelCheckpoint('lstm_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    # model train
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc])
    print('''*** Model fitted ***''')
    return None

def forecast_lstm(df, n_history, pred_horizon):
    model = load_model('lstm_multistep_multivariate.h5')
    with(open("lstm_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1]
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['LSTM Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def mlp_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
         
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_mlp(df, n_history, pred_horizon):
    x, y, scalerX, scalerY = mlp_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    n_input = x_train.shape[1] * x_train.shape[2]
    x_train = x_train.reshape((x_train.shape[0], n_input))
    n_neurons = int((n_input + pred_horizon)/2)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("mlp_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = Sequential()
    model.add(Dense(n_neurons, activation='tanh', input_dim=n_input))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=30)
    mc = ModelCheckpoint('mlp_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)    
    model.fit(x_train, y_train, validation_split=0.1, epochs=200, callbacks=[es, mc])
    return None

def forecast_mlp(df, n_history, pred_horizon):
    model_mlp = load_model('mlp_multistep_multivariate.h5')
    with(open("mlp_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)

    numberOfFeatures =  x_train.shape[1] // n_history # was reshaped to featureNumber * n_history, so divide it to get number of features = 61
    pred_input = x_train[-1:]
    n_input = pred_input.shape[0] * pred_input.shape[1]
    pred_input = pred_input.reshape((1,n_input))
    
    prediction = model_mlp.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['MLP Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def cnn_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def train_cnn(df, pred_horizon, n_history):
    x, y, scalerX, scalerY = cnn_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("lstm_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = Sequential()
    model.add(Conv1D(filters=75, kernel_size=3, activation='relu', input_shape=(n_history, numberOfFeatures)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=38, kernel_size=3, activation='relu'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(LSTM(100, activation='tanh',return_sequences=True))
    model.add(LSTM(50, activation='tanh'))
    model.add(Dense(pred_horizon))
    model.compile(loss='mse', optimizer='adam')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=100)
    mc = ModelCheckpoint('cnn_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc])
    print('''*** Model fitted ***''') 
    return None

def forecast_cnn(df, n_history, pred_horizon):
    model = load_model('cnn_multistep_multivariate.h5')
    with(open("lstm_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1] 
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['CNN Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def train_fbprophet_additiv(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_additiv.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return None

def train_fbprophet_boxcox(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    train["y"] = pd.to_numeric(train["y"])
    train['y'], lam = boxcox(train['y'])
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_boxcox.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return lam

def forecast_fbprophet_additiv(pred_horizon):
    with open('fbprophet_additiv.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet = m.predict(future)[['ds', 'yhat']]
    forecast_prophet.columns = ['date','FBProphet without Box-Cox-Transform']
    forecast_prophet.set_index('date', inplace=True)
    return forecast_prophet.tail(pred_horizon) 

def forecast_fbprophet_boxcox(pred_horizon, lam):
    with open('fbprophet_boxcox.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet_box_cox = m.predict(future)[['ds', 'yhat']]
    forecast_prophet_box_cox['yhat'] = forecast_prophet_box_cox['yhat'].apply(lambda x: inv_boxcox(x, lam))
    forecast_prophet_box_cox.columns = ['date','FBProphet with Box-Cox-Transform']
    forecast_prophet_box_cox.set_index('date', inplace=True)
    return forecast_prophet_box_cox.tail(pred_horizon)

# %%
# Declaration
skip_csv_rows = 0
measureInterval = 15 #min
daysToPredict = 5
pred_horizon = (60//measureInterval) * 24 * daysToPredict #5 days (4*24*5), timestep = 15min
hours_history = 8
n_history = (60//measureInterval)*hours_history 

# Read data from pickle file
with open("./4week_transformed_droppedErrors_filled.pkl", "rb") as pickleFile:
    df = pickle.load(pickleFile)

# %%
df = df.reset_index()

# %%
df[predictionColumn] = pd.to_numeric(df[predictionColumn])

# %%
starttime = time.time()
train_fbprophet_additiv(df, pred_horizon)
print("training prophet without boxcox took ", time.time() - starttime)
starttime = time.time()
fbprophet_boxcox_lam = train_fbprophet_boxcox(df, pred_horizon)
print("training prophet with boxcox took ", time.time() - starttime)
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# training prophet without boxcox took  1.2464666366577148
# training prophet with boxcox took  1.0063886642456055

# %%
starttime = time.time()
train_lstm(df.copy().reset_index(), n_history=n_history, pred_horizon=pred_horizon)
print("training lstm took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 4s 2ms/step - loss: 1.3040 - mse: 1.3040 - val_loss: 0.8696 - val_mse: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86957, saving model to lstm_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3029 - mse: 1.3029 - val_loss: 0.8688 - val_mse: 0.8688
#
# Epoch 00002: val_loss improved from 0.86957 to 0.86881, saving model to lstm_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2999 - mse: 1.2999 - val_loss: 0.8722 - val_mse: 0.8722
#
# Epoch 00003: val_loss did not improve from 0.86881
# Epoch 4/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2980 - mse: 1.2980 - val_loss: 0.8738 - val_mse: 0.8738
#
# Epoch 00004: val_loss did not improve from 0.86881
# Epoch 5/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2971 - mse: 1.2971 - val_loss: 0.8717 - val_mse: 0.8717
#
# Epoch 00005: val_loss did not improve from 0.86881
# Epoch 6/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2880 - mse: 1.2880 - val_loss: 0.8538 - val_mse: 0.8538
#
# Epoch 00006: val_loss improved from 0.86881 to 0.85376, saving model to lstm_multistep_multivariate.h5
# Epoch 7/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2505 - mse: 1.2505 - val_loss: 0.7953 - val_mse: 0.7953
#
# Epoch 00007: val_loss improved from 0.85376 to 0.79528, saving model to lstm_multistep_multivariate.h5
# Epoch 8/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2014 - mse: 1.2014 - val_loss: 0.7343 - val_mse: 0.7343
#
# Epoch 00008: val_loss improved from 0.79528 to 0.73432, saving model to lstm_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.1490 - mse: 1.1490 - val_loss: 0.6907 - val_mse: 0.6907
#
# Epoch 00009: val_loss improved from 0.73432 to 0.69066, saving model to lstm_multistep_multivariate.h5
# Epoch 10/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.1097 - mse: 1.1097 - val_loss: 0.6692 - val_mse: 0.6692
#
# Epoch 00010: val_loss improved from 0.69066 to 0.66922, saving model to lstm_multistep_multivariate.h5
# Epoch 11/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.0680 - mse: 1.0680 - val_loss: 0.6259 - val_mse: 0.6259
#
# Epoch 00011: val_loss improved from 0.66922 to 0.62593, saving model to lstm_multistep_multivariate.h5
# Epoch 12/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.0308 - mse: 1.0308 - val_loss: 0.5388 - val_mse: 0.5388
#
# Epoch 00012: val_loss improved from 0.62593 to 0.53879, saving model to lstm_multistep_multivariate.h5
# Epoch 13/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9996 - mse: 0.9996 - val_loss: 0.5635 - val_mse: 0.5635
#
# Epoch 00013: val_loss did not improve from 0.53879
# Epoch 14/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9690 - mse: 0.9690 - val_loss: 0.5405 - val_mse: 0.5405
#
# Epoch 00014: val_loss did not improve from 0.53879
# Epoch 15/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.0932 - mse: 1.0932 - val_loss: 0.8461 - val_mse: 0.8461
#
# Epoch 00015: val_loss did not improve from 0.53879
# Epoch 16/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9821 - mse: 0.9821 - val_loss: 0.5255 - val_mse: 0.5255
#
# Epoch 00016: val_loss improved from 0.53879 to 0.52555, saving model to lstm_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9316 - mse: 0.9316 - val_loss: 0.5006 - val_mse: 0.5006
#
# Epoch 00017: val_loss improved from 0.52555 to 0.50062, saving model to lstm_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9150 - mse: 0.9150 - val_loss: 0.5033 - val_mse: 0.5033
#
# Epoch 00018: val_loss did not improve from 0.50062
# Epoch 19/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9036 - mse: 0.9036 - val_loss: 0.4838 - val_mse: 0.4838
#
# Epoch 00019: val_loss improved from 0.50062 to 0.48377, saving model to lstm_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8956 - mse: 0.8956 - val_loss: 0.4728 - val_mse: 0.4728
#
# Epoch 00020: val_loss improved from 0.48377 to 0.47283, saving model to lstm_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8943 - mse: 0.8943 - val_loss: 0.4830 - val_mse: 0.4830
#
# Epoch 00021: val_loss did not improve from 0.47283
# Epoch 22/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8853 - mse: 0.8853 - val_loss: 0.4809 - val_mse: 0.4809
#
# Epoch 00022: val_loss did not improve from 0.47283
# Epoch 23/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9342 - mse: 0.9342 - val_loss: 1.0254 - val_mse: 1.0254
#
# Epoch 00023: val_loss did not improve from 0.47283
# Epoch 24/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.3129 - mse: 1.3129 - val_loss: 0.8496 - val_mse: 0.8496
#
# Epoch 00024: val_loss did not improve from 0.47283
# Epoch 25/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.2430 - mse: 1.2430 - val_loss: 0.8982 - val_mse: 0.8982
#
# Epoch 00025: val_loss did not improve from 0.47283
# Epoch 26/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 1.1738 - mse: 1.1738 - val_loss: 0.4728 - val_mse: 0.4728
#
# Epoch 00026: val_loss improved from 0.47283 to 0.47276, saving model to lstm_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9455 - mse: 0.9455 - val_loss: 0.4076 - val_mse: 0.4076
#
# Epoch 00027: val_loss improved from 0.47276 to 0.40765, saving model to lstm_multistep_multivariate.h5
# Epoch 28/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9172 - mse: 0.9172 - val_loss: 0.4016 - val_mse: 0.4016
#
# Epoch 00028: val_loss improved from 0.40765 to 0.40165, saving model to lstm_multistep_multivariate.h5
# Epoch 29/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9125 - mse: 0.9125 - val_loss: 0.4023 - val_mse: 0.4023
#
# Epoch 00029: val_loss did not improve from 0.40165
# Epoch 30/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9092 - mse: 0.9092 - val_loss: 0.4088 - val_mse: 0.4088
#
# Epoch 00030: val_loss did not improve from 0.40165
# Epoch 31/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9050 - mse: 0.9050 - val_loss: 0.4395 - val_mse: 0.4395
#
# Epoch 00031: val_loss did not improve from 0.40165
# Epoch 32/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.9041 - mse: 0.9041 - val_loss: 0.4358 - val_mse: 0.4358
#
# Epoch 00032: val_loss did not improve from 0.40165
# Epoch 33/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8993 - mse: 0.8993 - val_loss: 0.4424 - val_mse: 0.4424
#
# Epoch 00033: val_loss did not improve from 0.40165
# Epoch 34/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8980 - mse: 0.8980 - val_loss: 0.4111 - val_mse: 0.4111
#
# Epoch 00034: val_loss did not improve from 0.40165
# Epoch 35/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8944 - mse: 0.8944 - val_loss: 0.4719 - val_mse: 0.4719
#
# Epoch 00035: val_loss did not improve from 0.40165
# Epoch 36/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8912 - mse: 0.8912 - val_loss: 0.4870 - val_mse: 0.4870
#
# Epoch 00036: val_loss did not improve from 0.40165
# Epoch 37/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8874 - mse: 0.8874 - val_loss: 0.4683 - val_mse: 0.4683
#
# Epoch 00037: val_loss did not improve from 0.40165
# Epoch 38/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8939 - mse: 0.8939 - val_loss: 0.4589 - val_mse: 0.4589
#
# Epoch 00038: val_loss did not improve from 0.40165
# Epoch 39/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8845 - mse: 0.8845 - val_loss: 0.4923 - val_mse: 0.4923
#
# Epoch 00039: val_loss did not improve from 0.40165
# Epoch 40/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8855 - mse: 0.8855 - val_loss: 0.4968 - val_mse: 0.4968
#
# Epoch 00040: val_loss did not improve from 0.40165
# Epoch 41/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8787 - mse: 0.8787 - val_loss: 0.5062 - val_mse: 0.5062
#
# Epoch 00041: val_loss did not improve from 0.40165
# Epoch 42/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8764 - mse: 0.8764 - val_loss: 0.5089 - val_mse: 0.5089
#
# Epoch 00042: val_loss did not improve from 0.40165
# Epoch 43/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8764 - mse: 0.8764 - val_loss: 0.5030 - val_mse: 0.5030
#
# Epoch 00043: val_loss did not improve from 0.40165
# Epoch 44/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8733 - mse: 0.8733 - val_loss: 0.4947 - val_mse: 0.4947
#
# Epoch 00044: val_loss did not improve from 0.40165
# Epoch 45/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8706 - mse: 0.8706 - val_loss: 0.5138 - val_mse: 0.5138
#
# Epoch 00045: val_loss did not improve from 0.40165
# Epoch 46/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8723 - mse: 0.8723 - val_loss: 0.5071 - val_mse: 0.5071
#
# Epoch 00046: val_loss did not improve from 0.40165
# Epoch 47/200
# 1619/1619 [==============================] - 3s 2ms/step - loss: 0.8675 - mse: 0.8675 - val_loss: 0.5155 - val_mse: 0.5155
#
# Epoch 00047: val_loss did not improve from 0.40165
# Epoch 48/200
# 1619/1619 [==============================] - 4s 2ms/step - loss: 0.8651 - mse: 0.8651 - val_loss: 0.5471 - val_mse: 0.5471
#
# Epoch 00048: val_loss did not improve from 0.40165
# Epoch 00048: early stopping
# *** Model fitted ***
# training lstm took  162.01970958709717

# %%
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.4461 - val_loss: 0.9717
#
# Epoch 00001: val_loss improved from inf to 0.97174, saving model to mlp_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3926 - val_loss: 0.9638
#
# Epoch 00002: val_loss improved from 0.97174 to 0.96377, saving model to mlp_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3915 - val_loss: 0.9678
#
# Epoch 00003: val_loss did not improve from 0.96377
# Epoch 4/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3914 - val_loss: 0.9628
#
# Epoch 00004: val_loss improved from 0.96377 to 0.96280, saving model to mlp_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3881 - val_loss: 0.9534
#
# Epoch 00005: val_loss improved from 0.96280 to 0.95345, saving model to mlp_multistep_multivariate.h5
# Epoch 6/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3881 - val_loss: 0.9548
#
# Epoch 00006: val_loss did not improve from 0.95345
# Epoch 7/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3895 - val_loss: 0.9559
#
# Epoch 00007: val_loss did not improve from 0.95345
# Epoch 8/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3816 - val_loss: 0.9714
#
# Epoch 00008: val_loss did not improve from 0.95345
# Epoch 9/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3872 - val_loss: 0.9493
#
# Epoch 00009: val_loss improved from 0.95345 to 0.94929, saving model to mlp_multistep_multivariate.h5
# Epoch 10/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3769 - val_loss: 0.9405
#
# Epoch 00010: val_loss improved from 0.94929 to 0.94045, saving model to mlp_multistep_multivariate.h5
# Epoch 11/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3807 - val_loss: 0.9583
#
# Epoch 00011: val_loss did not improve from 0.94045
# Epoch 12/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3818 - val_loss: 0.9405
#
# Epoch 00012: val_loss did not improve from 0.94045
# Epoch 13/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3865 - val_loss: 0.9420
#
# Epoch 00013: val_loss did not improve from 0.94045
# Epoch 14/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3888 - val_loss: 0.9608
#
# Epoch 00014: val_loss did not improve from 0.94045
# Epoch 15/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3870 - val_loss: 0.9452
#
# Epoch 00015: val_loss did not improve from 0.94045
# Epoch 16/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3788 - val_loss: 0.9382
#
# Epoch 00016: val_loss improved from 0.94045 to 0.93821, saving model to mlp_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3807 - val_loss: 0.9648
#
# Epoch 00017: val_loss did not improve from 0.93821
# Epoch 18/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3781 - val_loss: 0.9421
#
# Epoch 00018: val_loss did not improve from 0.93821
# Epoch 19/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3836 - val_loss: 0.9585
#
# Epoch 00019: val_loss did not improve from 0.93821
# Epoch 20/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3786 - val_loss: 0.9586
#
# Epoch 00020: val_loss did not improve from 0.93821
# Epoch 21/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3821 - val_loss: 0.9303
#
# Epoch 00021: val_loss improved from 0.93821 to 0.93028, saving model to mlp_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3819 - val_loss: 0.9491
#
# Epoch 00022: val_loss did not improve from 0.93028
# Epoch 23/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3803 - val_loss: 0.9686
#
# Epoch 00023: val_loss did not improve from 0.93028
# Epoch 24/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3834 - val_loss: 0.9540
#
# Epoch 00024: val_loss did not improve from 0.93028
# Epoch 25/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3822 - val_loss: 0.9562
#
# Epoch 00025: val_loss did not improve from 0.93028
# Epoch 26/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3856 - val_loss: 0.9476
#
# Epoch 00026: val_loss did not improve from 0.93028
# Epoch 27/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3768 - val_loss: 0.9588
#
# Epoch 00027: val_loss did not improve from 0.93028
# Epoch 28/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3830 - val_loss: 0.9526
#
# Epoch 00028: val_loss did not improve from 0.93028
# Epoch 29/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3850 - val_loss: 0.9461
#
# Epoch 00029: val_loss did not improve from 0.93028
# Epoch 30/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3796 - val_loss: 0.9608
#
# Epoch 00030: val_loss did not improve from 0.93028
# Epoch 31/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3842 - val_loss: 0.9616
#
# Epoch 00031: val_loss did not improve from 0.93028
# Epoch 32/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3874 - val_loss: 0.9599
#
# Epoch 00032: val_loss did not improve from 0.93028
# Epoch 33/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3865 - val_loss: 0.9499
#
# Epoch 00033: val_loss did not improve from 0.93028
# Epoch 34/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3883 - val_loss: 0.9429
#
# Epoch 00034: val_loss did not improve from 0.93028
# Epoch 35/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3846 - val_loss: 0.9578
#
# Epoch 00035: val_loss did not improve from 0.93028
# Epoch 36/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3759 - val_loss: 0.9390
#
# Epoch 00036: val_loss did not improve from 0.93028
# Epoch 37/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3831 - val_loss: 0.9568
#
# Epoch 00037: val_loss did not improve from 0.93028
# Epoch 38/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3809 - val_loss: 0.9345
#
# Epoch 00038: val_loss did not improve from 0.93028
# Epoch 39/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3793 - val_loss: 0.9522
#
# Epoch 00039: val_loss did not improve from 0.93028
# Epoch 40/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3795 - val_loss: 0.9499
#
# Epoch 00040: val_loss did not improve from 0.93028
# Epoch 41/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3743 - val_loss: 0.9516
#
# Epoch 00041: val_loss did not improve from 0.93028
# Epoch 42/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3802 - val_loss: 0.9514
#
# Epoch 00042: val_loss did not improve from 0.93028
# Epoch 43/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3827 - val_loss: 0.9538
#
# Epoch 00043: val_loss did not improve from 0.93028
# Epoch 44/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3801 - val_loss: 0.9628
#
# Epoch 00044: val_loss did not improve from 0.93028
# Epoch 45/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3812 - val_loss: 0.9616
#
# Epoch 00045: val_loss did not improve from 0.93028
# Epoch 46/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3822 - val_loss: 0.9410
#
# Epoch 00046: val_loss did not improve from 0.93028
# Epoch 47/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3780 - val_loss: 0.9388
#
# Epoch 00047: val_loss did not improve from 0.93028
# Epoch 48/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3783 - val_loss: 0.9566
#
# Epoch 00048: val_loss did not improve from 0.93028
# Epoch 49/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3796 - val_loss: 0.9493
#
# Epoch 00049: val_loss did not improve from 0.93028
# Epoch 50/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3789 - val_loss: 0.9501
#
# Epoch 00050: val_loss did not improve from 0.93028
# Epoch 51/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3802 - val_loss: 0.9529
#
# Epoch 00051: val_loss did not improve from 0.93028
# Epoch 00051: early stopping
# training mlp took  307.0720753669739

# %%
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 2s 954us/step - loss: 1.3046 - val_loss: 0.8696
#
# Epoch 00001: val_loss improved from inf to 0.86964, saving model to cnn_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 1.3031 - val_loss: 0.8699
#
# Epoch 00002: val_loss did not improve from 0.86964
# Epoch 3/200
# 1619/1619 [==============================] - 1s 410us/step - loss: 1.3030 - val_loss: 0.8698
#
# Epoch 00003: val_loss did not improve from 0.86964
# Epoch 4/200
# 1619/1619 [==============================] - 1s 406us/step - loss: 1.3030 - val_loss: 0.8691
#
# Epoch 00004: val_loss improved from 0.86964 to 0.86908, saving model to cnn_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 1s 415us/step - loss: 1.3028 - val_loss: 0.8694
#
# Epoch 00005: val_loss did not improve from 0.86908
# Epoch 6/200
# 1619/1619 [==============================] - 1s 435us/step - loss: 1.3023 - val_loss: 0.8682
#
# Epoch 00006: val_loss improved from 0.86908 to 0.86823, saving model to cnn_multistep_multivariate.h5
# Epoch 7/200
# 1619/1619 [==============================] - 1s 448us/step - loss: 1.3025 - val_loss: 0.8688
#
# Epoch 00007: val_loss did not improve from 0.86823
# Epoch 8/200
# 1619/1619 [==============================] - 1s 418us/step - loss: 1.3018 - val_loss: 0.8681
#
# Epoch 00008: val_loss improved from 0.86823 to 0.86807, saving model to cnn_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.3016 - val_loss: 0.8702
#
# Epoch 00009: val_loss did not improve from 0.86807
# Epoch 10/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.3012 - val_loss: 0.8694
#
# Epoch 00010: val_loss did not improve from 0.86807
# Epoch 11/200
# 1619/1619 [==============================] - 1s 409us/step - loss: 1.2999 - val_loss: 0.8689
#
# Epoch 00011: val_loss did not improve from 0.86807
# Epoch 12/200
# 1619/1619 [==============================] - 1s 427us/step - loss: 1.2990 - val_loss: 0.8721
#
# Epoch 00012: val_loss did not improve from 0.86807
# Epoch 13/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 1.2981 - val_loss: 0.8705
#
# Epoch 00013: val_loss did not improve from 0.86807
# Epoch 14/200
# 1619/1619 [==============================] - 1s 430us/step - loss: 1.2972 - val_loss: 0.8707
#
# Epoch 00014: val_loss did not improve from 0.86807
# Epoch 15/200
# 1619/1619 [==============================] - 1s 442us/step - loss: 1.2966 - val_loss: 0.8696
#
# Epoch 00015: val_loss did not improve from 0.86807
# Epoch 16/200
# 1619/1619 [==============================] - 1s 436us/step - loss: 1.2813 - val_loss: 0.8417
#
# Epoch 00016: val_loss improved from 0.86807 to 0.84171, saving model to cnn_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 1.2356 - val_loss: 0.7851
#
# Epoch 00017: val_loss improved from 0.84171 to 0.78507, saving model to cnn_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 1s 436us/step - loss: 1.1390 - val_loss: 0.6405
#
# Epoch 00018: val_loss improved from 0.78507 to 0.64055, saving model to cnn_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 1s 432us/step - loss: 1.0195 - val_loss: 0.5246
#
# Epoch 00019: val_loss improved from 0.64055 to 0.52457, saving model to cnn_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 0.9480 - val_loss: 0.4610
#
# Epoch 00020: val_loss improved from 0.52457 to 0.46100, saving model to cnn_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 1s 444us/step - loss: 0.9141 - val_loss: 0.4359
#
# Epoch 00021: val_loss improved from 0.46100 to 0.43591, saving model to cnn_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 1s 439us/step - loss: 0.9027 - val_loss: 0.4266
#
# Epoch 00022: val_loss improved from 0.43591 to 0.42657, saving model to cnn_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 1s 437us/step - loss: 0.8970 - val_loss: 0.4206
#
# Epoch 00023: val_loss improved from 0.42657 to 0.42057, saving model to cnn_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 1s 429us/step - loss: 0.8941 - val_loss: 0.4189
#
# Epoch 00024: val_loss improved from 0.42057 to 0.41890, saving model to cnn_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 1s 427us/step - loss: 0.8940 - val_loss: 0.4273
#
# Epoch 00025: val_loss did not improve from 0.41890
# Epoch 26/200
# 1619/1619 [==============================] - 1s 432us/step - loss: 0.8919 - val_loss: 0.3997
#
# Epoch 00026: val_loss improved from 0.41890 to 0.39968, saving model to cnn_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 1s 434us/step - loss: 0.8932 - val_loss: 0.4032
#
# Epoch 00027: val_loss did not improve from 0.39968
# Epoch 28/200
# 1619/1619 [==============================] - 1s 421us/step - loss: 0.8896 - val_loss: 0.4027
#
# Epoch 00028: val_loss did not improve from 0.39968
# Epoch 29/200
# 1619/1619 [==============================] - 1s 423us/step - loss: 0.8879 - val_loss: 0.3952
#
# Epoch 00029: val_loss improved from 0.39968 to 0.39524, saving model to cnn_multistep_multivariate.h5
# Epoch 30/200
# 1619/1619 [==============================] - 1s 434us/step - loss: 0.8870 - val_loss: 0.3889
#
# Epoch 00030: val_loss improved from 0.39524 to 0.38894, saving model to cnn_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 1s 421us/step - loss: 0.8866 - val_loss: 0.3869
#
# Epoch 00031: val_loss improved from 0.38894 to 0.38689, saving model to cnn_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 1s 426us/step - loss: 0.8858 - val_loss: 0.3860
#
# Epoch 00032: val_loss improved from 0.38689 to 0.38598, saving model to cnn_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 1s 429us/step - loss: 0.8852 - val_loss: 0.3852
#
# Epoch 00033: val_loss improved from 0.38598 to 0.38515, saving model to cnn_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 1s 418us/step - loss: 0.8849 - val_loss: 0.3847
#
# Epoch 00034: val_loss improved from 0.38515 to 0.38475, saving model to cnn_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 1s 423us/step - loss: 0.8837 - val_loss: 0.3902
#
# Epoch 00035: val_loss did not improve from 0.38475
# Epoch 36/200
# 1619/1619 [==============================] - 1s 410us/step - loss: 0.8831 - val_loss: 0.3897
#
# Epoch 00036: val_loss did not improve from 0.38475
# Epoch 37/200
# 1619/1619 [==============================] - 1s 420us/step - loss: 0.8822 - val_loss: 0.3896
#
# Epoch 00037: val_loss did not improve from 0.38475
# Epoch 38/200
# 1619/1619 [==============================] - 1s 413us/step - loss: 0.8814 - val_loss: 0.3915
#
# Epoch 00038: val_loss did not improve from 0.38475
# Epoch 39/200
# 1619/1619 [==============================] - 1s 406us/step - loss: 0.8809 - val_loss: 0.3934
#
# Epoch 00039: val_loss did not improve from 0.38475
# Epoch 40/200
# 1619/1619 [==============================] - 1s 419us/step - loss: 0.8798 - val_loss: 0.3997
#
# Epoch 00040: val_loss did not improve from 0.38475
# Epoch 41/200
# 1619/1619 [==============================] - 1s 409us/step - loss: 0.8791 - val_loss: 0.4139
#
# Epoch 00041: val_loss did not improve from 0.38475
# Epoch 42/200
# 1619/1619 [==============================] - 1s 405us/step - loss: 0.8846 - val_loss: 0.4106
#
# Epoch 00042: val_loss did not improve from 0.38475
# Epoch 43/200
# 1619/1619 [==============================] - 1s 440us/step - loss: 0.8769 - val_loss: 0.4094
#
# Epoch 00043: val_loss did not improve from 0.38475
# Epoch 44/200
# 1619/1619 [==============================] - 1s 486us/step - loss: 0.8744 - val_loss: 0.4160
#
# Epoch 00044: val_loss did not improve from 0.38475
# Epoch 45/200
# 1619/1619 [==============================] - 1s 477us/step - loss: 0.8726 - val_loss: 0.4191
#
# Epoch 00045: val_loss did not improve from 0.38475
# Epoch 46/200
# 1619/1619 [==============================] - 1s 480us/step - loss: 0.8702 - val_loss: 0.4335
#
# Epoch 00046: val_loss did not improve from 0.38475
# Epoch 47/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8686 - val_loss: 0.4266
#
# Epoch 00047: val_loss did not improve from 0.38475
# Epoch 48/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8682 - val_loss: 0.4311
#
# Epoch 00048: val_loss did not improve from 0.38475
# Epoch 49/200
# 1619/1619 [==============================] - 1s 546us/step - loss: 0.8645 - val_loss: 0.4387
#
# Epoch 00049: val_loss did not improve from 0.38475
# Epoch 50/200
# 1619/1619 [==============================] - 1s 515us/step - loss: 0.8616 - val_loss: 0.4379
#
# Epoch 00050: val_loss did not improve from 0.38475
# Epoch 51/200
# 1619/1619 [==============================] - 1s 480us/step - loss: 0.8588 - val_loss: 0.4392
#
# Epoch 00051: val_loss did not improve from 0.38475
# Epoch 52/200
# 1619/1619 [==============================] - 1s 474us/step - loss: 0.8690 - val_loss: 0.5981
#
# Epoch 00052: val_loss did not improve from 0.38475
# Epoch 53/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8602 - val_loss: 0.4489
#
# Epoch 00053: val_loss did not improve from 0.38475
# Epoch 54/200
# 1619/1619 [==============================] - 1s 489us/step - loss: 0.8533 - val_loss: 0.4607
#
# Epoch 00054: val_loss did not improve from 0.38475
# Epoch 55/200
# 1619/1619 [==============================] - 1s 481us/step - loss: 0.8502 - val_loss: 0.4575
#
# Epoch 00055: val_loss did not improve from 0.38475
# Epoch 56/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.8471 - val_loss: 0.4415
#
# Epoch 00056: val_loss did not improve from 0.38475
# Epoch 57/200
# 1619/1619 [==============================] - 1s 482us/step - loss: 0.8441 - val_loss: 0.4457
#
# Epoch 00057: val_loss did not improve from 0.38475
# Epoch 58/200
# 1619/1619 [==============================] - 1s 485us/step - loss: 0.8538 - val_loss: 0.4790
#
# Epoch 00058: val_loss did not improve from 0.38475
# Epoch 59/200
# 1619/1619 [==============================] - 1s 517us/step - loss: 0.8499 - val_loss: 0.4727
#
# Epoch 00059: val_loss did not improve from 0.38475
# Epoch 60/200
# 1619/1619 [==============================] - 1s 490us/step - loss: 0.8381 - val_loss: 0.4758
#
# Epoch 00060: val_loss did not improve from 0.38475
# Epoch 61/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.8350 - val_loss: 0.4816
#
# Epoch 00061: val_loss did not improve from 0.38475
# Epoch 62/200
# 1619/1619 [==============================] - 1s 487us/step - loss: 0.8318 - val_loss: 0.4915
#
# Epoch 00062: val_loss did not improve from 0.38475
# Epoch 63/200
# 1619/1619 [==============================] - 1s 489us/step - loss: 0.8288 - val_loss: 0.4708
#
# Epoch 00063: val_loss did not improve from 0.38475
# Epoch 64/200
# 1619/1619 [==============================] - 1s 521us/step - loss: 0.8269 - val_loss: 0.4872
#
# Epoch 00064: val_loss did not improve from 0.38475
# Epoch 65/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.8235 - val_loss: 0.4743
#
# Epoch 00065: val_loss did not improve from 0.38475
# Epoch 66/200
# 1619/1619 [==============================] - 1s 520us/step - loss: 0.8204 - val_loss: 0.4873
#
# Epoch 00066: val_loss did not improve from 0.38475
# Epoch 67/200
# 1619/1619 [==============================] - 1s 583us/step - loss: 0.8179 - val_loss: 0.4714
#
# Epoch 00067: val_loss did not improve from 0.38475
# Epoch 68/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.8139 - val_loss: 0.4959
#
# Epoch 00068: val_loss did not improve from 0.38475
# Epoch 69/200
# 1619/1619 [==============================] - 1s 498us/step - loss: 0.8108 - val_loss: 0.4689
#
# Epoch 00069: val_loss did not improve from 0.38475
# Epoch 70/200
# 1619/1619 [==============================] - 1s 487us/step - loss: 0.8118 - val_loss: 0.4922
#
# Epoch 00070: val_loss did not improve from 0.38475
# Epoch 71/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.8056 - val_loss: 0.4936
#
# Epoch 00071: val_loss did not improve from 0.38475
# Epoch 72/200
# 1619/1619 [==============================] - 1s 516us/step - loss: 0.8021 - val_loss: 0.5017
#
# Epoch 00072: val_loss did not improve from 0.38475
# Epoch 73/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.8002 - val_loss: 0.5365
#
# Epoch 00073: val_loss did not improve from 0.38475
# Epoch 74/200
# 1619/1619 [==============================] - 1s 506us/step - loss: 0.7970 - val_loss: 0.5278
#
# Epoch 00074: val_loss did not improve from 0.38475
# Epoch 75/200
# 1619/1619 [==============================] - 1s 503us/step - loss: 0.7935 - val_loss: 0.5293
#
# Epoch 00075: val_loss did not improve from 0.38475
# Epoch 76/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7906 - val_loss: 0.4961
#
# Epoch 00076: val_loss did not improve from 0.38475
# Epoch 77/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7888 - val_loss: 0.4771
#
# Epoch 00077: val_loss did not improve from 0.38475
# Epoch 78/200
# 1619/1619 [==============================] - 1s 511us/step - loss: 0.7892 - val_loss: 0.5004
#
# Epoch 00078: val_loss did not improve from 0.38475
# Epoch 79/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7909 - val_loss: 0.5199
#
# Epoch 00079: val_loss did not improve from 0.38475
# Epoch 80/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7855 - val_loss: 0.5553
#
# Epoch 00080: val_loss did not improve from 0.38475
# Epoch 81/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7797 - val_loss: 0.5109
#
# Epoch 00081: val_loss did not improve from 0.38475
# Epoch 82/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7768 - val_loss: 0.5325
#
# Epoch 00082: val_loss did not improve from 0.38475
# Epoch 83/200
# 1619/1619 [==============================] - 1s 518us/step - loss: 0.7740 - val_loss: 0.5299
#
# Epoch 00083: val_loss did not improve from 0.38475
# Epoch 84/200
# 1619/1619 [==============================] - 1s 524us/step - loss: 0.7717 - val_loss: 0.5800
#
# Epoch 00084: val_loss did not improve from 0.38475
# Epoch 85/200
# 1619/1619 [==============================] - 1s 511us/step - loss: 0.7695 - val_loss: 0.5887
#
# Epoch 00085: val_loss did not improve from 0.38475
# Epoch 86/200
# 1619/1619 [==============================] - 1s 534us/step - loss: 0.7673 - val_loss: 0.5446
#
# Epoch 00086: val_loss did not improve from 0.38475
# Epoch 87/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7646 - val_loss: 0.5709
#
# Epoch 00087: val_loss did not improve from 0.38475
# Epoch 88/200
# 1619/1619 [==============================] - 1s 505us/step - loss: 0.7637 - val_loss: 0.5712
#
# Epoch 00088: val_loss did not improve from 0.38475
# Epoch 89/200
# 1619/1619 [==============================] - 1s 503us/step - loss: 0.7608 - val_loss: 0.5672
#
# Epoch 00089: val_loss did not improve from 0.38475
# Epoch 90/200
# 1619/1619 [==============================] - 1s 514us/step - loss: 0.7726 - val_loss: 0.7322
#
# Epoch 00090: val_loss did not improve from 0.38475
# Epoch 91/200
# 1619/1619 [==============================] - 1s 660us/step - loss: 0.7731 - val_loss: 0.4671
#
# Epoch 00091: val_loss did not improve from 0.38475
# Epoch 92/200
# 1619/1619 [==============================] - 1s 573us/step - loss: 0.7593 - val_loss: 0.5589
#
# Epoch 00092: val_loss did not improve from 0.38475
# Epoch 93/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.7536 - val_loss: 0.5773
#
# Epoch 00093: val_loss did not improve from 0.38475
# Epoch 94/200
# 1619/1619 [==============================] - 1s 490us/step - loss: 0.7508 - val_loss: 0.5746
#
# Epoch 00094: val_loss did not improve from 0.38475
# Epoch 95/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7482 - val_loss: 0.6013
#
# Epoch 00095: val_loss did not improve from 0.38475
# Epoch 96/200
# 1619/1619 [==============================] - 1s 493us/step - loss: 0.7463 - val_loss: 0.5840
#
# Epoch 00096: val_loss did not improve from 0.38475
# Epoch 97/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.7441 - val_loss: 0.5839
#
# Epoch 00097: val_loss did not improve from 0.38475
# Epoch 98/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7437 - val_loss: 0.5372
#
# Epoch 00098: val_loss did not improve from 0.38475
# Epoch 99/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.7423 - val_loss: 0.5960
#
# Epoch 00099: val_loss did not improve from 0.38475
# Epoch 100/200
# 1619/1619 [==============================] - 1s 494us/step - loss: 0.7391 - val_loss: 0.5796
#
# Epoch 00100: val_loss did not improve from 0.38475
# Epoch 101/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7370 - val_loss: 0.5874
#
# Epoch 00101: val_loss did not improve from 0.38475
# Epoch 102/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.7346 - val_loss: 0.5844
#
# Epoch 00102: val_loss did not improve from 0.38475
# Epoch 103/200
# 1619/1619 [==============================] - 1s 517us/step - loss: 0.7326 - val_loss: 0.6173
#
# Epoch 00103: val_loss did not improve from 0.38475
# Epoch 104/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7307 - val_loss: 0.6148
#
# Epoch 00104: val_loss did not improve from 0.38475
# Epoch 105/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.7294 - val_loss: 0.5818
#
# Epoch 00105: val_loss did not improve from 0.38475
# Epoch 106/200
# 1619/1619 [==============================] - 1s 550us/step - loss: 0.7281 - val_loss: 0.6250
#
# Epoch 00106: val_loss did not improve from 0.38475
# Epoch 107/200
# 1619/1619 [==============================] - 1s 580us/step - loss: 0.7259 - val_loss: 0.5696
#
# Epoch 00107: val_loss did not improve from 0.38475
# Epoch 108/200
# 1619/1619 [==============================] - 1s 518us/step - loss: 0.7237 - val_loss: 0.5860
#
# Epoch 00108: val_loss did not improve from 0.38475
# Epoch 109/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7230 - val_loss: 0.6153
#
# Epoch 00109: val_loss did not improve from 0.38475
# Epoch 110/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.7204 - val_loss: 0.5800
#
# Epoch 00110: val_loss did not improve from 0.38475
# Epoch 111/200
# 1619/1619 [==============================] - 1s 499us/step - loss: 0.7195 - val_loss: 0.6322
#
# Epoch 00111: val_loss did not improve from 0.38475
# Epoch 112/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.7210 - val_loss: 0.6933
#
# Epoch 00112: val_loss did not improve from 0.38475
# Epoch 113/200
# 1619/1619 [==============================] - 1s 536us/step - loss: 0.7203 - val_loss: 0.6518
#
# Epoch 00113: val_loss did not improve from 0.38475
# Epoch 114/200
# 1619/1619 [==============================] - 1s 552us/step - loss: 0.7363 - val_loss: 0.6529
#
# Epoch 00114: val_loss did not improve from 0.38475
# Epoch 115/200
# 1619/1619 [==============================] - 1s 556us/step - loss: 0.7179 - val_loss: 0.6474
#
# Epoch 00115: val_loss did not improve from 0.38475
# Epoch 116/200
# 1619/1619 [==============================] - 1s 493us/step - loss: 0.7137 - val_loss: 0.6215
#
# Epoch 00116: val_loss did not improve from 0.38475
# Epoch 117/200
# 1619/1619 [==============================] - 1s 514us/step - loss: 0.7098 - val_loss: 0.6146
#
# Epoch 00117: val_loss did not improve from 0.38475
# Epoch 118/200
# 1619/1619 [==============================] - 1s 513us/step - loss: 0.7081 - val_loss: 0.6337
#
# Epoch 00118: val_loss did not improve from 0.38475
# Epoch 119/200
# 1619/1619 [==============================] - 1s 530us/step - loss: 0.7063 - val_loss: 0.6260
#
# Epoch 00119: val_loss did not improve from 0.38475
# Epoch 120/200
# 1619/1619 [==============================] - 1s 510us/step - loss: 0.7046 - val_loss: 0.6202
#
# Epoch 00120: val_loss did not improve from 0.38475
# Epoch 121/200
# 1619/1619 [==============================] - 1s 512us/step - loss: 0.7038 - val_loss: 0.5983
#
# Epoch 00121: val_loss did not improve from 0.38475
# Epoch 122/200
# 1619/1619 [==============================] - 1s 551us/step - loss: 0.7026 - val_loss: 0.6656
#
# Epoch 00122: val_loss did not improve from 0.38475
# Epoch 123/200
# 1619/1619 [==============================] - 1s 554us/step - loss: 0.7004 - val_loss: 0.6685
#
# Epoch 00123: val_loss did not improve from 0.38475
# Epoch 124/200
# 1619/1619 [==============================] - 1s 502us/step - loss: 0.6987 - val_loss: 0.6644
#
# Epoch 00124: val_loss did not improve from 0.38475
# Epoch 125/200
# 1619/1619 [==============================] - 1s 492us/step - loss: 0.6974 - val_loss: 0.6302
#
# Epoch 00125: val_loss did not improve from 0.38475
# Epoch 126/200
# 1619/1619 [==============================] - 1s 523us/step - loss: 0.6955 - val_loss: 0.6508
#
# Epoch 00126: val_loss did not improve from 0.38475
# Epoch 127/200
# 1619/1619 [==============================] - 1s 491us/step - loss: 0.6937 - val_loss: 0.6407
#
# Epoch 00127: val_loss did not improve from 0.38475
# Epoch 128/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.6923 - val_loss: 0.6918
#
# Epoch 00128: val_loss did not improve from 0.38475
# Epoch 129/200
# 1619/1619 [==============================] - 1s 488us/step - loss: 0.6938 - val_loss: 0.6333
#
# Epoch 00129: val_loss did not improve from 0.38475
# Epoch 130/200
# 1619/1619 [==============================] - 1s 485us/step - loss: 0.6937 - val_loss: 0.7251
#
# Epoch 00130: val_loss did not improve from 0.38475
# Epoch 131/200
# 1619/1619 [==============================] - 1s 497us/step - loss: 0.6895 - val_loss: 0.6668
#
# Epoch 00131: val_loss did not improve from 0.38475
# Epoch 132/200
# 1619/1619 [==============================] - 1s 488us/step - loss: 0.6871 - val_loss: 0.6692
#
# Epoch 00132: val_loss did not improve from 0.38475
# Epoch 133/200
# 1619/1619 [==============================] - 1s 484us/step - loss: 0.6857 - val_loss: 0.6703
#
# Epoch 00133: val_loss did not improve from 0.38475
# Epoch 134/200
# 1619/1619 [==============================] - 1s 483us/step - loss: 0.6846 - val_loss: 0.6907
#
# Epoch 00134: val_loss did not improve from 0.38475
# Epoch 00134: early stopping
# *** Model fitted ***
# training cnn took  109.71351504325867

# %%
def train_sarima(df, n_history, pred_horizon, order, seasonal_order):
    trainingData = pd.DataFrame(df[predictionColumn], columns=[predictionColumn])
    print(trainingData.head())
    model = SARIMAX(trainingData[predictionColumn],order=order, seasonal_order=seasonal_order, start_p = 1, start_q = 1)
    fit = model.fit()
    fit.save("sarima.pkl")

    return None    

def forecast_sarima(df, n_history, pred_horizon):

    start = len(df[:-pred_horizon]) - 1
    end = start + pred_horizon - 1
    starttime = time.time()
    
    order = (1, 3, 0)
    seasonal_order = (1, 1, 1, n_history) #last parameter should be 52 for weekly saisonality
    train_sarima(df, n_history = n_history, pred_horizon=pred_horizon, order=order, seasonal_order=seasonal_order)
    print("training sarima took ", time.time() - starttime)

    model = SARIMAXResults.load('sarima.pkl')
    
    predictions = model.predict(start=start, end=end, dynamic=False).rename('SARIMAX Predictions' % n_history)
    
    df_forecast = pd.DataFrame(predictions.values, columns=['SARIMA Predictions (1, 3, 0)(1, 1, 1, n_history) ' % n_history])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
# this produces a memory error with 8gb RAM even when changing the paging size
#auto_arima(df[predictionColumn], start_p=1, start_q=1,
#                          test='adf',
#                          max_p=2, max_q=2, m=52,
#                          start_P=0, seasonal=True,
#                          d=None, D=1, trace=True,
#                          error_action='ignore',  
#                          suppress_warnings=True, 
#                          stepwise=True)
# m=52 for weekly seasonality https://alkaline-ml.com/pmdarima/tips_and_tricks.html#period
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 52); AIC=13654.872, BIC=13684.445, Fit time=251.124 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 52); AIC=16500.574, BIC=16512.404, Fit time=2.177 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 52); AIC=14993.537, BIC=15017.195, Fit time=65.003 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 52); AIC=13952.810, BIC=13976.469, Fit time=196.682 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 52); AIC=13605.328, BIC=13640.816, Fit time=326.772 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 52); AIC=14952.720, BIC=14982.293, Fit time=70.714 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 52); AIC=13602.190, BIC=13643.593, Fit time=973.515 seconds
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-1665058be22b> in <module>
#       6                          error_action='ignore',
#       7                          suppress_warnings=True,
# ----> 8                          stepwise=True)
#       9 # m=52 for weekly seasonality https://alkaline-ml.com/pmdarima/tips_and_tricks.html#period
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, transparams, solver, maxiter, disp, callback, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     517
#     518         # do the step-through...
# --> 519         all_res = stepwise_wrapper.step_through()
#     520
#     521     # filter the non-successful ones
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in step_through(self)
#     170
#     171             # p fluctuations:
# --> 172             self.fit_increment_k_cache_set(self.p > 0, p=self.p - 1)
#     173             self.fit_increment_k_cache_set(self.p < self.max_p, p=self.p + 1)
#     174
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in fit_increment_k_cache_set(self, expr, p, q, P, Q)
#     134                              scoring_args=self.scoring_args,
#     135                              with_intercept=self.with_intercept,
# --> 136                              **self.kwargs)
#     137
#     138             # use the orders as a key to be hashed for
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in _fit_arima(x, xreg, order, seasonal_order, start_params, trend, method, transparams, solver, maxiter, disp, callback, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, **kwargs)
#     203                     scoring_args=scoring_args,
#     204                     with_intercept=with_intercept, **kwargs)\
# --> 205             .fit(x, exogenous=xreg, **fit_params)
#     206
#     207     # for non-stationarity errors or singular matrices, return None
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in fit(self, y, exogenous, **fit_args)
#     485
#     486         # Internal call
# --> 487         self._fit(y, exogenous, **fit_args)
#     488
#     489         # now make a forecast if we're validating to compute the
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in _fit(self, y, exogenous, **fit_args)
#     400             with warnings.catch_warnings(record=False):
#     401                 warnings.simplefilter('ignore')
# --> 402                 fit, self.arima_res_ = _fit_wrapper()
#     403         else:
#     404             fit, self.arima_res_ = _fit_wrapper()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in _fit_wrapper()
#     394                                     solver=self.solver, maxiter=_maxiter,
#     395                                     disp=self.disp, callback=self.callback,
# --> 396                                     **fit_args)
#     397
#     398         # sometimes too many warnings...
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     488         else:
#     489             res = self.smooth(mlefit.params, transformed=False,
# --> 490                               cov_type=cov_type, cov_kwds=cov_kwds)
#     491
#     492             res.mlefit = mlefit
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     604
#     605         # Get the state space output
# --> 606         result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     607
#     608         # Wrap in a results object
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py in smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, **kwargs)
#     381
#     382         # Run the filter
# --> 383         kfilter = self._filter(**kwargs)
#     384
#     385         # Create the results object
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     791             self._initialize_filter(
#     792                 filter_method, inversion_method, stability_method,
# --> 793                 conserve_memory, filter_timing, tolerance, loglikelihood_burn
#     794             )
#     795         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _initialize_filter(self, filter_method, inversion_method, stability_method, conserve_memory, tolerance, filter_timing, loglikelihood_burn)
#     390                 self._statespaces[prefix], filter_method, inversion_method,
#     391                 stability_method, conserve_memory, filter_timing, tolerance,
# --> 392                 loglikelihood_burn
#     393             )
#     394         # Otherwise, update the filter parameters
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__init__()
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.set_filter_method()
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.allocate_arrays()
#
# MemoryError: Unable to allocate array with shape (158, 158, 2790) and data type float64

# %%
# Real data
plot_frames = []
plot_frames.append(plot_real_data_train(df, n_history))
plot_frames.append(plot_real_data_test(df, pred_horizon))

# %%
plot_frames.append(forecast_sarima(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
#    cpuusage_ps
# 0       11.592
# 1        0.357
# 2        0.409
# 3        0.335
# 4        0.885
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:993: UserWarning:
#
# Non-invertible starting seasonal moving average Using zeros as starting parameters.
# training sarima took  704.7937247753143

# %%
plot_frames.append(forecast_fbprophet_additiv(pred_horizon))
plot_frames.append(forecast_fbprophet_boxcox(pred_horizon, fbprophet_boxcox_lam))
plot_frames.append(forecast_lstm(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
plot_frames.append(forecast_mlp(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
plot_frames.append(forecast_cnn(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))

# %%
# Plot
plot_data(pd.concat(plot_frames, sort=True),'Vergleich ML-Models')
