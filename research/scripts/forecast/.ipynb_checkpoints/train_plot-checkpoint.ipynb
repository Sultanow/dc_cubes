# %%
import pandas as pd
import numpy as np
import pickle
import time

from numpy import array
from datetime import timedelta  
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten
from keras.layers import LSTM, GRU
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from fbprophet import Prophet
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from pmdarima import auto_arima
from datetime import timedelta 

import plotly
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode

# %%
timestamp = "timestamp"
predictionColumn = "cpuusage_ps"

# %%
def plot_real_data_train(df, n_history):
    data = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    data.columns = ['date','Train Data']
    data.set_index('date', inplace=True)
    return data

def plot_real_data_test(df, pred_horizon):
    data = df.reset_index()[[timestamp, predictionColumn]]
    data = data.tail(pred_horizon)
    data.columns = ['date','Test Data']
    data.set_index('date', inplace=True)
    return data

# %%
plotly.offline.init_notebook_mode(connected=True)

def plot_data(df, plotTitle):
    map_plotly_series = dict()
    for columnName in df.columns:
        s = go.Scatter(
            x=df.index,
            y=df[columnName],
            name = columnName,
            hoverinfo='none',
            opacity = 0.8)
        map_plotly_series[columnName] = s
    data = list(map_plotly_series.values())
    layout = dict(
        title = plotTitle,
        xaxis = dict(
            range = [df.index.min(),df.index.max()])
    )
    fig = dict(data=data, layout=layout)
    plotly.offline.plot(fig, filename = plotTitle + '.html')
    return None
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def generate_index_forecast(df, df_forecast, pred_horizon):
    minutesBetweenMeasures = 15
    temp = df.reset_index()[[timestamp]]
    lastTrainDataTimeStamp = temp.tail(pred_horizon)[timestamp].iloc[0]
    nextTimeStamp = lastTrainDataTimeStamp
    for i in df_forecast.index:
        nextTimeStamp = nextTimeStamp + timedelta(minutes=minutesBetweenMeasures)
        df_forecast.at[i, 'date'] = nextTimeStamp
    df_forecast.set_index('date', inplace=True)
    return df_forecast

# %%
# split a multivariate sequence into samples
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

# %%
def lstm_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def lstm_split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

def train_lstm(df, n_history, pred_horizon):
    # data split / preprocessing
    x, y, scalerX, scalerY = lstm_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("lstm_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)

    # model definition
    model = Sequential()
    model.add(LSTM(75, activation='tanh', return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)
    mc = ModelCheckpoint('lstm_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    # model train
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc])
    print('''*** Model fitted ***''')
    return None

def forecast_lstm(df, n_history, pred_horizon):
    model = load_model('lstm_multistep_multivariate.h5')
    with(open("lstm_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1]
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['LSTM Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def gru_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def gru_split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

def train_gru(df, n_history, pred_horizon):
    # data split / preprocessing
    x, y, scalerX, scalerY = gru_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = gru_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("gru_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)

    # model definition
    model = Sequential()
    model.add(GRU(50, activation='relu', return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('gru_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    # model train
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc])
    print('''*** Model fitted ***''')
    return None

def forecast_gru(df, n_history, pred_horizon):
    model = load_model('gru_multistep_multivariate.h5')
    with(open("gru_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1]
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['GRU Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def mlp_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
         
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_mlp(df, n_history, pred_horizon):
    x, y, scalerX, scalerY = mlp_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    n_input = x_train.shape[1] * x_train.shape[2]
    x_train = x_train.reshape((x_train.shape[0], n_input))
    n_neurons = int((n_input + pred_horizon))
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("mlp_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = Sequential()
    model.add(Dense(n_neurons, activation='tanh', input_dim=n_input))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('mlp_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)    
    model.fit(x_train, y_train, validation_split=0.1, epochs=200, callbacks=[es, mc])
    return None

def forecast_mlp(df, n_history, pred_horizon):
    model_mlp = load_model('mlp_multistep_multivariate.h5')
    with(open("mlp_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)

    numberOfFeatures =  x_train.shape[1] // n_history # was reshaped to featureNumber * n_history, so divide it to get number of features = 61
    pred_input = x_train[-1:]
    n_input = pred_input.shape[0] * pred_input.shape[1]
    pred_input = pred_input.reshape((1,n_input))
    
    prediction = model_mlp.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['MLP Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def cnn_data_preprocessing(df, n_history, pred_horizon):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    pcaTransformer = PCA(0.95) # keep 95% variance
    pcaTransformer.fit(x)
    x = pcaTransformer.transform(x)
    df_with_pca = pd.DataFrame().from_records(x)
    df_with_pca[predictionColumn] = y
    print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' % (len(df.columns)-1, pcaTransformer.n_components_))
    df_with_pca.reset_index(inplace=True)
    x, y = split_sequences(df_with_pca.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def train_cnn(df, pred_horizon, n_history):
    x, y, scalerX, scalerY = cnn_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon)
    print("SHAPES: ", x.shape, y.shape)
    numberOfFeatures = x.shape[2]
    x_train, x_test, y_train, y_test = lstm_split_train_test(x, y, pred_horizon)
    print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
    with(open("cnn_preprocessingResult.pkl", "wb")) as pkl:
        pickle.dump(preprocessingResult, pkl)
        
    model = Sequential()
    model.add(Conv1D(filters=150, kernel_size=2, activation='tanh', input_shape=(n_history, numberOfFeatures)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=40, kernel_size=2, activation='tanh'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(LSTM(75, activation='tanh'))
    model.add(Dense(pred_horizon))
    model.compile(loss='mse', optimizer='adam')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=15)
    mc = ModelCheckpoint('cnn_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc])
    print('''*** Model fitted ***''') 
    return None

def forecast_cnn(df, n_history, pred_horizon):
    model = load_model('cnn_multistep_multivariate.h5')
    with(open("cnn_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1] 
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = prediction = scalerY.inverse_transform(prediction)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['CNN'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def train_fbprophet_additiv(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_additiv.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return None

def train_fbprophet_boxcox(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    train["y"] = pd.to_numeric(train["y"])
    train['y'], lam = boxcox(train['y'])
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_boxcox.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return lam

def forecast_fbprophet_additiv(pred_horizon):
    with open('fbprophet_additiv.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet = m.predict(future)[['ds', 'yhat']]
    forecast_prophet.columns = ['date','FBProphet without Box-Cox-Transform']
    forecast_prophet.set_index('date', inplace=True)
    return forecast_prophet.tail(pred_horizon) 

def forecast_fbprophet_boxcox(pred_horizon, lam):
    with open('fbprophet_boxcox.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet_box_cox = m.predict(future)[['ds', 'yhat']]
    forecast_prophet_box_cox['yhat'] = forecast_prophet_box_cox['yhat'].apply(lambda x: inv_boxcox(x, lam))
    forecast_prophet_box_cox.columns = ['date','FBProphet with Box-Cox-Transform']
    forecast_prophet_box_cox.set_index('date', inplace=True)
    return forecast_prophet_box_cox.tail(pred_horizon)

# %%
def train_sarima(df, n_history, pred_horizon, order, seasonal_order):
    trainingData = pd.DataFrame(df[predictionColumn], columns=[predictionColumn])
    model = SARIMAX(trainingData[predictionColumn],order=order, seasonal_order=seasonal_order, start_p = 1, start_q = 1)
    fit = model.fit()
    fit.save("sarima.pkl")

    return None    

def forecast_sarima(df, n_history, pred_horizon):

    start = len(df[:-pred_horizon]) - 1
    end = start + pred_horizon - 1
    starttime = time.time()
    
    order = (1, 3, 0)
    seasonal_order = (1, 1, 1, n_history) #last parameter should be 52 for weekly saisonality
    train_sarima(df, n_history = n_history, pred_horizon=pred_horizon, order=order, seasonal_order=seasonal_order)
    print("training sarima took ", time.time() - starttime)

    model = SARIMAXResults.load('sarima.pkl')
    
    predictions = model.predict(start=start, end=end, dynamic=False).rename('SARIMAX Predictions')
    
    df_forecast = pd.DataFrame(predictions.values, columns=['SARIMA Predictions (1, 3, 0)(1, 1, 1, %d) ' % n_history])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
# Declaration
skip_csv_rows = 0
measureInterval = 15 #min
daysToPredict = 5
pred_horizon = (60//measureInterval) * 24 * daysToPredict #5 days (4*24*5), timestep = 15min
hours_history = 8
n_history = (60//measureInterval)*hours_history 

# Read data from pickle file
with open("./4week_transformed_droppedErrors_filled.pkl", "rb") as pickleFile:
    df = pickle.load(pickleFile)

# %%
df = df.reset_index()

# %%
df[predictionColumn] = pd.to_numeric(df[predictionColumn])

# %%
starttime = time.time()
train_fbprophet_additiv(df, pred_horizon)
print("training prophet without boxcox took ", time.time() - starttime)
starttime = time.time()
fbprophet_boxcox_lam = train_fbprophet_boxcox(df, pred_horizon)
print("training prophet with boxcox took ", time.time() - starttime)
# Out:
# training prophet without boxcox took  1.3000037670135498
# training prophet with boxcox took  1.0710952281951904

# %%
starttime = time.time()
train_lstm(df.copy().reset_index(), n_history=n_history, pred_horizon=pred_horizon)
print("training lstm took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3032 - mse: 1.3032 - val_loss: 0.8702 - val_mse: 0.8702
#
# Epoch 00001: val_loss improved from inf to 0.87023, saving model to lstm_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3000 - mse: 1.3000 - val_loss: 0.8699 - val_mse: 0.8699
#
# Epoch 00002: val_loss improved from 0.87023 to 0.86993, saving model to lstm_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2984 - mse: 1.2984 - val_loss: 0.8706 - val_mse: 0.8706
#
# Epoch 00003: val_loss did not improve from 0.86993
# Epoch 4/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2977 - mse: 1.2977 - val_loss: 0.8699 - val_mse: 0.8699
#
# Epoch 00004: val_loss improved from 0.86993 to 0.86993, saving model to lstm_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2976 - mse: 1.2976 - val_loss: 0.8708 - val_mse: 0.8708
#
# Epoch 00005: val_loss did not improve from 0.86993
# Epoch 6/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2976 - mse: 1.2976 - val_loss: 0.8706 - val_mse: 0.8706
#
# Epoch 00006: val_loss did not improve from 0.86993
# Epoch 7/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2971 - mse: 1.2971 - val_loss: 0.8691 - val_mse: 0.8691
#
# Epoch 00007: val_loss improved from 0.86993 to 0.86911, saving model to lstm_multistep_multivariate.h5
# Epoch 8/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2971 - mse: 1.2971 - val_loss: 0.8700 - val_mse: 0.8700
#
# Epoch 00008: val_loss did not improve from 0.86911
# Epoch 9/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2959 - mse: 1.2959 - val_loss: 0.8717 - val_mse: 0.8717
#
# Epoch 00009: val_loss did not improve from 0.86911
# Epoch 10/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2957 - mse: 1.2957 - val_loss: 0.8698 - val_mse: 0.8698
#
# Epoch 00010: val_loss did not improve from 0.86911
# Epoch 11/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2892 - mse: 1.2892 - val_loss: 0.8663 - val_mse: 0.8663
#
# Epoch 00011: val_loss improved from 0.86911 to 0.86631, saving model to lstm_multistep_multivariate.h5
# Epoch 12/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2773 - mse: 1.2773 - val_loss: 0.8551 - val_mse: 0.8551
#
# Epoch 00012: val_loss improved from 0.86631 to 0.85509, saving model to lstm_multistep_multivariate.h5
# Epoch 13/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2420 - mse: 1.2420 - val_loss: 0.7835 - val_mse: 0.7835
#
# Epoch 00013: val_loss improved from 0.85509 to 0.78351, saving model to lstm_multistep_multivariate.h5
# Epoch 14/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1994 - mse: 1.1994 - val_loss: 0.7491 - val_mse: 0.7491
#
# Epoch 00014: val_loss improved from 0.78351 to 0.74909, saving model to lstm_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2095 - mse: 1.2095 - val_loss: 0.8736 - val_mse: 0.8736
#
# Epoch 00015: val_loss did not improve from 0.74909
# Epoch 16/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2155 - mse: 1.2155 - val_loss: 0.7131 - val_mse: 0.7131
#
# Epoch 00016: val_loss improved from 0.74909 to 0.71315, saving model to lstm_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.1123 - mse: 1.1123 - val_loss: 0.6892 - val_mse: 0.6892
#
# Epoch 00017: val_loss improved from 0.71315 to 0.68918, saving model to lstm_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0785 - mse: 1.0785 - val_loss: 0.6828 - val_mse: 0.6828
#
# Epoch 00018: val_loss improved from 0.68918 to 0.68282, saving model to lstm_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0864 - mse: 1.0864 - val_loss: 0.6768 - val_mse: 0.6768
#
# Epoch 00019: val_loss improved from 0.68282 to 0.67677, saving model to lstm_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0378 - mse: 1.0378 - val_loss: 0.6387 - val_mse: 0.6387
#
# Epoch 00020: val_loss improved from 0.67677 to 0.63869, saving model to lstm_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0085 - mse: 1.0085 - val_loss: 0.6254 - val_mse: 0.6254
#
# Epoch 00021: val_loss improved from 0.63869 to 0.62540, saving model to lstm_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0049 - mse: 1.0049 - val_loss: 0.6324 - val_mse: 0.6324
#
# Epoch 00022: val_loss did not improve from 0.62540
# Epoch 23/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.0059 - mse: 1.0059 - val_loss: 0.5992 - val_mse: 0.5992
#
# Epoch 00023: val_loss improved from 0.62540 to 0.59919, saving model to lstm_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9731 - mse: 0.9731 - val_loss: 0.5937 - val_mse: 0.5937
#
# Epoch 00024: val_loss improved from 0.59919 to 0.59365, saving model to lstm_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9458 - mse: 0.9458 - val_loss: 0.6126 - val_mse: 0.6126
#
# Epoch 00025: val_loss did not improve from 0.59365
# Epoch 26/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9332 - mse: 0.9332 - val_loss: 0.5931 - val_mse: 0.5931
#
# Epoch 00026: val_loss improved from 0.59365 to 0.59314, saving model to lstm_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9211 - mse: 0.9211 - val_loss: 0.5814 - val_mse: 0.5814
#
# Epoch 00027: val_loss improved from 0.59314 to 0.58136, saving model to lstm_multistep_multivariate.h5
# Epoch 28/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.9088 - mse: 0.9088 - val_loss: 0.5743 - val_mse: 0.5743
#
# Epoch 00028: val_loss improved from 0.58136 to 0.57433, saving model to lstm_multistep_multivariate.h5
# Epoch 29/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9016 - mse: 0.9016 - val_loss: 0.6096 - val_mse: 0.6096
#
# Epoch 00029: val_loss did not improve from 0.57433
# Epoch 30/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.9227 - mse: 0.9227 - val_loss: 0.5624 - val_mse: 0.5624
#
# Epoch 00030: val_loss improved from 0.57433 to 0.56244, saving model to lstm_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8965 - mse: 0.8965 - val_loss: 0.5765 - val_mse: 0.5765
#
# Epoch 00031: val_loss did not improve from 0.56244
# Epoch 32/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8910 - mse: 0.8910 - val_loss: 0.6018 - val_mse: 0.6018
#
# Epoch 00032: val_loss did not improve from 0.56244
# Epoch 33/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8889 - mse: 0.8889 - val_loss: 0.5692 - val_mse: 0.5692TA: 0s - loss: 0.8839 - mse: 0
#
# Epoch 00033: val_loss did not improve from 0.56244
# Epoch 34/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8944 - mse: 0.8944 - val_loss: 0.5442 - val_mse: 0.5442
#
# Epoch 00034: val_loss improved from 0.56244 to 0.54417, saving model to lstm_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8925 - mse: 0.8925 - val_loss: 0.5730 - val_mse: 0.5730
#
# Epoch 00035: val_loss did not improve from 0.54417
# Epoch 36/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8893 - mse: 0.8893 - val_loss: 0.5712 - val_mse: 0.5712
#
# Epoch 00036: val_loss did not improve from 0.54417
# Epoch 37/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8914 - mse: 0.8914 - val_loss: 0.6140 - val_mse: 0.6140
#
# Epoch 00037: val_loss did not improve from 0.54417
# Epoch 38/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8867 - mse: 0.8867 - val_loss: 0.5857 - val_mse: 0.5857
#
# Epoch 00038: val_loss did not improve from 0.54417
# Epoch 39/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8851 - mse: 0.8851 - val_loss: 0.6080 - val_mse: 0.6080
#
# Epoch 00039: val_loss did not improve from 0.54417
# Epoch 40/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8854 - mse: 0.8854 - val_loss: 0.6057 - val_mse: 0.6057
#
# Epoch 00040: val_loss did not improve from 0.54417
# Epoch 41/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8845 - mse: 0.8845 - val_loss: 0.6233 - val_mse: 0.6233
#
# Epoch 00041: val_loss did not improve from 0.54417
# Epoch 42/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8824 - mse: 0.8824 - val_loss: 0.6144 - val_mse: 0.6144
#
# Epoch 00042: val_loss did not improve from 0.54417
# Epoch 43/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8896 - mse: 0.8896 - val_loss: 0.6307 - val_mse: 0.6307
#
# Epoch 00043: val_loss did not improve from 0.54417
# Epoch 44/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8817 - mse: 0.8817 - val_loss: 0.6360 - val_mse: 0.6360
#
# Epoch 00044: val_loss did not improve from 0.54417
# Epoch 45/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8886 - mse: 0.8886 - val_loss: 0.5500 - val_mse: 0.5500
#
# Epoch 00045: val_loss did not improve from 0.54417
# Epoch 46/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8850 - mse: 0.8850 - val_loss: 0.5931 - val_mse: 0.5931
#
# Epoch 00046: val_loss did not improve from 0.54417
# Epoch 47/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8797 - mse: 0.8797 - val_loss: 0.6388 - val_mse: 0.6388
#
# Epoch 00047: val_loss did not improve from 0.54417
# Epoch 48/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8765 - mse: 0.8765 - val_loss: 0.6008 - val_mse: 0.6008
#
# Epoch 00048: val_loss did not improve from 0.54417
# Epoch 49/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8752 - mse: 0.8752 - val_loss: 0.6417 - val_mse: 0.6417
#
# Epoch 00049: val_loss did not improve from 0.54417
# Epoch 50/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8741 - mse: 0.8741 - val_loss: 0.6553 - val_mse: 0.6553
#
# Epoch 00050: val_loss did not improve from 0.54417
# Epoch 51/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 0.8821 - mse: 0.8821 - val_loss: 0.6285 - val_mse: 0.6285
#
# Epoch 00051: val_loss did not improve from 0.54417
# Epoch 52/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8818 - mse: 0.8818 - val_loss: 0.6446 - val_mse: 0.6446
#
# Epoch 00052: val_loss did not improve from 0.54417
# Epoch 53/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8742 - mse: 0.8742 - val_loss: 0.6571 - val_mse: 0.6571
#
# Epoch 00053: val_loss did not improve from 0.54417
# Epoch 54/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 0.8716 - mse: 0.8716 - val_loss: 0.6022 - val_mse: 0.6022
#
# Epoch 00054: val_loss did not improve from 0.54417
# Epoch 00054: early stopping
# *** Model fitted ***
# training lstm took  345.0057682991028

# %%
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.6011 - val_loss: 1.0157
#
# Epoch 00001: val_loss improved from inf to 1.01572, saving model to mlp_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4293 - val_loss: 0.9937
#
# Epoch 00002: val_loss improved from 1.01572 to 0.99370, saving model to mlp_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4332 - val_loss: 1.0090
#
# Epoch 00003: val_loss did not improve from 0.99370
# Epoch 4/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4388 - val_loss: 1.0302
#
# Epoch 00004: val_loss did not improve from 0.99370
# Epoch 5/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4436 - val_loss: 1.0188
#
# Epoch 00005: val_loss did not improve from 0.99370
# Epoch 6/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4442 - val_loss: 1.0053
#
# Epoch 00006: val_loss did not improve from 0.99370
# Epoch 7/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4394 - val_loss: 1.0006
#
# Epoch 00007: val_loss did not improve from 0.99370
# Epoch 8/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4447 - val_loss: 0.9870
#
# Epoch 00008: val_loss improved from 0.99370 to 0.98704, saving model to mlp_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4329 - val_loss: 1.0392
#
# Epoch 00009: val_loss did not improve from 0.98704
# Epoch 10/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4382 - val_loss: 1.0298
#
# Epoch 00010: val_loss did not improve from 0.98704
# Epoch 11/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4376 - val_loss: 1.0078
#
# Epoch 00011: val_loss did not improve from 0.98704
# Epoch 12/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4476 - val_loss: 1.0251
#
# Epoch 00012: val_loss did not improve from 0.98704
# Epoch 13/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4390 - val_loss: 0.9857
#
# Epoch 00013: val_loss improved from 0.98704 to 0.98572, saving model to mlp_multistep_multivariate.h5
# Epoch 14/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4294 - val_loss: 1.0076
#
# Epoch 00014: val_loss did not improve from 0.98572
# Epoch 15/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4323 - val_loss: 1.0018
#
# Epoch 00015: val_loss did not improve from 0.98572
# Epoch 16/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4435 - val_loss: 1.0505
#
# Epoch 00016: val_loss did not improve from 0.98572
# Epoch 17/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4454 - val_loss: 1.0257
#
# Epoch 00017: val_loss did not improve from 0.98572
# Epoch 18/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4383 - val_loss: 0.9891
#
# Epoch 00018: val_loss did not improve from 0.98572
# Epoch 19/200
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.4409 - val_loss: 1.0216
#
# Epoch 00019: val_loss did not improve from 0.98572
# Epoch 20/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4553 - val_loss: 1.0573
#
# Epoch 00020: val_loss did not improve from 0.98572
# Epoch 21/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.4571 - val_loss: 0.9788
#
# Epoch 00021: val_loss improved from 0.98572 to 0.97884, saving model to mlp_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4348 - val_loss: 1.0923
#
# Epoch 00022: val_loss did not improve from 0.97884
# Epoch 23/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4561 - val_loss: 1.0437
#
# Epoch 00023: val_loss did not improve from 0.97884
# Epoch 24/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4521 - val_loss: 1.0366
#
# Epoch 00024: val_loss did not improve from 0.97884
# Epoch 25/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4373 - val_loss: 1.0057
#
# Epoch 00025: val_loss did not improve from 0.97884
# Epoch 26/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4420 - val_loss: 1.0040
#
# Epoch 00026: val_loss did not improve from 0.97884
# Epoch 27/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4358 - val_loss: 1.0122
#
# Epoch 00027: val_loss did not improve from 0.97884
# Epoch 28/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4452 - val_loss: 1.0078
#
# Epoch 00028: val_loss did not improve from 0.97884
# Epoch 29/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4365 - val_loss: 0.9929
#
# Epoch 00029: val_loss did not improve from 0.97884
# Epoch 30/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.4375 - val_loss: 1.0168
#
# Epoch 00030: val_loss did not improve from 0.97884
# Epoch 31/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4371 - val_loss: 0.9744
#
# Epoch 00031: val_loss improved from 0.97884 to 0.97436, saving model to mlp_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4343 - val_loss: 1.0173
#
# Epoch 00032: val_loss did not improve from 0.97436
# Epoch 33/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4460 - val_loss: 1.0013
#
# Epoch 00033: val_loss did not improve from 0.97436
# Epoch 34/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4380 - val_loss: 0.9959
#
# Epoch 00034: val_loss did not improve from 0.97436
# Epoch 35/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4311 - val_loss: 0.9834
#
# Epoch 00035: val_loss did not improve from 0.97436
# Epoch 36/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4327 - val_loss: 1.0107
#
# Epoch 00036: val_loss did not improve from 0.97436
# Epoch 37/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4441 - val_loss: 1.0338
#
# Epoch 00037: val_loss did not improve from 0.97436
# Epoch 38/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4505 - val_loss: 1.0208
#
# Epoch 00038: val_loss did not improve from 0.97436
# Epoch 39/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4404 - val_loss: 1.0391
#
# Epoch 00039: val_loss did not improve from 0.97436
# Epoch 40/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4435 - val_loss: 1.0135
#
# Epoch 00040: val_loss did not improve from 0.97436
# Epoch 41/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4459 - val_loss: 1.0013
#
# Epoch 00041: val_loss did not improve from 0.97436
# Epoch 42/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4413 - val_loss: 0.9893
#
# Epoch 00042: val_loss did not improve from 0.97436
# Epoch 43/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4460 - val_loss: 1.0058
#
# Epoch 00043: val_loss did not improve from 0.97436
# Epoch 44/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4350 - val_loss: 1.0271
#
# Epoch 00044: val_loss did not improve from 0.97436
# Epoch 45/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4401 - val_loss: 1.0485
#
# Epoch 00045: val_loss did not improve from 0.97436
# Epoch 46/200
# 1619/1619 [==============================] - 23s 14ms/step - loss: 1.4387 - val_loss: 0.9993
#
# Epoch 00046: val_loss did not improve from 0.97436
# Epoch 00046: early stopping
# training mlp took  1073.0286190509796

# %%
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 1s 901us/step - loss: 1.3037 - val_loss: 0.8702
#
# Epoch 00001: val_loss improved from inf to 0.87021, saving model to cnn_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 1s 472us/step - loss: 1.3032 - val_loss: 0.8692
#
# Epoch 00002: val_loss improved from 0.87021 to 0.86918, saving model to cnn_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 1s 472us/step - loss: 1.3018 - val_loss: 0.8697
#
# Epoch 00003: val_loss did not improve from 0.86918
# Epoch 4/200
# 1619/1619 [==============================] - 1s 473us/step - loss: 1.2987 - val_loss: 0.8713
#
# Epoch 00004: val_loss did not improve from 0.86918
# Epoch 5/200
# 1619/1619 [==============================] - 1s 467us/step - loss: 1.2978 - val_loss: 0.8709
#
# Epoch 00005: val_loss did not improve from 0.86918
# Epoch 6/200
# 1619/1619 [==============================] - 1s 539us/step - loss: 1.2971 - val_loss: 0.8701
#
# Epoch 00006: val_loss did not improve from 0.86918
# Epoch 7/200
# 1619/1619 [==============================] - 1s 468us/step - loss: 1.2978 - val_loss: 0.8686
#
# Epoch 00007: val_loss improved from 0.86918 to 0.86864, saving model to cnn_multistep_multivariate.h5
# Epoch 8/200
# 1619/1619 [==============================] - 1s 470us/step - loss: 1.2966 - val_loss: 0.8712
#
# Epoch 00008: val_loss did not improve from 0.86864
# Epoch 9/200
# 1619/1619 [==============================] - 1s 474us/step - loss: 1.2958 - val_loss: 0.8706
#
# Epoch 00009: val_loss did not improve from 0.86864
# Epoch 10/200
# 1619/1619 [==============================] - 1s 466us/step - loss: 1.2908 - val_loss: 0.8702
#
# Epoch 00010: val_loss did not improve from 0.86864
# Epoch 11/200
# 1619/1619 [==============================] - 1s 524us/step - loss: 1.2919 - val_loss: 0.8717
#
# Epoch 00011: val_loss did not improve from 0.86864
# Epoch 12/200
# 1619/1619 [==============================] - 1s 469us/step - loss: 1.2806 - val_loss: 0.8700
#
# Epoch 00012: val_loss did not improve from 0.86864
# Epoch 13/200
# 1619/1619 [==============================] - 1s 467us/step - loss: 1.2515 - val_loss: 0.8129
#
# Epoch 00013: val_loss improved from 0.86864 to 0.81291, saving model to cnn_multistep_multivariate.h5
# Epoch 14/200
# 1619/1619 [==============================] - 1s 483us/step - loss: 1.2065 - val_loss: 0.7754
#
# Epoch 00014: val_loss improved from 0.81291 to 0.77541, saving model to cnn_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 1s 524us/step - loss: 1.1686 - val_loss: 0.6729
#
# Epoch 00015: val_loss improved from 0.77541 to 0.67292, saving model to cnn_multistep_multivariate.h5
# Epoch 16/200
# 1619/1619 [==============================] - 1s 473us/step - loss: 1.1312 - val_loss: 0.6466
#
# Epoch 00016: val_loss improved from 0.67292 to 0.64664, saving model to cnn_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 1s 472us/step - loss: 1.1132 - val_loss: 0.6751
#
# Epoch 00017: val_loss did not improve from 0.64664
# Epoch 18/200
# 1619/1619 [==============================] - 1s 465us/step - loss: 1.0859 - val_loss: 0.5884
#
# Epoch 00018: val_loss improved from 0.64664 to 0.58845, saving model to cnn_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 1s 549us/step - loss: 1.0498 - val_loss: 0.5673
#
# Epoch 00019: val_loss improved from 0.58845 to 0.56727, saving model to cnn_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 1s 487us/step - loss: 1.0295 - val_loss: 0.5572
#
# Epoch 00020: val_loss improved from 0.56727 to 0.55722, saving model to cnn_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 1s 466us/step - loss: 1.0125 - val_loss: 0.5519
#
# Epoch 00021: val_loss improved from 0.55722 to 0.55189, saving model to cnn_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 1s 464us/step - loss: 0.9914 - val_loss: 0.5266
#
# Epoch 00022: val_loss improved from 0.55189 to 0.52658, saving model to cnn_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 1s 469us/step - loss: 0.9643 - val_loss: 0.4883
#
# Epoch 00023: val_loss improved from 0.52658 to 0.48828, saving model to cnn_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 1s 476us/step - loss: 0.9366 - val_loss: 0.4742
#
# Epoch 00024: val_loss improved from 0.48828 to 0.47417, saving model to cnn_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 1s 473us/step - loss: 0.9164 - val_loss: 0.4630
#
# Epoch 00025: val_loss improved from 0.47417 to 0.46303, saving model to cnn_multistep_multivariate.h5
# Epoch 26/200
# 1619/1619 [==============================] - 1s 530us/step - loss: 0.9239 - val_loss: 0.4464
#
# Epoch 00026: val_loss improved from 0.46303 to 0.44640, saving model to cnn_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 1s 469us/step - loss: 0.9140 - val_loss: 0.4499
#
# Epoch 00027: val_loss did not improve from 0.44640
# Epoch 28/200
# 1619/1619 [==============================] - 1s 470us/step - loss: 0.9002 - val_loss: 0.4475
#
# Epoch 00028: val_loss did not improve from 0.44640
# Epoch 29/200
# 1619/1619 [==============================] - 1s 478us/step - loss: 0.8967 - val_loss: 0.4559
#
# Epoch 00029: val_loss did not improve from 0.44640
# Epoch 30/200
# 1619/1619 [==============================] - 1s 500us/step - loss: 0.8949 - val_loss: 0.4635
#
# Epoch 00030: val_loss did not improve from 0.44640
# Epoch 31/200
# 1619/1619 [==============================] - 1s 545us/step - loss: 0.8937 - val_loss: 0.4532
#
# Epoch 00031: val_loss did not improve from 0.44640
# Epoch 32/200
# 1619/1619 [==============================] - 1s 547us/step - loss: 0.8927 - val_loss: 0.4558
#
# Epoch 00032: val_loss did not improve from 0.44640
# Epoch 33/200
# 1619/1619 [==============================] - 1s 552us/step - loss: 0.8923 - val_loss: 0.7989
#
# Epoch 00033: val_loss did not improve from 0.44640
# Epoch 34/200
# 1619/1619 [==============================] - 1s 545us/step - loss: 0.9435 - val_loss: 0.5280
#
# Epoch 00034: val_loss did not improve from 0.44640
# Epoch 35/200
# 1619/1619 [==============================] - 1s 553us/step - loss: 0.9208 - val_loss: 0.5433
#
# Epoch 00035: val_loss did not improve from 0.44640
# Epoch 36/200
# 1619/1619 [==============================] - 1s 547us/step - loss: 0.8981 - val_loss: 0.4519
#
# Epoch 00036: val_loss did not improve from 0.44640
# Epoch 37/200
# 1619/1619 [==============================] - 1s 533us/step - loss: 0.8921 - val_loss: 0.4594
#
# Epoch 00037: val_loss did not improve from 0.44640
# Epoch 38/200
# 1619/1619 [==============================] - 1s 556us/step - loss: 0.8912 - val_loss: 0.4628
#
# Epoch 00038: val_loss did not improve from 0.44640
# Epoch 39/200
# 1619/1619 [==============================] - 1s 541us/step - loss: 0.8909 - val_loss: 0.4684
#
# Epoch 00039: val_loss did not improve from 0.44640
# Epoch 40/200
# 1619/1619 [==============================] - 1s 550us/step - loss: 0.8904 - val_loss: 0.4633
#
# Epoch 00040: val_loss did not improve from 0.44640
# Epoch 41/200
# 1619/1619 [==============================] - 1s 542us/step - loss: 0.8898 - val_loss: 0.4612
#
# Epoch 00041: val_loss did not improve from 0.44640
# Epoch 00041: early stopping
# *** Model fitted ***
# training cnn took  41.92505121231079

# %%
starttime = time.time()
train_gru(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training GRU took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 182 features, reduced to 60 features
# SHAPES:  (2279, 32, 61) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 61) (480, 32, 61) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3051 - mse: 1.3051 - val_loss: 0.8694 - val_mse: 0.8694
#
# Epoch 00001: val_loss improved from inf to 0.86942, saving model to gru_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.3025 - mse: 1.3025 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00002: val_loss did not improve from 0.86942
# Epoch 3/200
# 1619/1619 [==============================] - 5s 3ms/step - loss: 1.2994 - mse: 1.2994 - val_loss: 0.8648 - val_mse: 0.8648
#
# Epoch 00003: val_loss improved from 0.86942 to 0.86480, saving model to gru_multistep_multivariate.h5
# Epoch 4/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2935 - mse: 1.2935 - val_loss: 0.8664 - val_mse: 0.8664
#
# Epoch 00004: val_loss did not improve from 0.86480
# Epoch 5/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2906 - mse: 1.2906 - val_loss: 0.8738 - val_mse: 0.8738
#
# Epoch 00005: val_loss did not improve from 0.86480
# Epoch 6/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2843 - mse: 1.2843 - val_loss: 0.8554 - val_mse: 0.8554
#
# Epoch 00006: val_loss improved from 0.86480 to 0.85535, saving model to gru_multistep_multivariate.h5
# Epoch 7/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2776 - mse: 1.2776 - val_loss: 0.8557 - val_mse: 0.8557
#
# Epoch 00007: val_loss did not improve from 0.85535
# Epoch 8/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2756 - mse: 1.2756 - val_loss: 0.8624 - val_mse: 0.8624
#
# Epoch 00008: val_loss did not improve from 0.85535
# Epoch 9/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2724 - mse: 1.2724 - val_loss: 0.8675 - val_mse: 0.8675
#
# Epoch 00009: val_loss did not improve from 0.85535
# Epoch 10/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2664 - mse: 1.2664 - val_loss: 0.8762 - val_mse: 0.8762
#
# Epoch 00010: val_loss did not improve from 0.85535
# Epoch 11/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2521 - mse: 1.2521 - val_loss: 0.8548 - val_mse: 0.8548
#
# Epoch 00011: val_loss improved from 0.85535 to 0.85475, saving model to gru_multistep_multivariate.h5
# Epoch 12/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2267 - mse: 1.2267 - val_loss: 0.8309 - val_mse: 0.8309
#
# Epoch 00012: val_loss improved from 0.85475 to 0.83086, saving model to gru_multistep_multivariate.h5
# Epoch 13/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.1895 - mse: 1.1895 - val_loss: 0.8101 - val_mse: 0.8101
#
# Epoch 00013: val_loss improved from 0.83086 to 0.81007, saving model to gru_multistep_multivariate.h5
# Epoch 14/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.1767 - mse: 1.1767 - val_loss: 0.7837 - val_mse: 0.7837
#
# Epoch 00014: val_loss improved from 0.81007 to 0.78369, saving model to gru_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 1.1357 - mse: 1.1357 - val_loss: 0.7834 - val_mse: 0.7834
#
# Epoch 00015: val_loss improved from 0.78369 to 0.78338, saving model to gru_multistep_multivariate.h5
# Epoch 16/200
# 1619/1619 [==============================] - 6s 3ms/step - loss: 1.1220 - mse: 1.1220 - val_loss: 0.7224 - val_mse: 0.7224
#
# Epoch 00016: val_loss improved from 0.78338 to 0.72245, saving model to gru_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0983 - mse: 1.0983 - val_loss: 0.7252 - val_mse: 0.7252
#
# Epoch 00017: val_loss did not improve from 0.72245
# Epoch 18/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0680 - mse: 1.0680 - val_loss: 0.7222 - val_mse: 0.7222
#
# Epoch 00018: val_loss improved from 0.72245 to 0.72223, saving model to gru_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0572 - mse: 1.0572 - val_loss: 0.6651 - val_mse: 0.6651
#
# Epoch 00019: val_loss improved from 0.72223 to 0.66505, saving model to gru_multistep_multivariate.h5
# Epoch 20/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0268 - mse: 1.0268 - val_loss: 0.6513 - val_mse: 0.6513
#
# Epoch 00020: val_loss improved from 0.66505 to 0.65130, saving model to gru_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0096 - mse: 1.0096 - val_loss: 0.6345 - val_mse: 0.6345
#
# Epoch 00021: val_loss improved from 0.65130 to 0.63448, saving model to gru_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9971 - mse: 0.9971 - val_loss: 0.6157 - val_mse: 0.6157
#
# Epoch 00022: val_loss improved from 0.63448 to 0.61570, saving model to gru_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9962 - mse: 0.9962 - val_loss: 0.6220 - val_mse: 0.6220
#
# Epoch 00023: val_loss did not improve from 0.61570
# Epoch 24/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9748 - mse: 0.9748 - val_loss: 0.6079 - val_mse: 0.6079
#
# Epoch 00024: val_loss improved from 0.61570 to 0.60794, saving model to gru_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9617 - mse: 0.9617 - val_loss: 0.5871 - val_mse: 0.5871
#
# Epoch 00025: val_loss improved from 0.60794 to 0.58714, saving model to gru_multistep_multivariate.h5
# Epoch 26/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9678 - mse: 0.9678 - val_loss: 0.6344 - val_mse: 0.6344
#
# Epoch 00026: val_loss did not improve from 0.58714
# Epoch 27/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9633 - mse: 0.9633 - val_loss: 0.5480 - val_mse: 0.5480
#
# Epoch 00027: val_loss improved from 0.58714 to 0.54796, saving model to gru_multistep_multivariate.h5
# Epoch 28/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9380 - mse: 0.9380 - val_loss: 0.5478 - val_mse: 0.5478
#
# Epoch 00028: val_loss improved from 0.54796 to 0.54784, saving model to gru_multistep_multivariate.h5
# Epoch 29/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9281 - mse: 0.9281 - val_loss: 0.5561 - val_mse: 0.5561
#
# Epoch 00029: val_loss did not improve from 0.54784
# Epoch 30/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9209 - mse: 0.9209 - val_loss: 0.5470 - val_mse: 0.5470
#
# Epoch 00030: val_loss improved from 0.54784 to 0.54698, saving model to gru_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9204 - mse: 0.9204 - val_loss: 0.5861 - val_mse: 0.5861
#
# Epoch 00031: val_loss did not improve from 0.54698
# Epoch 32/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9194 - mse: 0.9194 - val_loss: 0.5304 - val_mse: 0.5304
#
# Epoch 00032: val_loss improved from 0.54698 to 0.53043, saving model to gru_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9078 - mse: 0.9078 - val_loss: 0.5299 - val_mse: 0.5299
#
# Epoch 00033: val_loss improved from 0.53043 to 0.52987, saving model to gru_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9134 - mse: 0.9134 - val_loss: 0.5130 - val_mse: 0.5130
#
# Epoch 00034: val_loss improved from 0.52987 to 0.51297, saving model to gru_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8939 - mse: 0.8939 - val_loss: 0.5377 - val_mse: 0.5377
#
# Epoch 00035: val_loss did not improve from 0.51297
# Epoch 36/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8903 - mse: 0.8903 - val_loss: 0.5041 - val_mse: 0.5041
#
# Epoch 00036: val_loss improved from 0.51297 to 0.50412, saving model to gru_multistep_multivariate.h5
# Epoch 37/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8858 - mse: 0.8858 - val_loss: 0.4946 - val_mse: 0.4946
#
# Epoch 00037: val_loss improved from 0.50412 to 0.49457, saving model to gru_multistep_multivariate.h5
# Epoch 38/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8831 - mse: 0.8831 - val_loss: 0.5203 - val_mse: 0.5203
#
# Epoch 00038: val_loss did not improve from 0.49457
# Epoch 39/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8746 - mse: 0.8746 - val_loss: 0.5015 - val_mse: 0.5015
#
# Epoch 00039: val_loss did not improve from 0.49457
# Epoch 40/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8700 - mse: 0.8700 - val_loss: 0.5161 - val_mse: 0.5161
#
# Epoch 00040: val_loss did not improve from 0.49457
# Epoch 41/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8671 - mse: 0.8671 - val_loss: 0.5013 - val_mse: 0.5013
#
# Epoch 00041: val_loss did not improve from 0.49457
# Epoch 42/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8769 - mse: 0.8769 - val_loss: 0.5278 - val_mse: 0.5278
#
# Epoch 00042: val_loss did not improve from 0.49457
# Epoch 43/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8725 - mse: 0.8725 - val_loss: 0.5248 - val_mse: 0.5248
#
# Epoch 00043: val_loss did not improve from 0.49457
# Epoch 44/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8563 - mse: 0.8563 - val_loss: 0.5226 - val_mse: 0.5226
#
# Epoch 00044: val_loss did not improve from 0.49457
# Epoch 45/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8617 - mse: 0.8617 - val_loss: 0.5710 - val_mse: 0.5710
#
# Epoch 00045: val_loss did not improve from 0.49457
# Epoch 46/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8583 - mse: 0.8583 - val_loss: 0.5313 - val_mse: 0.5313
#
# Epoch 00046: val_loss did not improve from 0.49457
# Epoch 47/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8491 - mse: 0.8491 - val_loss: 0.4753 - val_mse: 0.4753
#
# Epoch 00047: val_loss improved from 0.49457 to 0.47534, saving model to gru_multistep_multivariate.h5
# Epoch 48/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8441 - mse: 0.8441 - val_loss: 0.4982 - val_mse: 0.4982
#
# Epoch 00048: val_loss did not improve from 0.47534
# Epoch 49/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8434 - mse: 0.8434 - val_loss: 0.4832 - val_mse: 0.4832
#
# Epoch 00049: val_loss did not improve from 0.47534
# Epoch 50/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8393 - mse: 0.8393 - val_loss: 0.5161 - val_mse: 0.5161
#
# Epoch 00050: val_loss did not improve from 0.47534
# Epoch 51/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8319 - mse: 0.8319 - val_loss: 0.5212 - val_mse: 0.5212
#
# Epoch 00051: val_loss did not improve from 0.47534
# Epoch 52/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8364 - mse: 0.8364 - val_loss: 0.5063 - val_mse: 0.5063
#
# Epoch 00052: val_loss did not improve from 0.47534
# Epoch 53/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8325 - mse: 0.8325 - val_loss: 0.4777 - val_mse: 0.4777
#
# Epoch 00053: val_loss did not improve from 0.47534
# Epoch 54/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8915 - mse: 0.8915 - val_loss: 0.4723 - val_mse: 0.4723
#
# Epoch 00054: val_loss improved from 0.47534 to 0.47233, saving model to gru_multistep_multivariate.h5
# Epoch 55/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8305 - mse: 0.8305 - val_loss: 0.4850 - val_mse: 0.4850
#
# Epoch 00055: val_loss did not improve from 0.47233
# Epoch 56/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8257 - mse: 0.8257 - val_loss: 0.4730 - val_mse: 0.4730
#
# Epoch 00056: val_loss did not improve from 0.47233
# Epoch 57/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8232 - mse: 0.8232 - val_loss: 0.4937 - val_mse: 0.4937
#
# Epoch 00057: val_loss did not improve from 0.47233
# Epoch 58/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8214 - mse: 0.8214 - val_loss: 0.5204 - val_mse: 0.5204
#
# Epoch 00058: val_loss did not improve from 0.47233
# Epoch 59/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8192 - mse: 0.8192 - val_loss: 0.4861 - val_mse: 0.4861
#
# Epoch 00059: val_loss did not improve from 0.47233
# Epoch 60/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8192 - mse: 0.8192 - val_loss: 0.5127 - val_mse: 0.5127
#
# Epoch 00060: val_loss did not improve from 0.47233
# Epoch 61/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8224 - mse: 0.8224 - val_loss: 0.4554 - val_mse: 0.4554
#
# Epoch 00061: val_loss improved from 0.47233 to 0.45539, saving model to gru_multistep_multivariate.h5
# Epoch 62/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8292 - mse: 0.8292 - val_loss: 0.4972 - val_mse: 0.4972
#
# Epoch 00062: val_loss did not improve from 0.45539
# Epoch 63/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8274 - mse: 0.8274 - val_loss: 0.4982 - val_mse: 0.4982
#
# Epoch 00063: val_loss did not improve from 0.45539
# Epoch 64/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8181 - mse: 0.8181 - val_loss: 0.4846 - val_mse: 0.4846
#
# Epoch 00064: val_loss did not improve from 0.45539
# Epoch 65/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8110 - mse: 0.8110 - val_loss: 0.4975 - val_mse: 0.4975
#
# Epoch 00065: val_loss did not improve from 0.45539
# Epoch 66/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8209 - mse: 0.8209 - val_loss: 0.4912 - val_mse: 0.4912
#
# Epoch 00066: val_loss did not improve from 0.45539
# Epoch 67/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8179 - mse: 0.8179 - val_loss: 0.4868 - val_mse: 0.4868
#
# Epoch 00067: val_loss did not improve from 0.45539
# Epoch 68/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8181 - mse: 0.8181 - val_loss: 0.4911 - val_mse: 0.4911
#
# Epoch 00068: val_loss did not improve from 0.45539
# Epoch 69/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8207 - mse: 0.8207 - val_loss: 0.4748 - val_mse: 0.4748
#
# Epoch 00069: val_loss did not improve from 0.45539
# Epoch 70/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8068 - mse: 0.8068 - val_loss: 0.4853 - val_mse: 0.4853
#
# Epoch 00070: val_loss did not improve from 0.45539
# Epoch 71/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8071 - mse: 0.8071 - val_loss: 0.4820 - val_mse: 0.4820
#
# Epoch 00071: val_loss did not improve from 0.45539
# Epoch 72/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8071 - mse: 0.8071 - val_loss: 0.5028 - val_mse: 0.5028
#
# Epoch 00072: val_loss did not improve from 0.45539
# Epoch 73/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8099 - mse: 0.8099 - val_loss: 0.4787 - val_mse: 0.4787
#
# Epoch 00073: val_loss did not improve from 0.45539
# Epoch 74/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8147 - mse: 0.8147 - val_loss: 0.5035 - val_mse: 0.5035
#
# Epoch 00074: val_loss did not improve from 0.45539
# Epoch 75/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8099 - mse: 0.8099 - val_loss: 0.4764 - val_mse: 0.4764
#
# Epoch 00075: val_loss did not improve from 0.45539
# Epoch 76/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.8031 - mse: 0.8031 - val_loss: 0.4693 - val_mse: 0.4693
#
# Epoch 00076: val_loss did not improve from 0.45539
# Epoch 00076: early stopping
# *** Model fitted ***
# training GRU took  475.35817217826843

# %%
# this produces a memory error with 8gb RAM even when changing the paging size
#auto_arima(df[predictionColumn], start_p=1, start_q=1,
#                          test='adf',
#                          max_p=2, max_q=2, m=52,
#                          start_P=0, seasonal=True,
#                          d=None, D=1, trace=True,
#                          error_action='ignore',  
#                          suppress_warnings=True, 
#                          stepwise=True)
# m=52 for weekly seasonality https://alkaline-ml.com/pmdarima/tips_and_tricks.html#period
# Out:
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(0, 1, 1, 52); AIC=13654.872, BIC=13684.445, Fit time=251.124 seconds
# Fit ARIMA: order=(0, 0, 0) seasonal_order=(0, 1, 0, 52); AIC=16500.574, BIC=16512.404, Fit time=2.177 seconds
# Fit ARIMA: order=(1, 0, 0) seasonal_order=(1, 1, 0, 52); AIC=14993.537, BIC=15017.195, Fit time=65.003 seconds
# Fit ARIMA: order=(0, 0, 1) seasonal_order=(0, 1, 1, 52); AIC=13952.810, BIC=13976.469, Fit time=196.682 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 1, 52); AIC=13605.328, BIC=13640.816, Fit time=326.772 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 0, 52); AIC=14952.720, BIC=14982.293, Fit time=70.714 seconds
# Fit ARIMA: order=(1, 0, 1) seasonal_order=(1, 1, 2, 52); AIC=13602.190, BIC=13643.593, Fit time=973.515 seconds
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-7-1665058be22b> in <module>
#       6                          error_action='ignore',
#       7                          suppress_warnings=True,
# ----> 8                          stepwise=True)
#       9 # m=52 for weekly seasonality https://alkaline-ml.com/pmdarima/tips_and_tricks.html#period
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, transparams, solver, maxiter, disp, callback, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     517
#     518         # do the step-through...
# --> 519         all_res = stepwise_wrapper.step_through()
#     520
#     521     # filter the non-successful ones
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in step_through(self)
#     170
#     171             # p fluctuations:
# --> 172             self.fit_increment_k_cache_set(self.p > 0, p=self.p - 1)
#     173             self.fit_increment_k_cache_set(self.p < self.max_p, p=self.p + 1)
#     174
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in fit_increment_k_cache_set(self, expr, p, q, P, Q)
#     134                              scoring_args=self.scoring_args,
#     135                              with_intercept=self.with_intercept,
# --> 136                              **self.kwargs)
#     137
#     138             # use the orders as a key to be hashed for
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\_auto_solvers.py in _fit_arima(x, xreg, order, seasonal_order, start_params, trend, method, transparams, solver, maxiter, disp, callback, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, **kwargs)
#     203                     scoring_args=scoring_args,
#     204                     with_intercept=with_intercept, **kwargs)\
# --> 205             .fit(x, exogenous=xreg, **fit_params)
#     206
#     207     # for non-stationarity errors or singular matrices, return None
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in fit(self, y, exogenous, **fit_args)
#     485
#     486         # Internal call
# --> 487         self._fit(y, exogenous, **fit_args)
#     488
#     489         # now make a forecast if we're validating to compute the
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in _fit(self, y, exogenous, **fit_args)
#     400             with warnings.catch_warnings(record=False):
#     401                 warnings.simplefilter('ignore')
# --> 402                 fit, self.arima_res_ = _fit_wrapper()
#     403         else:
#     404             fit, self.arima_res_ = _fit_wrapper()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pmdarima-1.3.0-py3.7-win-amd64.egg\pmdarima\arima\arima.py in _fit_wrapper()
#     394                                     solver=self.solver, maxiter=_maxiter,
#     395                                     disp=self.disp, callback=self.callback,
# --> 396                                     **fit_args)
#     397
#     398         # sometimes too many warnings...
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     488         else:
#     489             res = self.smooth(mlefit.params, transformed=False,
# --> 490                               cov_type=cov_type, cov_kwds=cov_kwds)
#     491
#     492             res.mlefit = mlefit
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in smooth(self, params, transformed, complex_step, cov_type, cov_kwds, return_ssm, results_class, results_wrapper_class, **kwargs)
#     604
#     605         # Get the state space output
# --> 606         result = self.ssm.smooth(complex_step=complex_step, **kwargs)
#     607
#     608         # Wrap in a results object
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_smoother.py in smooth(self, smoother_output, smooth_method, results, run_filter, prefix, complex_step, **kwargs)
#     381
#     382         # Run the filter
# --> 383         kfilter = self._filter(**kwargs)
#     384
#     385         # Create the results object
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     791             self._initialize_filter(
#     792                 filter_method, inversion_method, stability_method,
# --> 793                 conserve_memory, filter_timing, tolerance, loglikelihood_burn
#     794             )
#     795         )
#
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\tsa\statespace\kalman_filter.py in _initialize_filter(self, filter_method, inversion_method, stability_method, conserve_memory, tolerance, filter_timing, loglikelihood_burn)
#     390                 self._statespaces[prefix], filter_method, inversion_method,
#     391                 stability_method, conserve_memory, filter_timing, tolerance,
# --> 392                 loglikelihood_burn
#     393             )
#     394         # Otherwise, update the filter parameters
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.__init__()
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.set_filter_method()
#
# statsmodels\tsa\statespace\_kalman_filter.pyx in statsmodels.tsa.statespace._kalman_filter.dKalmanFilter.allocate_arrays()
#
# MemoryError: Unable to allocate array with shape (158, 158, 2790) and data type float64

# %%
# Real data
plot_frames = []
plot_frames.append(plot_real_data_train(df, n_history))
plot_frames.append(plot_real_data_test(df, pred_horizon))

# %%
plot_frames.append(forecast_gru(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))

# %%
plot_frames.append(forecast_fbprophet_additiv(pred_horizon))
plot_frames.append(forecast_fbprophet_boxcox(pred_horizon, fbprophet_boxcox_lam))
# Out:
#    cpuusage_ps
# 0       11.592
# 1        0.357
# 2        0.409
# 3        0.335
# 4        0.885
# training sarima took  89.33058142662048
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-273763eccf29> in <module>
#       4 plot_frames.append(forecast_mlp(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
#       5 plot_frames.append(forecast_cnn(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# ----> 6 plot_frames.append(forecast_sarima(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
#
# <ipython-input-26-8cdee8b56296> in forecast_sarima(df, n_history, pred_horizon)
#      21     model = SARIMAXResults.load('sarima.pkl')
#      22
# ---> 23     predictions = model.predict(start=start, end=end, dynamic=False).rename('SARIMAX Predictions' % n_history)
#      24
#      25     df_forecast = pd.DataFrame(predictions.values, columns=['SARIMA Predictions (1, 3, 0)(1, 1, 1, n_history) ' % n_history])
#
# TypeError: not all arguments converted during string formatting

# %%
plot_frames.append(forecast_cnn(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))

# %%
plot_frames.append(forecast_lstm(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))

# %%
plot_frames.append(forecast_mlp(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))

# %%
plot_frames.append(forecast_sarima(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
#    cpuusage_ps
# 0       11.592
# 1        0.357
# 2        0.409
# 3        0.335
# 4        0.885
# training sarima took  87.22043108940125

# %%
# Plot
plot_data(pd.concat(plot_frames, sort=True),'Vergleich ML-Models')
