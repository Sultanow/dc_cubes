# %%
import pandas as pd
import numpy as np
import pickle
import time
import os.path


from numpy import array
from datetime import timedelta  
from sklearn.preprocessing import StandardScaler
from keras.models import load_model
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.layers import Flatten
from keras.layers import LSTM, GRU
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
from sklearn.decomposition import PCA
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
from keras.layers import Conv1D
from keras.layers import MaxPooling1D
from fbprophet import Prophet
from scipy.stats import boxcox
from scipy.special import inv_boxcox
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.statespace.sarimax import SARIMAX, SARIMAXResults
from pmdarima import auto_arima
from datetime import timedelta 

import plotly
import chart_studio.plotly as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode

# %%
timestamp = "timestamp"
predictionColumn = "cpuusage_ps"

# %%
def plot_real_data_train(df, n_history):
    data = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    data.columns = ['date','Train Data']
    data.set_index('date', inplace=True)
    return data

def plot_real_data_test(df, pred_horizon):
    data = df.reset_index()[[timestamp, predictionColumn]]
    data = data.tail(pred_horizon)
    data.columns = ['date','Test Data']
    data.set_index('date', inplace=True)
    return data

# %%
plotly.offline.init_notebook_mode(connected=True)

def plot_data(df, plotTitle):
    map_plotly_series = dict()
    for columnName in df.columns:
        s = go.Scatter(
            x=df.index,
            y=df[columnName],
            name = columnName,
            hoverinfo='none',
            opacity = 0.8)
        map_plotly_series[columnName] = s
    data = list(map_plotly_series.values())
    layout = dict(
        title = plotTitle,
        xaxis = dict(
            range = [df.index.min(),df.index.max()])
    )
    fig = dict(data=data, layout=layout)
    plotly.offline.plot(fig, filename = plotTitle + '.html')
    return None
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def generate_index_forecast(df, df_forecast, pred_horizon):
    minutesBetweenMeasures = 15
    temp = df.reset_index()[[timestamp]]
    lastTrainDataTimeStamp = temp.tail(pred_horizon)[timestamp].iloc[0]
    nextTimeStamp = lastTrainDataTimeStamp
    for i in df_forecast.index:
        nextTimeStamp = nextTimeStamp + timedelta(minutes=minutesBetweenMeasures)
        df_forecast.at[i, 'date'] = nextTimeStamp
    df_forecast.set_index('date', inplace=True)
    return df_forecast 

def calculateMSE_RMSE(real, prediction):
    from sklearn.metrics import mean_squared_error
    from math import sqrt

    mse = mean_squared_error(real, prediction)
    rmse = sqrt(mse)
    
    print("********MSE, RMSE******")
    print("MSE: %f" % mse)
    print("RMSE: %f" % rmse)

# %%
# split a multivariate sequence into samples
# https://machinelearningmastery.com/how-to-develop-lstm-models-for-time-series-forecasting/
def split_sequences(sequences, n_steps_in, n_steps_out):
    X, y = list(), list()
    for i in range(len(sequences)):
        # find the end of this pattern
        end_ix = i + n_steps_in
        out_end_ix = end_ix + n_steps_out-1
        # check if we are beyond the dataset
        if out_end_ix > len(sequences):
            break
        # gather input and output parts of the pattern
        seq_x, seq_y = sequences[i:end_ix, :-1], sequences[end_ix-1:out_end_ix, -1]
        X.append(seq_x)
        y.append(seq_y)
    return array(X), array(y)

def split_train_test(x, y, pred_horizon):
    x_train = x[:-pred_horizon]
    x_test = x[-pred_horizon:]
    y_train = y[:-pred_horizon]
    y_test = y[-pred_horizon:]
    
    return x_train, x_test, y_train, y_test

# %%
def lstm_data_preprocessing(df, n_history, pred_horizon, performPCA):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    if(performPCA):
        pcaTransformer = PCA(0.95) # keep 95% variance
        pcaTransformer.fit(x)
        x = pcaTransformer.transform(x)
        print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' 
              % (len(df.columns)-1, pcaTransformer.n_components_))
        
    transformed_df = pd.DataFrame().from_records(x)
    transformed_df[predictionColumn] = y
    
    transformed_df.reset_index(inplace=True)
    x, y = split_sequences(transformed_df.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_lstm(df, n_history, pred_horizon, performPCA=False):
    preprocessingResultFile = "lstm_preprocessingResult.pkl"
    if not os.path.isfile(preprocessingResultFile):
        print("Preprocessing data...")
        # data split / preprocessing
        x, y, scalerX, scalerY = lstm_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon, performPCA=performPCA)
        print("SHAPES: ", x.shape, y.shape)
        numberOfFeatures = x.shape[2]
        x_train, x_test, y_train, y_test = split_train_test(x, y, pred_horizon)
        print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
        preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
        with(open(preprocessingResultFile, "wb")) as pkl:
            pickle.dump(preprocessingResult, pkl)
    else:
        with(open(preprocessingResultFile, "rb")) as pkl:
            x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
            
    # model definition
    model = Sequential()
    model.add(LSTM(75, activation='tanh', return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh", return_sequences=True))
    model.add(LSTM(75, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
    mc = ModelCheckpoint('lstm_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    # model train
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc], shuffle=False)
    print('''*** Model fitted ***''')
    return None

def forecast_lstm(df, n_history, pred_horizon):
    model = load_model('lstm_multistep_multivariate.h5')
    with(open("lstm_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1]
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    realValues = df[predictionColumn].tail(pred_horizon)
    calculateMSE_RMSE(realValues, (prediction[:,[0]]).reshape(prediction.shape[0])) #reshape from (480,1) to (480)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['LSTM Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def gru_data_preprocessing(df, n_history, pred_horizon, performPCA):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    if(performPCA):
        pcaTransformer = PCA(0.95) # keep 95% variance
        pcaTransformer.fit(x)
        x = pcaTransformer.transform(x)
        print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' 
              % (len(df.columns)-1, pcaTransformer.n_components_))
        
    transformed_df = pd.DataFrame().from_records(x)
    transformed_df[predictionColumn] = y
    
    transformed_df.reset_index(inplace=True)
    x, y = split_sequences(transformed_df.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_gru(df, n_history, pred_horizon, performPCA=False):
    preprocessingResultFile = "gru_preprocessingResult.pkl"
    if not os.path.isfile(preprocessingResultFile):
        print("Preprocessing data...")
        # data split / preprocessing
        x, y, scalerX, scalerY = gru_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon, performPCA=performPCA)
        print("SHAPES: ", x.shape, y.shape)
        numberOfFeatures = x.shape[2]
        x_train, x_test, y_train, y_test = split_train_test(x, y, pred_horizon)
        print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
        preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
        
        with(open(preprocessingResultFile, "wb")) as pkl:
            pickle.dump(preprocessingResult, pkl)
    else:
        with(open(preprocessingResultFile, "rb")) as pkl:
            x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
            
    # model definition
    model = Sequential()
    model.add(GRU(50, activation='relu', return_sequences=True, input_shape=(n_history, numberOfFeatures)))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu", return_sequences=True))
    model.add(GRU(50, activation="relu"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse', metrics=['mse'])
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
    mc = ModelCheckpoint('gru_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    # model train
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc], shuffle=False)
    print('''*** Model fitted ***''')
    return None

def forecast_gru(df, n_history, pred_horizon):
    model = load_model('gru_multistep_multivariate.h5')
    with(open("gru_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1]
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    realValues = df[predictionColumn].tail(pred_horizon)
    calculateMSE_RMSE(realValues, (prediction[:,[0]]).reshape(prediction.shape[0])) #reshape from (480,1) to (480)
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['GRU Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def mlp_data_preprocessing(df, n_history, pred_horizon, performPCA):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
         
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    if(performPCA):
        pcaTransformer = PCA(0.95) # keep 95% variance
        pcaTransformer.fit(x)
        x = pcaTransformer.transform(x)
        print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' 
              % (len(df.columns)-1, pcaTransformer.n_components_))
        
    transformed_df = pd.DataFrame().from_records(x)
    transformed_df[predictionColumn] = y
    
    transformed_df.reset_index(inplace=True)
    x, y = split_sequences(transformed_df.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY


def train_mlp(df, n_history, pred_horizon, performPCA=True):
    preprocessingResultFile = "mlp_preprocessingResult.pkl"
    if not os.path.isfile(preprocessingResultFile):
        print("Preprocessing data...")
        x, y, scalerX, scalerY = mlp_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon, performPCA=performPCA)
        print("SHAPES: ", x.shape, y.shape)
        x_train, x_test, y_train, y_test = split_train_test(x, y, pred_horizon)
        print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
        n_input = x_train.shape[1] * x_train.shape[2]
        x_train = x_train.reshape((x_train.shape[0], n_input))
        n_neurons = int((n_input + pred_horizon))
        preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
        with(open(preprocessingResultFile, "wb")) as pkl:
            pickle.dump(preprocessingResult, pkl)
    else:
        with(open(preprocessingResultFile, "rb")) as pkl:
            x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
        
    model = Sequential()
    model.add(Dense(n_neurons, activation='tanh', input_dim=n_input))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(n_neurons, activation="tanh"))
    model.add(Dense(pred_horizon))
    model.compile(optimizer='adam', loss='mse')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
    mc = ModelCheckpoint('mlp_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)    
    model.fit(x_train, y_train, validation_split=0.1, epochs=200, callbacks=[es, mc], shuffle=False)
    return None

def forecast_mlp(df, n_history, pred_horizon):
    model_mlp = load_model('mlp_multistep_multivariate.h5')
    with(open("mlp_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)

    numberOfFeatures =  x_train.shape[1] // n_history # was reshaped to featureNumber * n_history, so divide it to get number of features = 61
    pred_input = x_train[-1:]
    n_input = pred_input.shape[0] * pred_input.shape[1]
    pred_input = pred_input.reshape((1,n_input))
    
    prediction = model_mlp.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    realValues = df[predictionColumn].tail(pred_horizon)
    calculateMSE_RMSE(realValues, (prediction[:,[0]]).reshape(prediction.shape[0])) #reshape from (480,1) to (480)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['MLP Multistep Multivariate'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def cnn_data_preprocessing(df, n_history, pred_horizon, performPCA):
    if not df.index.name == timestamp:
        dataset = df.set_index(timestamp)
    else:
        dataset = df
    
    y = dataset[predictionColumn].copy()
    x = dataset.drop(columns=predictionColumn)
    
    scalerX = StandardScaler()
    scalerX.fit(x)
    x = scalerX.transform(x)
    scalerY = StandardScaler()
   # .reshape(-1, 1) # needed for standardScaler
    scalerY.fit(y.values.reshape(-1,1))
    y = scalerY.transform(y.values.reshape(-1,1))
    
    if(performPCA):
        pcaTransformer = PCA(0.95) # keep 95% variance
        pcaTransformer.fit(x)
        x = pcaTransformer.transform(x)
        print(''' *** PCA Result***\n Started with %d features, reduced to %d features''' 
              % (len(df.columns)-1, pcaTransformer.n_components_))
        
    transformed_df = pd.DataFrame().from_records(x)
    transformed_df[predictionColumn] = y
    
    transformed_df.reset_index(inplace=True)
    x, y = split_sequences(transformed_df.values, n_steps_in=n_history, n_steps_out=pred_horizon)
    return x, y, scalerX, scalerY

def train_cnn(df, pred_horizon, n_history, performPCA=True):
    preprocessingResultFile = "cnn_preprocessingResult.pkl"
    if not os.path.isfile(preprocessingResultFile):
        print("Preprocessing data...")
        x, y, scalerX, scalerY = cnn_data_preprocessing(df, n_history=n_history, pred_horizon=pred_horizon, performPCA=performPCA)
        print("SHAPES: ", x.shape, y.shape)
        numberOfFeatures = x.shape[2]
        x_train, x_test, y_train, y_test = split_train_test(x, y, pred_horizon)
        print("Shapes: xtr, xte, ytr, yte: ", x_train.shape, x_test.shape, y_train.shape, y_test.shape)
        preprocessingResult = [x_train, x_test, y_train, y_test, scalerX, scalerY]
        with(open(preprocessingResultFile, "wb")) as pkl:
            pickle.dump(preprocessingResult, pkl)
    else:
        with(open(preprocessingResultFile, "rb")) as pkl:
            x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
              
    model = Sequential()
    model.add(Conv1D(filters=150, kernel_size=2, activation='tanh', input_shape=(n_history, numberOfFeatures)))
    model.add(MaxPooling1D(pool_size=2))
    model.add(Conv1D(filters=40, kernel_size=2, activation='tanh'))
    model.add(MaxPooling1D(pool_size=2))
    model.add(LSTM(75, activation='tanh'))
    model.add(Dense(pred_horizon))
    model.compile(loss='mse', optimizer='adam')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=25)
    mc = ModelCheckpoint('cnn_multistep_multivariate.h5', monitor='val_loss' , mode='min', verbose=1, save_best_only=True)
    model.fit(x_train, y_train,  validation_split=0.1, epochs=200, callbacks=[es, mc], shuffle=False)
    print('''*** Model fitted ***''') 
    return None

def forecast_cnn(df, n_history, pred_horizon):
    model = load_model('cnn_multistep_multivariate.h5')
    with(open("cnn_preprocessingResult.pkl", "rb")) as pkl:
        x_train, x_test, y_train, y_test, scalerX, scalerY = pickle.load(pkl)
    numberOfFeatures = x_train.shape[2]
    pred_input = x_train[-1] 
    pred_input = pred_input.reshape((1, pred_input.shape[0],pred_input.shape[1]))
    
    prediction = model.predict(pred_input)
    prediction = prediction.reshape((pred_horizon,1))
    prediction = np.hstack((prediction, np.zeros((prediction.shape[0], numberOfFeatures-1), dtype=prediction.dtype)))
    prediction = scalerY.inverse_transform(prediction)
    
    realValues = df[predictionColumn].tail(pred_horizon)
    calculateMSE_RMSE(realValues, (prediction[:,[0]]).reshape(prediction.shape[0])) #reshape from (480,1) to (480)
    
    df_forecast = pd.DataFrame(prediction[:,[0]], columns=['CNN'])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
def train_fbprophet_additiv(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_additiv.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return None

def train_fbprophet_boxcox(df, n_history):
    train = df.reset_index()[[timestamp, predictionColumn]][:-n_history]
    train.columns = ["ds","y"]
    train["y"] = pd.to_numeric(train["y"])
    train['y'], lam = boxcox(train['y'])
    m = Prophet(weekly_seasonality=True, yearly_seasonality=True)
    m.fit(train)
    with open('fbprophet_boxcox.pckl', 'wb') as fout:
        pickle.dump(m, fout)
    return lam

def forecast_fbprophet_additiv(pred_horizon):
    with open('fbprophet_additiv.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet = m.predict(future)[['ds', 'yhat']]
    forecast_prophet.columns = ['date','FBProphet without Box-Cox-Transform']
    forecast_prophet.set_index('date', inplace=True)
    return forecast_prophet.tail(pred_horizon) 

def forecast_fbprophet_boxcox(pred_horizon, lam):
    with open('fbprophet_boxcox.pckl', 'rb') as fin:
        m = pickle.load(fin)
    future = m.make_future_dataframe(periods=pred_horizon, freq='15min')
    forecast_prophet_box_cox = m.predict(future)[['ds', 'yhat']]
    forecast_prophet_box_cox['yhat'] = forecast_prophet_box_cox['yhat'].apply(lambda x: inv_boxcox(x, lam))
    forecast_prophet_box_cox.columns = ['date','FBProphet with Box-Cox-Transform']
    forecast_prophet_box_cox.set_index('date', inplace=True)
    return forecast_prophet_box_cox.tail(pred_horizon)

# %%
def train_sarima(df, n_history, pred_horizon, order, seasonal_order):
    trainingData = pd.DataFrame(df[predictionColumn], columns=[predictionColumn])
    model = SARIMAX(trainingData[predictionColumn],order=order, seasonal_order=seasonal_order, start_p = 1, start_q = 1)
    fit = model.fit()
    fit.save("sarima.pkl")

    return None    

def forecast_sarima(df, n_history, pred_horizon):

    start = len(df[:-pred_horizon]) - 1
    end = start + pred_horizon - 1
    starttime = time.time()
    
    order = (1, 3, 0)
    seasonal_order = (1, 1, 1, n_history) #last parameter should be 52 for weekly saisonality
    train_sarima(df, n_history = n_history, pred_horizon=pred_horizon, order=order, seasonal_order=seasonal_order)
    print("training sarima took ", time.time() - starttime)

    model = SARIMAXResults.load('sarima.pkl')
    
    predictions = model.predict(start=start, end=end, dynamic=False).rename('SARIMAX Predictions')
    
    df_forecast = pd.DataFrame(predictions.values, columns=['SARIMA Predictions (1, 3, 0)(1, 1, 1, %d) ' % n_history])
    return generate_index_forecast(df, df_forecast, pred_horizon=pred_horizon)

# %%
# Declaration
skip_csv_rows = 0
measureInterval = 15 #min
daysToPredict = 5
pred_horizon = (60//measureInterval) * 24 * daysToPredict #5 days (4*24*5), timestep = 15min
hours_history = 8
n_history = (60//measureInterval)*hours_history 

# Read data from pickle file
with open("./4week_transformed_droppedErrors_filled.pkl", "rb") as pickleFile:
    df = pickle.load(pickleFile)

# %%
df = df.reset_index()

# %%
df[predictionColumn] = pd.to_numeric(df[predictionColumn])

# %%
# generate features/columns from the timestamp
df["dayOfWeek"] = df[timestamp].map(lambda x: x.dayofweek)
df["isWeekend"] = df.dayOfWeek.map(lambda x: 0 if (x < 5) else 1) # saturday.dayofweek = 5, monday=0
df["weekofyear"] = df[timestamp].map(lambda x: x.weekofyear)
df["hour"] = df[timestamp].map(lambda x: x.hour)
df["minute"]= df[timestamp].map(lambda x: x.minute)

# %%
# # time windows for binning, eg 0-6 a.m., 17-20 p.m.
# bins = [(0,6),(6,12),(12,17),(17,20),(20,24)]
# pdBins = pd.IntervalIndex.from_tuples(bins)

# df["hourBin"] = pd.cut(data.hour, pdBins, include_lowest=True)

# %%
starttime = time.time()
train_fbprophet_additiv(df, pred_horizon)
print("training prophet without boxcox took ", time.time() - starttime)
starttime = time.time()
fbprophet_boxcox_lam = train_fbprophet_boxcox(df, pred_horizon)
print("training prophet with boxcox took ", time.time() - starttime)
# Out:
# training prophet without boxcox took  1.3000037670135498
# training prophet with boxcox took  1.0710952281951904

# %%
starttime = time.time()
train_lstm(df.copy().reset_index(), n_history=n_history, pred_horizon=pred_horizon)
print("training lstm took ", time.time() - starttime)
# Out:
# SHAPES:  (2279, 32, 187) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 187) (480, 32, 187) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.3024 - val_loss: 0.8720
#
# Epoch 00001: val_loss improved from inf to 0.87203, saving model to lstm_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3020 - val_loss: 0.8812
#
# Epoch 00002: val_loss did not improve from 0.87203
# Epoch 3/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3024 - val_loss: 0.8828
#
# Epoch 00003: val_loss did not improve from 0.87203
# Epoch 4/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3022 - val_loss: 0.8717
#
# Epoch 00004: val_loss improved from 0.87203 to 0.87171, saving model to lstm_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3019 - val_loss: 0.8808
#
# Epoch 00005: val_loss did not improve from 0.87171
# Epoch 6/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3034 - val_loss: 0.8779
#
# Epoch 00006: val_loss did not improve from 0.87171
# Epoch 7/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3039 - val_loss: 0.8730
#
# Epoch 00007: val_loss did not improve from 0.87171
# Epoch 8/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3040 - val_loss: 0.8704
#
# Epoch 00008: val_loss improved from 0.87171 to 0.87036, saving model to lstm_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3036 - val_loss: 0.8710
#
# Epoch 00009: val_loss did not improve from 0.87036
# Epoch 10/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3043 - val_loss: 0.8706
#
# Epoch 00010: val_loss did not improve from 0.87036
# Epoch 11/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3038 - val_loss: 0.8703
#
# Epoch 00011: val_loss improved from 0.87036 to 0.87026, saving model to lstm_multistep_multivariate.h5
# Epoch 12/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3033 - val_loss: 0.8700
#
# Epoch 00012: val_loss improved from 0.87026 to 0.87003, saving model to lstm_multistep_multivariate.h5
# Epoch 13/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3032 - val_loss: 0.8699
#
# Epoch 00013: val_loss improved from 0.87003 to 0.86987, saving model to lstm_multistep_multivariate.h5
# Epoch 14/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3031 - val_loss: 0.8698
#
# Epoch 00014: val_loss improved from 0.86987 to 0.86976, saving model to lstm_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.3030 - val_loss: 0.8695
#
# Epoch 00015: val_loss improved from 0.86976 to 0.86946, saving model to lstm_multistep_multivariate.h5
# Epoch 16/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2907 - val_loss: 0.8176
#
# Epoch 00016: val_loss improved from 0.86946 to 0.81757, saving model to lstm_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2706 - val_loss: 0.8061
#
# Epoch 00017: val_loss improved from 0.81757 to 0.80611, saving model to lstm_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2670 - val_loss: 0.8080
#
# Epoch 00018: val_loss did not improve from 0.80611
# Epoch 19/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2667 - val_loss: 0.8245
#
# Epoch 00019: val_loss did not improve from 0.80611
# Epoch 20/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2568 - val_loss: 0.7827
#
# Epoch 00020: val_loss improved from 0.80611 to 0.78266, saving model to lstm_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.2330 - val_loss: 0.7392
#
# Epoch 00021: val_loss improved from 0.78266 to 0.73917, saving model to lstm_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.1928 - val_loss: 0.7010
#
# Epoch 00022: val_loss improved from 0.73917 to 0.70102, saving model to lstm_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.1619 - val_loss: 0.6516
#
# Epoch 00023: val_loss improved from 0.70102 to 0.65163, saving model to lstm_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.1200 - val_loss: 0.6412
#
# Epoch 00024: val_loss improved from 0.65163 to 0.64121, saving model to lstm_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0838 - val_loss: 0.5532
#
# Epoch 00025: val_loss improved from 0.64121 to 0.55318, saving model to lstm_multistep_multivariate.h5
# Epoch 26/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0993 - val_loss: 0.5290
#
# Epoch 00026: val_loss improved from 0.55318 to 0.52900, saving model to lstm_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0189 - val_loss: 0.4919
#
# Epoch 00027: val_loss improved from 0.52900 to 0.49189, saving model to lstm_multistep_multivariate.h5
# Epoch 28/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9888 - val_loss: 0.4638
#
# Epoch 00028: val_loss improved from 0.49189 to 0.46382, saving model to lstm_multistep_multivariate.h5
# Epoch 29/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9661 - val_loss: 0.4437
#
# Epoch 00029: val_loss improved from 0.46382 to 0.44372, saving model to lstm_multistep_multivariate.h5
# Epoch 30/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9481 - val_loss: 0.4290
#
# Epoch 00030: val_loss improved from 0.44372 to 0.42905, saving model to lstm_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9362 - val_loss: 0.4163
#
# Epoch 00031: val_loss improved from 0.42905 to 0.41627, saving model to lstm_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9273 - val_loss: 0.4106
#
# Epoch 00032: val_loss improved from 0.41627 to 0.41061, saving model to lstm_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9210 - val_loss: 0.4060
#
# Epoch 00033: val_loss improved from 0.41061 to 0.40597, saving model to lstm_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9177 - val_loss: 0.4041
#
# Epoch 00034: val_loss improved from 0.40597 to 0.40410, saving model to lstm_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9158 - val_loss: 0.4028
#
# Epoch 00035: val_loss improved from 0.40410 to 0.40283, saving model to lstm_multistep_multivariate.h5
# Epoch 36/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9149 - val_loss: 0.4015
#
# Epoch 00036: val_loss improved from 0.40283 to 0.40154, saving model to lstm_multistep_multivariate.h5
# Epoch 37/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9143 - val_loss: 0.4011
#
# Epoch 00037: val_loss improved from 0.40154 to 0.40105, saving model to lstm_multistep_multivariate.h5
# Epoch 38/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9134 - val_loss: 0.4005
#
# Epoch 00038: val_loss improved from 0.40105 to 0.40055, saving model to lstm_multistep_multivariate.h5
# Epoch 39/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9130 - val_loss: 0.4004
#
# Epoch 00039: val_loss improved from 0.40055 to 0.40036, saving model to lstm_multistep_multivariate.h5
# Epoch 40/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9128 - val_loss: 0.4003
#
# Epoch 00040: val_loss improved from 0.40036 to 0.40027, saving model to lstm_multistep_multivariate.h5
# Epoch 41/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9126 - val_loss: 0.4002
#
# Epoch 00041: val_loss improved from 0.40027 to 0.40021, saving model to lstm_multistep_multivariate.h5
# Epoch 42/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9125 - val_loss: 0.4001
#
# Epoch 00042: val_loss improved from 0.40021 to 0.40009, saving model to lstm_multistep_multivariate.h5
# Epoch 43/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9124 - val_loss: 0.4002
#
# Epoch 00043: val_loss did not improve from 0.40009
# Epoch 44/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9123 - val_loss: 0.4000
#
# Epoch 00044: val_loss improved from 0.40009 to 0.40000, saving model to lstm_multistep_multivariate.h5
# Epoch 45/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9125 - val_loss: 0.3999
#
# Epoch 00045: val_loss improved from 0.40000 to 0.39994, saving model to lstm_multistep_multivariate.h5
# Epoch 46/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9122 - val_loss: 0.3999
#
# Epoch 00046: val_loss improved from 0.39994 to 0.39989, saving model to lstm_multistep_multivariate.h5
# Epoch 47/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9121 - val_loss: 0.3998
#
# Epoch 00047: val_loss improved from 0.39989 to 0.39980, saving model to lstm_multistep_multivariate.h5
# Epoch 48/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9120 - val_loss: 0.3997
#
# Epoch 00048: val_loss improved from 0.39980 to 0.39973, saving model to lstm_multistep_multivariate.h5
# Epoch 49/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9120 - val_loss: 0.3997
#
# Epoch 00049: val_loss improved from 0.39973 to 0.39968, saving model to lstm_multistep_multivariate.h5
# Epoch 50/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9119 - val_loss: 0.3997
#
# Epoch 00050: val_loss improved from 0.39968 to 0.39965, saving model to lstm_multistep_multivariate.h5
# Epoch 51/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9119 - val_loss: 0.3997
#
# Epoch 00051: val_loss did not improve from 0.39965
# Epoch 52/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9129 - val_loss: 0.5950
#
# Epoch 00052: val_loss did not improve from 0.39965
# Epoch 53/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.0831 - val_loss: 0.4943
#
# Epoch 00053: val_loss did not improve from 0.39965
# Epoch 54/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0028 - val_loss: 0.4639
#
# Epoch 00054: val_loss did not improve from 0.39965
# Epoch 55/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9745 - val_loss: 0.4996
#
# Epoch 00055: val_loss did not improve from 0.39965
# Epoch 56/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9571 - val_loss: 0.4361
#
# Epoch 00056: val_loss did not improve from 0.39965
# Epoch 57/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9495 - val_loss: 0.4288
#
# Epoch 00057: val_loss did not improve from 0.39965
# Epoch 58/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9351 - val_loss: 0.4166
#
# Epoch 00058: val_loss did not improve from 0.39965
# Epoch 59/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9247 - val_loss: 0.4095
#
# Epoch 00059: val_loss did not improve from 0.39965
# Epoch 60/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9203 - val_loss: 0.4053
#
# Epoch 00060: val_loss did not improve from 0.39965
# Epoch 61/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9175 - val_loss: 0.4029
#
# Epoch 00061: val_loss did not improve from 0.39965
# Epoch 62/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9157 - val_loss: 0.4013
#
# Epoch 00062: val_loss did not improve from 0.39965
# Epoch 63/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9145 - val_loss: 0.4003
#
# Epoch 00063: val_loss did not improve from 0.39965
# Epoch 64/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9137 - val_loss: 0.3998
#
# Epoch 00064: val_loss did not improve from 0.39965
# Epoch 65/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9132 - val_loss: 0.3994
#
# Epoch 00065: val_loss improved from 0.39965 to 0.39941, saving model to lstm_multistep_multivariate.h5
# Epoch 66/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9129 - val_loss: 0.3992
#
# Epoch 00066: val_loss improved from 0.39941 to 0.39922, saving model to lstm_multistep_multivariate.h5
# Epoch 67/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 0.9126 - val_loss: 0.3991
#
# Epoch 00067: val_loss improved from 0.39922 to 0.39914, saving model to lstm_multistep_multivariate.h5
# Epoch 68/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9125 - val_loss: 0.3990
#
# Epoch 00068: val_loss improved from 0.39914 to 0.39901, saving model to lstm_multistep_multivariate.h5
# Epoch 69/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9124 - val_loss: 0.3989
#
# Epoch 00069: val_loss improved from 0.39901 to 0.39890, saving model to lstm_multistep_multivariate.h5
# Epoch 70/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9122 - val_loss: 0.3988
#
# Epoch 00070: val_loss improved from 0.39890 to 0.39885, saving model to lstm_multistep_multivariate.h5
# Epoch 71/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9121 - val_loss: 0.3988
#
# Epoch 00071: val_loss did not improve from 0.39885
# Epoch 72/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9122 - val_loss: 0.3987
#
# Epoch 00072: val_loss improved from 0.39885 to 0.39868, saving model to lstm_multistep_multivariate.h5
# Epoch 73/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9121 - val_loss: 0.3990
#
# Epoch 00073: val_loss did not improve from 0.39868
# Epoch 74/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9121 - val_loss: 0.3989
#
# Epoch 00074: val_loss did not improve from 0.39868
# Epoch 75/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9120 - val_loss: 0.3987
#
# Epoch 00075: val_loss did not improve from 0.39868
# Epoch 76/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9119 - val_loss: 0.3987
#
# Epoch 00076: val_loss did not improve from 0.39868
# Epoch 77/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9118 - val_loss: 0.3987
#
# Epoch 00077: val_loss did not improve from 0.39868
# Epoch 78/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9118 - val_loss: 0.3986
#
# Epoch 00078: val_loss improved from 0.39868 to 0.39864, saving model to lstm_multistep_multivariate.h5
# Epoch 79/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 0.9117 - val_loss: 0.3987
#
# Epoch 00079: val_loss did not improve from 0.39864
# Epoch 80/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9117 - val_loss: 0.3986
#
# Epoch 00080: val_loss improved from 0.39864 to 0.39861, saving model to lstm_multistep_multivariate.h5
# Epoch 81/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9116 - val_loss: 0.3986
#
# Epoch 00081: val_loss did not improve from 0.39861
# Epoch 82/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9116 - val_loss: 0.3986
#
# Epoch 00082: val_loss improved from 0.39861 to 0.39859, saving model to lstm_multistep_multivariate.h5
# Epoch 83/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9116 - val_loss: 0.3986
#
# Epoch 00083: val_loss did not improve from 0.39859
# Epoch 84/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9115 - val_loss: 0.3986
#
# Epoch 00084: val_loss did not improve from 0.39859
# Epoch 85/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9115 - val_loss: 0.3986
#
# Epoch 00085: val_loss did not improve from 0.39859
# Epoch 86/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9115 - val_loss: 0.3995
#
# Epoch 00086: val_loss did not improve from 0.39859
# Epoch 87/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9114 - val_loss: 0.4005
#
# Epoch 00087: val_loss did not improve from 0.39859
# Epoch 88/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9158 - val_loss: 0.3994
#
# Epoch 00088: val_loss did not improve from 0.39859
# Epoch 89/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9124 - val_loss: 0.3986
#
# Epoch 00089: val_loss did not improve from 0.39859
# Epoch 90/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9116 - val_loss: 0.3985
#
# Epoch 00090: val_loss improved from 0.39859 to 0.39848, saving model to lstm_multistep_multivariate.h5
# Epoch 91/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9114 - val_loss: 0.3984
#
# Epoch 00091: val_loss improved from 0.39848 to 0.39842, saving model to lstm_multistep_multivariate.h5
# Epoch 92/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9114 - val_loss: 0.3984
#
# Epoch 00092: val_loss improved from 0.39842 to 0.39840, saving model to lstm_multistep_multivariate.h5
# Epoch 93/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9113 - val_loss: 0.3984
#
# Epoch 00093: val_loss improved from 0.39840 to 0.39840, saving model to lstm_multistep_multivariate.h5
# Epoch 94/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9113 - val_loss: 0.3984
#
# Epoch 00094: val_loss improved from 0.39840 to 0.39838, saving model to lstm_multistep_multivariate.h5
# Epoch 95/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9112 - val_loss: 0.3985
#
# Epoch 00095: val_loss did not improve from 0.39838
# Epoch 96/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9112 - val_loss: 0.3984
#
# Epoch 00096: val_loss did not improve from 0.39838
# Epoch 97/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9112 - val_loss: 0.3984
#
# Epoch 00097: val_loss improved from 0.39838 to 0.39835, saving model to lstm_multistep_multivariate.h5
# Epoch 98/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9112 - val_loss: 0.3985
#
# Epoch 00098: val_loss did not improve from 0.39835
# Epoch 99/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9112 - val_loss: 0.3984
#
# Epoch 00099: val_loss did not improve from 0.39835
# Epoch 100/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9110 - val_loss: 0.3986
#
# Epoch 00100: val_loss did not improve from 0.39835
# Epoch 101/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9110 - val_loss: 0.3988
#
# Epoch 00101: val_loss did not improve from 0.39835
# Epoch 102/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9110 - val_loss: 0.3992
#
# Epoch 00102: val_loss did not improve from 0.39835
# Epoch 103/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9110 - val_loss: 0.3988
#
# Epoch 00103: val_loss did not improve from 0.39835
# Epoch 104/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9107 - val_loss: 0.3996
#
# Epoch 00104: val_loss did not improve from 0.39835
# Epoch 105/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9116 - val_loss: 0.4007
#
# Epoch 00105: val_loss did not improve from 0.39835
# Epoch 106/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.1624 - val_loss: 0.5824
#
# Epoch 00106: val_loss did not improve from 0.39835
# Epoch 107/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 1.0260 - val_loss: 0.4706
#
# Epoch 00107: val_loss did not improve from 0.39835
# Epoch 108/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9486 - val_loss: 0.4241
#
# Epoch 00108: val_loss did not improve from 0.39835
# Epoch 109/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9263 - val_loss: 0.4106
#
# Epoch 00109: val_loss did not improve from 0.39835
# Epoch 110/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9188 - val_loss: 0.4050
#
# Epoch 00110: val_loss did not improve from 0.39835
# Epoch 111/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9156 - val_loss: 0.4025
#
# Epoch 00111: val_loss did not improve from 0.39835
# Epoch 112/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9140 - val_loss: 0.4013
#
# Epoch 00112: val_loss did not improve from 0.39835
# Epoch 113/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9133 - val_loss: 0.4006
#
# Epoch 00113: val_loss did not improve from 0.39835
# Epoch 114/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9128 - val_loss: 0.4003
#
# Epoch 00114: val_loss did not improve from 0.39835
# Epoch 115/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9126 - val_loss: 0.4000
#
# Epoch 00115: val_loss did not improve from 0.39835
# Epoch 116/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9124 - val_loss: 0.3999
#
# Epoch 00116: val_loss did not improve from 0.39835
# Epoch 117/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9122 - val_loss: 0.3998
#
# Epoch 00117: val_loss did not improve from 0.39835
# Epoch 118/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9120 - val_loss: 0.3997
#
# Epoch 00118: val_loss did not improve from 0.39835
# Epoch 119/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9119 - val_loss: 0.3997
#
# Epoch 00119: val_loss did not improve from 0.39835
# Epoch 120/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9118 - val_loss: 0.3997
#
# Epoch 00120: val_loss did not improve from 0.39835
# Epoch 121/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 0.9117 - val_loss: 0.3998
#
# Epoch 00121: val_loss did not improve from 0.39835
# Epoch 122/200
# 1619/1619 [==============================] - 6s 4ms/step - loss: 0.9116 - val_loss: 0.3995
#
# Epoch 00122: val_loss did not improve from 0.39835
# Epoch 00122: early stopping
# *** Model fitted ***
# training lstm took  923.8580598831177

# %%
starttime = time.time()
train_mlp(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training mlp took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 187 features, reduced to 62 features
# SHAPES:  (2279, 32, 63) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 63) (480, 32, 63) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.7173 - val_loss: 1.3645
#
# Epoch 00001: val_loss improved from inf to 1.36453, saving model to mlp_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.6051 - val_loss: 1.2305
#
# Epoch 00002: val_loss improved from 1.36453 to 1.23053, saving model to mlp_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5827 - val_loss: 1.2412
#
# Epoch 00003: val_loss did not improve from 1.23053
# Epoch 4/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5839 - val_loss: 1.2400
#
# Epoch 00004: val_loss did not improve from 1.23053
# Epoch 5/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5826 - val_loss: 1.2362
#
# Epoch 00005: val_loss did not improve from 1.23053
# Epoch 6/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5817 - val_loss: 1.2339
#
# Epoch 00006: val_loss did not improve from 1.23053
# Epoch 7/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5815 - val_loss: 1.2317
#
# Epoch 00007: val_loss did not improve from 1.23053
# Epoch 8/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5811 - val_loss: 1.2320
#
# Epoch 00008: val_loss did not improve from 1.23053
# Epoch 9/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5811 - val_loss: 1.2320
#
# Epoch 00009: val_loss did not improve from 1.23053
# Epoch 10/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5811 - val_loss: 1.2318
#
# Epoch 00010: val_loss did not improve from 1.23053
# Epoch 11/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5809 - val_loss: 1.2320
#
# Epoch 00011: val_loss did not improve from 1.23053
# Epoch 12/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5809 - val_loss: 1.2314
#
# Epoch 00012: val_loss did not improve from 1.23053
# Epoch 13/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5807 - val_loss: 1.2314
#
# Epoch 00013: val_loss did not improve from 1.23053
# Epoch 14/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5806 - val_loss: 1.2311
#
# Epoch 00014: val_loss did not improve from 1.23053
# Epoch 15/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5806 - val_loss: 1.2326
#
# Epoch 00015: val_loss did not improve from 1.23053
# Epoch 16/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5807 - val_loss: 1.2303
#
# Epoch 00016: val_loss improved from 1.23053 to 1.23031, saving model to mlp_multistep_multivariate.h5
# Epoch 17/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5804 - val_loss: 1.2305
#
# Epoch 00017: val_loss did not improve from 1.23031
# Epoch 18/200
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.5804 - val_loss: 1.2304
#
# Epoch 00018: val_loss did not improve from 1.23031
# Epoch 19/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5803 - val_loss: 1.2304
#
# Epoch 00019: val_loss did not improve from 1.23031
# Epoch 20/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2303
#
# Epoch 00020: val_loss did not improve from 1.23031
# Epoch 21/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2302
#
# Epoch 00021: val_loss improved from 1.23031 to 1.23021, saving model to mlp_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2299
#
# Epoch 00022: val_loss improved from 1.23021 to 1.22995, saving model to mlp_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2300
#
# Epoch 00023: val_loss did not improve from 1.22995
# Epoch 24/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2305
#
# Epoch 00024: val_loss did not improve from 1.22995
# Epoch 25/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2298
#
# Epoch 00025: val_loss improved from 1.22995 to 1.22976, saving model to mlp_multistep_multivariate.h5
# Epoch 26/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5805 - val_loss: 1.2297
#
# Epoch 00026: val_loss improved from 1.22976 to 1.22972, saving model to mlp_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2295
#
# Epoch 00027: val_loss improved from 1.22972 to 1.22946, saving model to mlp_multistep_multivariate.h5
# Epoch 28/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5803 - val_loss: 1.2307
#
# Epoch 00028: val_loss did not improve from 1.22946
# Epoch 29/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5804 - val_loss: 1.2295
#
# Epoch 00029: val_loss did not improve from 1.22946
# Epoch 30/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2296
#
# Epoch 00030: val_loss did not improve from 1.22946
# Epoch 31/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2296
#
# Epoch 00031: val_loss did not improve from 1.22946
# Epoch 32/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2293
#
# Epoch 00032: val_loss improved from 1.22946 to 1.22933, saving model to mlp_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2296
#
# Epoch 00033: val_loss did not improve from 1.22933
# Epoch 34/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5801 - val_loss: 1.2294
#
# Epoch 00034: val_loss did not improve from 1.22933
# Epoch 35/200
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.5803 - val_loss: 1.2295
#
# Epoch 00035: val_loss did not improve from 1.22933
# Epoch 36/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2293
#
# Epoch 00036: val_loss improved from 1.22933 to 1.22928, saving model to mlp_multistep_multivariate.h5
# Epoch 37/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5801 - val_loss: 1.2294
#
# Epoch 00037: val_loss did not improve from 1.22928
# Epoch 38/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5801 - val_loss: 1.2293
#
# Epoch 00038: val_loss improved from 1.22928 to 1.22926, saving model to mlp_multistep_multivariate.h5
# Epoch 39/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5802 - val_loss: 1.2293
#
# Epoch 00039: val_loss did not improve from 1.22926
# Epoch 40/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2292
#
# Epoch 00040: val_loss improved from 1.22926 to 1.22925, saving model to mlp_multistep_multivariate.h5
# Epoch 41/200
# 1619/1619 [==============================] - 27s 17ms/step - loss: 1.5800 - val_loss: 1.2293
#
# Epoch 00041: val_loss did not improve from 1.22925
# Epoch 42/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2299
#
# Epoch 00042: val_loss did not improve from 1.22925
# Epoch 43/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2292
#
# Epoch 00043: val_loss improved from 1.22925 to 1.22918, saving model to mlp_multistep_multivariate.h5
# Epoch 44/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2291
#
# Epoch 00044: val_loss improved from 1.22918 to 1.22914, saving model to mlp_multistep_multivariate.h5
# Epoch 45/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2290
#
# Epoch 00045: val_loss improved from 1.22914 to 1.22900, saving model to mlp_multistep_multivariate.h5
# Epoch 46/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5801 - val_loss: 1.2288
#
# Epoch 00046: val_loss improved from 1.22900 to 1.22883, saving model to mlp_multistep_multivariate.h5
# Epoch 47/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2291
#
# Epoch 00047: val_loss did not improve from 1.22883
# Epoch 48/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2291
#
# Epoch 00048: val_loss did not improve from 1.22883
# Epoch 49/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2287
#
# Epoch 00049: val_loss improved from 1.22883 to 1.22868, saving model to mlp_multistep_multivariate.h5
# Epoch 50/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5799 - val_loss: 1.2291
#
# Epoch 00050: val_loss did not improve from 1.22868
# Epoch 51/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2291
#
# Epoch 00051: val_loss did not improve from 1.22868
# Epoch 52/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5801 - val_loss: 1.2291
#
# Epoch 00052: val_loss did not improve from 1.22868
# Epoch 53/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5802 - val_loss: 1.2291
#
# Epoch 00053: val_loss did not improve from 1.22868
# Epoch 54/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2290
#
# Epoch 00054: val_loss did not improve from 1.22868
# Epoch 55/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5800 - val_loss: 1.2290
#
# Epoch 00055: val_loss did not improve from 1.22868
# Epoch 56/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00056: val_loss did not improve from 1.22868
# Epoch 57/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00057: val_loss did not improve from 1.22868
# Epoch 58/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5801 - val_loss: 1.2290
#
# Epoch 00058: val_loss did not improve from 1.22868
# Epoch 59/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00059: val_loss did not improve from 1.22868
# Epoch 60/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00060: val_loss did not improve from 1.22868
# Epoch 61/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5801 - val_loss: 1.2289
#
# Epoch 00061: val_loss did not improve from 1.22868
# Epoch 62/200
# 1619/1619 [==============================] - 25s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00062: val_loss did not improve from 1.22868
# Epoch 63/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00063: val_loss did not improve from 1.22868
# Epoch 64/200
# 1619/1619 [==============================] - 26s 16ms/step - loss: 1.5800 - val_loss: 1.2288
#
# Epoch 00064: val_loss did not improve from 1.22868
# Epoch 65/200
# 1619/1619 [==============================] - 25s 15ms/step - loss: 1.5799 - val_loss: 1.2288
#
# Epoch 00065: val_loss did not improve from 1.22868
# Epoch 66/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00066: val_loss did not improve from 1.22868
# Epoch 67/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2288
#
# Epoch 00067: val_loss did not improve from 1.22868
# Epoch 68/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2288
#
# Epoch 00068: val_loss did not improve from 1.22868
# Epoch 69/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2289
#
# Epoch 00069: val_loss did not improve from 1.22868
# Epoch 70/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2298
#
# Epoch 00070: val_loss did not improve from 1.22868
# Epoch 71/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5800 - val_loss: 1.2290
#
# Epoch 00071: val_loss did not improve from 1.22868
# Epoch 72/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5801 - val_loss: 1.2287
#
# Epoch 00072: val_loss did not improve from 1.22868
# Epoch 73/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5799 - val_loss: 1.2288
#
# Epoch 00073: val_loss did not improve from 1.22868
# Epoch 74/200
# 1619/1619 [==============================] - 24s 15ms/step - loss: 1.5799 - val_loss: 1.2288
#
# Epoch 00074: val_loss did not improve from 1.22868
# Epoch 00074: early stopping
# training mlp took  1865.8972289562225

# %%
starttime = time.time()
train_cnn(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training cnn took ", time.time() - starttime)
# Out:
#  *** PCA Result***
#  Started with 187 features, reduced to 62 features
# SHAPES:  (2279, 32, 63) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 63) (480, 32, 63) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 2s 1ms/step - loss: 1.3050 - val_loss: 0.8723
#
# Epoch 00001: val_loss improved from inf to 0.87232, saving model to cnn_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 2s 970us/step - loss: 1.3062 - val_loss: 0.8693
#
# Epoch 00002: val_loss improved from 0.87232 to 0.86930, saving model to cnn_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 2s 968us/step - loss: 1.3042 - val_loss: 0.8695
#
# Epoch 00003: val_loss did not improve from 0.86930
# Epoch 4/200
# 1619/1619 [==============================] - 1s 886us/step - loss: 1.3034 - val_loss: 0.8695
#
# Epoch 00004: val_loss did not improve from 0.86930
# Epoch 5/200
# 1619/1619 [==============================] - 1s 852us/step - loss: 1.3032 - val_loss: 0.8696
#
# Epoch 00005: val_loss did not improve from 0.86930
# Epoch 6/200
# 1619/1619 [==============================] - 1s 926us/step - loss: 1.3028 - val_loss: 0.8711
#
# Epoch 00006: val_loss did not improve from 0.86930
# Epoch 7/200
# 1619/1619 [==============================] - 1s 918us/step - loss: 1.3018 - val_loss: 0.8678
#
# Epoch 00007: val_loss improved from 0.86930 to 0.86782, saving model to cnn_multistep_multivariate.h5
# Epoch 8/200
# 1619/1619 [==============================] - 2s 981us/step - loss: 1.3030 - val_loss: 0.8710
#
# Epoch 00008: val_loss did not improve from 0.86782
# Epoch 9/200
# 1619/1619 [==============================] - 1s 910us/step - loss: 1.3051 - val_loss: 0.8694
#
# Epoch 00009: val_loss did not improve from 0.86782
# Epoch 10/200
# 1619/1619 [==============================] - 2s 972us/step - loss: 1.3030 - val_loss: 0.8695
#
# Epoch 00010: val_loss did not improve from 0.86782
# Epoch 11/200
# 1619/1619 [==============================] - 2s 932us/step - loss: 1.3029 - val_loss: 0.8699
#
# Epoch 00011: val_loss did not improve from 0.86782
# Epoch 12/200
# 1619/1619 [==============================] - 1s 835us/step - loss: 1.3023 - val_loss: 0.8725
#
# Epoch 00012: val_loss did not improve from 0.86782
# Epoch 13/200
# 1619/1619 [==============================] - 1s 861us/step - loss: 1.2995 - val_loss: 0.8737
#
# Epoch 00013: val_loss did not improve from 0.86782
# Epoch 14/200
# 1619/1619 [==============================] - 1s 828us/step - loss: 1.2919 - val_loss: 0.8529
#
# Epoch 00014: val_loss improved from 0.86782 to 0.85293, saving model to cnn_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 2s 940us/step - loss: 1.2843 - val_loss: 0.8719
#
# Epoch 00015: val_loss did not improve from 0.85293
# Epoch 16/200
# 1619/1619 [==============================] - 1s 910us/step - loss: 1.2839 - val_loss: 0.8775
#
# Epoch 00016: val_loss did not improve from 0.85293
# Epoch 17/200
# 1619/1619 [==============================] - 1s 867us/step - loss: 1.2719 - val_loss: 0.8297
#
# Epoch 00017: val_loss improved from 0.85293 to 0.82974, saving model to cnn_multistep_multivariate.h5
# Epoch 18/200
# 1619/1619 [==============================] - 1s 924us/step - loss: 1.2639 - val_loss: 0.8184
#
# Epoch 00018: val_loss improved from 0.82974 to 0.81842, saving model to cnn_multistep_multivariate.h5
# Epoch 19/200
# 1619/1619 [==============================] - 1s 892us/step - loss: 1.2559 - val_loss: 0.8332
#
# Epoch 00019: val_loss did not improve from 0.81842
# Epoch 20/200
# 1619/1619 [==============================] - 1s 852us/step - loss: 1.2488 - val_loss: 0.8053
#
# Epoch 00020: val_loss improved from 0.81842 to 0.80534, saving model to cnn_multistep_multivariate.h5
# Epoch 21/200
# 1619/1619 [==============================] - 2s 950us/step - loss: 1.2395 - val_loss: 0.7733
#
# Epoch 00021: val_loss improved from 0.80534 to 0.77329, saving model to cnn_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 1s 924us/step - loss: 1.2316 - val_loss: 0.7675
#
# Epoch 00022: val_loss improved from 0.77329 to 0.76753, saving model to cnn_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 2s 955us/step - loss: 1.2282 - val_loss: 0.7658
#
# Epoch 00023: val_loss improved from 0.76753 to 0.76581, saving model to cnn_multistep_multivariate.h5
# Epoch 24/200
# 1619/1619 [==============================] - 2s 953us/step - loss: 1.2267 - val_loss: 0.7623
#
# Epoch 00024: val_loss improved from 0.76581 to 0.76235, saving model to cnn_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 2s 948us/step - loss: 1.2257 - val_loss: 0.7793
#
# Epoch 00025: val_loss did not improve from 0.76235
# Epoch 26/200
# 1619/1619 [==============================] - 2s 952us/step - loss: 1.2252 - val_loss: 0.7628
#
# Epoch 00026: val_loss did not improve from 0.76235
# Epoch 27/200
# 1619/1619 [==============================] - 2s 952us/step - loss: 1.2234 - val_loss: 0.7749
#
# Epoch 00027: val_loss did not improve from 0.76235
# Epoch 28/200
# 1619/1619 [==============================] - 1s 912us/step - loss: 1.2229 - val_loss: 0.7714
#
# Epoch 00028: val_loss did not improve from 0.76235
# Epoch 29/200
# 1619/1619 [==============================] - 1s 909us/step - loss: 1.2203 - val_loss: 0.7421
#
# Epoch 00029: val_loss improved from 0.76235 to 0.74213, saving model to cnn_multistep_multivariate.h5
# Epoch 30/200
# 1619/1619 [==============================] - 2s 954us/step - loss: 1.1892 - val_loss: 0.6911
#
# Epoch 00030: val_loss improved from 0.74213 to 0.69105, saving model to cnn_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 2s 960us/step - loss: 1.1532 - val_loss: 0.6517
#
# Epoch 00031: val_loss improved from 0.69105 to 0.65175, saving model to cnn_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 2s 937us/step - loss: 1.1279 - val_loss: 0.6430
#
# Epoch 00032: val_loss improved from 0.65175 to 0.64296, saving model to cnn_multistep_multivariate.h5
# Epoch 33/200
# 1619/1619 [==============================] - 2s 941us/step - loss: 1.1260 - val_loss: 0.6389
#
# Epoch 00033: val_loss improved from 0.64296 to 0.63886, saving model to cnn_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 2s 957us/step - loss: 1.1283 - val_loss: 0.6308
#
# Epoch 00034: val_loss improved from 0.63886 to 0.63078, saving model to cnn_multistep_multivariate.h5
# Epoch 35/200
# 1619/1619 [==============================] - 2s 945us/step - loss: 1.1197 - val_loss: 0.6282
#
# Epoch 00035: val_loss improved from 0.63078 to 0.62817, saving model to cnn_multistep_multivariate.h5
# Epoch 36/200
# 1619/1619 [==============================] - 2s 967us/step - loss: 1.1220 - val_loss: 0.6238
#
# Epoch 00036: val_loss improved from 0.62817 to 0.62385, saving model to cnn_multistep_multivariate.h5
# Epoch 37/200
# 1619/1619 [==============================] - 2s 971us/step - loss: 1.1185 - val_loss: 0.6260
#
# Epoch 00037: val_loss did not improve from 0.62385
# Epoch 38/200
# 1619/1619 [==============================] - 2s 971us/step - loss: 1.1181 - val_loss: 0.6242
#
# Epoch 00038: val_loss did not improve from 0.62385
# Epoch 39/200
# 1619/1619 [==============================] - 1s 888us/step - loss: 1.1174 - val_loss: 0.6242
#
# Epoch 00039: val_loss did not improve from 0.62385
# Epoch 40/200
# 1619/1619 [==============================] - 1s 860us/step - loss: 1.1172 - val_loss: 0.6235
#
# Epoch 00040: val_loss improved from 0.62385 to 0.62348, saving model to cnn_multistep_multivariate.h5
# Epoch 41/200
# 1619/1619 [==============================] - 2s 943us/step - loss: 1.1169 - val_loss: 0.6225
#
# Epoch 00041: val_loss improved from 0.62348 to 0.62254, saving model to cnn_multistep_multivariate.h5
# Epoch 42/200
# 1619/1619 [==============================] - 1s 878us/step - loss: 1.1175 - val_loss: 0.6211
#
# Epoch 00042: val_loss improved from 0.62254 to 0.62114, saving model to cnn_multistep_multivariate.h5
# Epoch 43/200
# 1619/1619 [==============================] - 1s 843us/step - loss: 1.1189 - val_loss: 0.6239
#
# Epoch 00043: val_loss did not improve from 0.62114
# Epoch 44/200
# 1619/1619 [==============================] - 1s 888us/step - loss: 1.1183 - val_loss: 0.6292
#
# Epoch 00044: val_loss did not improve from 0.62114
# Epoch 45/200
# 1619/1619 [==============================] - 1s 838us/step - loss: 1.1175 - val_loss: 0.6281
#
# Epoch 00045: val_loss did not improve from 0.62114
# Epoch 46/200
# 1619/1619 [==============================] - 1s 900us/step - loss: 1.1169 - val_loss: 0.6282
#
# Epoch 00046: val_loss did not improve from 0.62114
# Epoch 47/200
# 1619/1619 [==============================] - 1s 821us/step - loss: 1.1166 - val_loss: 0.6289
#
# Epoch 00047: val_loss did not improve from 0.62114
# Epoch 48/200
# 1619/1619 [==============================] - 1s 818us/step - loss: 1.1160 - val_loss: 0.6314
#
# Epoch 00048: val_loss did not improve from 0.62114
# Epoch 49/200
# 1619/1619 [==============================] - 1s 744us/step - loss: 1.1158 - val_loss: 0.6279
#
# Epoch 00049: val_loss did not improve from 0.62114
# Epoch 50/200
# 1619/1619 [==============================] - 1s 730us/step - loss: 1.1151 - val_loss: 0.6331
#
# Epoch 00050: val_loss did not improve from 0.62114
# Epoch 51/200
# 1619/1619 [==============================] - 1s 730us/step - loss: 1.1156 - val_loss: 0.6393
#
# Epoch 00051: val_loss did not improve from 0.62114
# Epoch 52/200
# 1619/1619 [==============================] - 1s 838us/step - loss: 1.1121 - val_loss: 0.6160
#
# Epoch 00052: val_loss improved from 0.62114 to 0.61601, saving model to cnn_multistep_multivariate.h5
# Epoch 53/200
# 1619/1619 [==============================] - 1s 903us/step - loss: 1.1085 - val_loss: 0.6167
#
# Epoch 00053: val_loss did not improve from 0.61601
# Epoch 54/200
# 1619/1619 [==============================] - 1s 905us/step - loss: 1.1002 - val_loss: 0.5939
#
# Epoch 00054: val_loss improved from 0.61601 to 0.59386, saving model to cnn_multistep_multivariate.h5
# Epoch 55/200
# 1619/1619 [==============================] - 1s 915us/step - loss: 1.0956 - val_loss: 0.6332
#
# Epoch 00055: val_loss did not improve from 0.59386
# Epoch 56/200
# 1619/1619 [==============================] - 1s 872us/step - loss: 1.0807 - val_loss: 0.5563
#
# Epoch 00056: val_loss improved from 0.59386 to 0.55631, saving model to cnn_multistep_multivariate.h5
# Epoch 57/200
# 1619/1619 [==============================] - 2s 928us/step - loss: 1.0780 - val_loss: 0.6364
#
# Epoch 00057: val_loss did not improve from 0.55631
# Epoch 58/200
# 1619/1619 [==============================] - 1s 850us/step - loss: 1.0387 - val_loss: 0.5206
#
# Epoch 00058: val_loss improved from 0.55631 to 0.52061, saving model to cnn_multistep_multivariate.h5
# Epoch 59/200
# 1619/1619 [==============================] - 1s 909us/step - loss: 1.0546 - val_loss: 0.8185
#
# Epoch 00059: val_loss did not improve from 0.52061
# Epoch 60/200
# 1619/1619 [==============================] - 1s 870us/step - loss: 1.0391 - val_loss: 0.5093
#
# Epoch 00060: val_loss improved from 0.52061 to 0.50927, saving model to cnn_multistep_multivariate.h5
# Epoch 61/200
# 1619/1619 [==============================] - 1s 850us/step - loss: 1.0344 - val_loss: 0.5271
#
# Epoch 00061: val_loss did not improve from 0.50927
# Epoch 62/200
# 1619/1619 [==============================] - 1s 785us/step - loss: 1.0178 - val_loss: 0.5000
#
# Epoch 00062: val_loss improved from 0.50927 to 0.50001, saving model to cnn_multistep_multivariate.h5
# Epoch 63/200
# 1619/1619 [==============================] - 1s 757us/step - loss: 0.9941 - val_loss: 0.4753
#
# Epoch 00063: val_loss improved from 0.50001 to 0.47527, saving model to cnn_multistep_multivariate.h5
# Epoch 64/200
# 1619/1619 [==============================] - 1s 757us/step - loss: 0.9791 - val_loss: 0.4554
#
# Epoch 00064: val_loss improved from 0.47527 to 0.45542, saving model to cnn_multistep_multivariate.h5
# Epoch 65/200
# 1619/1619 [==============================] - 1s 897us/step - loss: 0.9520 - val_loss: 0.4250
#
# Epoch 00065: val_loss improved from 0.45542 to 0.42505, saving model to cnn_multistep_multivariate.h5
# Epoch 66/200
# 1619/1619 [==============================] - 1s 878us/step - loss: 0.9319 - val_loss: 0.4091
#
# Epoch 00066: val_loss improved from 0.42505 to 0.40915, saving model to cnn_multistep_multivariate.h5
# Epoch 67/200
# 1619/1619 [==============================] - 1s 913us/step - loss: 0.9499 - val_loss: 0.4030
#
# Epoch 00067: val_loss improved from 0.40915 to 0.40296, saving model to cnn_multistep_multivariate.h5
# Epoch 68/200
# 1619/1619 [==============================] - 1s 861us/step - loss: 1.0451 - val_loss: 0.8292
#
# Epoch 00068: val_loss did not improve from 0.40296
# Epoch 69/200
# 1619/1619 [==============================] - 1s 818us/step - loss: 1.0941 - val_loss: 0.6685
#
# Epoch 00069: val_loss did not improve from 0.40296
# Epoch 70/200
# 1619/1619 [==============================] - 1s 858us/step - loss: 0.9534 - val_loss: 0.4070
#
# Epoch 00070: val_loss did not improve from 0.40296
# Epoch 71/200
# 1619/1619 [==============================] - 1s 829us/step - loss: 0.9357 - val_loss: 0.7225
#
# Epoch 00071: val_loss did not improve from 0.40296
# Epoch 72/200
# 1619/1619 [==============================] - 1s 829us/step - loss: 1.0724 - val_loss: 0.6168
#
# Epoch 00072: val_loss did not improve from 0.40296
# Epoch 73/200
# 1619/1619 [==============================] - 1s 733us/step - loss: 1.0891 - val_loss: 0.6341
#
# Epoch 00073: val_loss did not improve from 0.40296
# Epoch 74/200
# 1619/1619 [==============================] - 1s 736us/step - loss: 1.0829 - val_loss: 0.6333
#
# Epoch 00074: val_loss did not improve from 0.40296
# Epoch 75/200
# 1619/1619 [==============================] - 1s 801us/step - loss: 1.1956 - val_loss: 0.7927
#
# Epoch 00075: val_loss did not improve from 0.40296
# Epoch 76/200
# 1619/1619 [==============================] - 1s 823us/step - loss: 1.1791 - val_loss: 0.6879
#
# Epoch 00076: val_loss did not improve from 0.40296
# Epoch 77/200
# 1619/1619 [==============================] - 1s 791us/step - loss: 1.1536 - val_loss: 0.6708
#
# Epoch 00077: val_loss did not improve from 0.40296
# Epoch 78/200
# 1619/1619 [==============================] - 1s 804us/step - loss: 1.1360 - val_loss: 0.6208
#
# Epoch 00078: val_loss did not improve from 0.40296
# Epoch 79/200
# 1619/1619 [==============================] - 1s 799us/step - loss: 1.1186 - val_loss: 0.6160
#
# Epoch 00079: val_loss did not improve from 0.40296
# Epoch 80/200
# 1619/1619 [==============================] - 1s 775us/step - loss: 1.0990 - val_loss: 0.5658
#
# Epoch 00080: val_loss did not improve from 0.40296
# Epoch 81/200
# 1619/1619 [==============================] - 1s 748us/step - loss: 1.0399 - val_loss: 0.4805
#
# Epoch 00081: val_loss did not improve from 0.40296
# Epoch 82/200
# 1619/1619 [==============================] - 1s 777us/step - loss: 1.0095 - val_loss: 0.4431
#
# Epoch 00082: val_loss did not improve from 0.40296
# Epoch 83/200
# 1619/1619 [==============================] - 1s 802us/step - loss: 0.9683 - val_loss: 0.4181
#
# Epoch 00083: val_loss did not improve from 0.40296
# Epoch 84/200
# 1619/1619 [==============================] - 1s 795us/step - loss: 0.9298 - val_loss: 0.4039
#
# Epoch 00084: val_loss did not improve from 0.40296
# Epoch 85/200
# 1619/1619 [==============================] - 1s 815us/step - loss: 0.9221 - val_loss: 0.3994
#
# Epoch 00085: val_loss improved from 0.40296 to 0.39945, saving model to cnn_multistep_multivariate.h5
# Epoch 86/200
# 1619/1619 [==============================] - 1s 766us/step - loss: 0.9141 - val_loss: 0.3983
#
# Epoch 00086: val_loss improved from 0.39945 to 0.39831, saving model to cnn_multistep_multivariate.h5
# Epoch 87/200
# 1619/1619 [==============================] - 1s 747us/step - loss: 0.9126 - val_loss: 0.3982
#
# Epoch 00087: val_loss improved from 0.39831 to 0.39821, saving model to cnn_multistep_multivariate.h5
# Epoch 88/200
# 1619/1619 [==============================] - 1s 790us/step - loss: 0.9124 - val_loss: 0.3985
#
# Epoch 00088: val_loss did not improve from 0.39821
# Epoch 89/200
# 1619/1619 [==============================] - 1s 822us/step - loss: 0.9121 - val_loss: 0.3990
#
# Epoch 00089: val_loss did not improve from 0.39821
# Epoch 90/200
# 1619/1619 [==============================] - 1s 757us/step - loss: 0.9121 - val_loss: 0.4005
#
# Epoch 00090: val_loss did not improve from 0.39821
# Epoch 91/200
# 1619/1619 [==============================] - 1s 771us/step - loss: 0.9120 - val_loss: 0.4014
#
# Epoch 00091: val_loss did not improve from 0.39821
# Epoch 92/200
# 1619/1619 [==============================] - 1s 807us/step - loss: 0.9120 - val_loss: 0.4022
#
# Epoch 00092: val_loss did not improve from 0.39821
# Epoch 93/200
# 1619/1619 [==============================] - 1s 783us/step - loss: 0.9119 - val_loss: 0.4024
#
# Epoch 00093: val_loss did not improve from 0.39821
# Epoch 94/200
# 1619/1619 [==============================] - 1s 769us/step - loss: 0.9118 - val_loss: 0.4025
#
# Epoch 00094: val_loss did not improve from 0.39821
# Epoch 95/200
# 1619/1619 [==============================] - 1s 778us/step - loss: 0.9118 - val_loss: 0.4024
#
# Epoch 00095: val_loss did not improve from 0.39821
# Epoch 96/200
# 1619/1619 [==============================] - 1s 827us/step - loss: 0.9118 - val_loss: 0.4021
#
# Epoch 00096: val_loss did not improve from 0.39821
# Epoch 97/200
# 1619/1619 [==============================] - 1s 792us/step - loss: 0.9118 - val_loss: 0.4016
#
# Epoch 00097: val_loss did not improve from 0.39821
# Epoch 98/200
# 1619/1619 [==============================] - 1s 765us/step - loss: 0.9117 - val_loss: 0.4013
#
# Epoch 00098: val_loss did not improve from 0.39821
# Epoch 99/200
# 1619/1619 [==============================] - 1s 766us/step - loss: 0.9117 - val_loss: 0.4010
#
# Epoch 00099: val_loss did not improve from 0.39821
# Epoch 100/200
# 1619/1619 [==============================] - 1s 810us/step - loss: 0.9116 - val_loss: 0.4008
#
# Epoch 00100: val_loss did not improve from 0.39821
# Epoch 101/200
# 1619/1619 [==============================] - 1s 786us/step - loss: 0.9116 - val_loss: 0.4006
#
# Epoch 00101: val_loss did not improve from 0.39821
# Epoch 102/200
# 1619/1619 [==============================] - 1s 787us/step - loss: 0.9116 - val_loss: 0.4005
#
# Epoch 00102: val_loss did not improve from 0.39821
# Epoch 103/200
# 1619/1619 [==============================] - 1s 765us/step - loss: 0.9115 - val_loss: 0.4003
#
# Epoch 00103: val_loss did not improve from 0.39821
# Epoch 104/200
# 1619/1619 [==============================] - 1s 784us/step - loss: 0.9115 - val_loss: 0.3999
#
# Epoch 00104: val_loss did not improve from 0.39821
# Epoch 105/200
# 1619/1619 [==============================] - 1s 778us/step - loss: 0.9115 - val_loss: 0.3995
#
# Epoch 00105: val_loss did not improve from 0.39821
# Epoch 106/200
# 1619/1619 [==============================] - 1s 776us/step - loss: 0.9115 - val_loss: 0.3991
#
# Epoch 00106: val_loss did not improve from 0.39821
# Epoch 107/200
# 1619/1619 [==============================] - 1s 783us/step - loss: 0.9116 - val_loss: 0.3984
#
# Epoch 00107: val_loss did not improve from 0.39821
# Epoch 108/200
# 1619/1619 [==============================] - 1s 777us/step - loss: 0.9115 - val_loss: 0.3978
#
# Epoch 00108: val_loss improved from 0.39821 to 0.39783, saving model to cnn_multistep_multivariate.h5
# Epoch 109/200
# 1619/1619 [==============================] - 1s 779us/step - loss: 0.9115 - val_loss: 0.3976
#
# Epoch 00109: val_loss improved from 0.39783 to 0.39757, saving model to cnn_multistep_multivariate.h5
# Epoch 110/200
# 1619/1619 [==============================] - 1s 737us/step - loss: 0.9116 - val_loss: 0.3974
#
# Epoch 00110: val_loss improved from 0.39757 to 0.39738, saving model to cnn_multistep_multivariate.h5
# Epoch 111/200
# 1619/1619 [==============================] - 1s 773us/step - loss: 0.9115 - val_loss: 0.3974
#
# Epoch 00111: val_loss did not improve from 0.39738
# Epoch 112/200
# 1619/1619 [==============================] - 1s 786us/step - loss: 0.9115 - val_loss: 0.3974
#
# Epoch 00112: val_loss did not improve from 0.39738
# Epoch 113/200
# 1619/1619 [==============================] - 1s 827us/step - loss: 0.9114 - val_loss: 0.3973
#
# Epoch 00113: val_loss improved from 0.39738 to 0.39729, saving model to cnn_multistep_multivariate.h5
# Epoch 114/200
# 1619/1619 [==============================] - 1s 750us/step - loss: 0.9113 - val_loss: 0.3975
#
# Epoch 00114: val_loss did not improve from 0.39729
# Epoch 115/200
# 1619/1619 [==============================] - 1s 774us/step - loss: 0.9113 - val_loss: 0.3973
#
# Epoch 00115: val_loss did not improve from 0.39729
# Epoch 116/200
# 1619/1619 [==============================] - 1s 810us/step - loss: 0.9113 - val_loss: 0.3973
#
# Epoch 00116: val_loss did not improve from 0.39729
# Epoch 117/200
# 1619/1619 [==============================] - 1s 787us/step - loss: 0.9112 - val_loss: 0.3977
#
# Epoch 00117: val_loss did not improve from 0.39729
# Epoch 118/200
# 1619/1619 [==============================] - 1s 741us/step - loss: 0.9112 - val_loss: 0.3975
#
# Epoch 00118: val_loss did not improve from 0.39729
# Epoch 119/200
# 1619/1619 [==============================] - 1s 773us/step - loss: 0.9112 - val_loss: 0.3975
#
# Epoch 00119: val_loss did not improve from 0.39729
# Epoch 120/200
# 1619/1619 [==============================] - 1s 815us/step - loss: 0.9111 - val_loss: 0.3977
#
# Epoch 00120: val_loss did not improve from 0.39729
# Epoch 121/200
# 1619/1619 [==============================] - 1s 790us/step - loss: 0.9111 - val_loss: 0.3978
#
# Epoch 00121: val_loss did not improve from 0.39729
# Epoch 122/200
# 1619/1619 [==============================] - 1s 798us/step - loss: 0.9111 - val_loss: 0.3980
#
# Epoch 00122: val_loss did not improve from 0.39729
# Epoch 123/200
# 1619/1619 [==============================] - 1s 847us/step - loss: 0.9111 - val_loss: 0.3982
#
# Epoch 00123: val_loss did not improve from 0.39729
# Epoch 124/200
# 1619/1619 [==============================] - 1s 786us/step - loss: 0.9110 - val_loss: 0.3981
#
# Epoch 00124: val_loss did not improve from 0.39729
# Epoch 125/200
# 1619/1619 [==============================] - 1s 815us/step - loss: 0.9111 - val_loss: 0.3981
#
# Epoch 00125: val_loss did not improve from 0.39729
# Epoch 126/200
# 1619/1619 [==============================] - 1s 758us/step - loss: 0.9110 - val_loss: 0.3980
#
# Epoch 00126: val_loss did not improve from 0.39729
# Epoch 127/200
# 1619/1619 [==============================] - 1s 836us/step - loss: 0.9110 - val_loss: 0.3981
#
# Epoch 00127: val_loss did not improve from 0.39729
# Epoch 128/200
# 1619/1619 [==============================] - 1s 802us/step - loss: 0.9109 - val_loss: 0.3982
#
# Epoch 00128: val_loss did not improve from 0.39729
# Epoch 129/200
# 1619/1619 [==============================] - 1s 756us/step - loss: 0.9110 - val_loss: 0.3984
#
# Epoch 00129: val_loss did not improve from 0.39729
# Epoch 130/200
# 1619/1619 [==============================] - 1s 796us/step - loss: 0.9108 - val_loss: 0.3982
#
# Epoch 00130: val_loss did not improve from 0.39729
# Epoch 131/200
# 1619/1619 [==============================] - 1s 798us/step - loss: 0.9111 - val_loss: 0.3988
#
# Epoch 00131: val_loss did not improve from 0.39729
# Epoch 132/200
# 1619/1619 [==============================] - 1s 808us/step - loss: 0.9109 - val_loss: 0.3986
#
# Epoch 00132: val_loss did not improve from 0.39729
# Epoch 133/200
# 1619/1619 [==============================] - 1s 784us/step - loss: 0.9110 - val_loss: 0.3983
#
# Epoch 00133: val_loss did not improve from 0.39729
# Epoch 134/200
# 1619/1619 [==============================] - 1s 765us/step - loss: 0.9115 - val_loss: 0.3985
#
# Epoch 00134: val_loss did not improve from 0.39729
# Epoch 135/200
# 1619/1619 [==============================] - 1s 773us/step - loss: 0.9120 - val_loss: 0.3983
#
# Epoch 00135: val_loss did not improve from 0.39729
# Epoch 136/200
# 1619/1619 [==============================] - 1s 790us/step - loss: 0.9113 - val_loss: 0.3992
#
# Epoch 00136: val_loss did not improve from 0.39729
# Epoch 137/200
# 1619/1619 [==============================] - 1s 787us/step - loss: 0.9116 - val_loss: 0.3997
#
# Epoch 00137: val_loss did not improve from 0.39729
# Epoch 138/200
# 1619/1619 [==============================] - 1s 780us/step - loss: 0.9114 - val_loss: 0.4001
#
# Epoch 00138: val_loss did not improve from 0.39729
# Epoch 00138: early stopping
# *** Model fitted ***
# training cnn took  222.8621654510498

# %%
starttime = time.time()
train_gru(df.copy().reset_index(), pred_horizon=pred_horizon, n_history=n_history)
print("training GRU took ", time.time() - starttime)
# Out:
# SHAPES:  (2279, 32, 187) (2279, 480)
# Shapes: xtr, xte, ytr, yte:  (1799, 32, 187) (480, 32, 187) (1799, 480) (480, 480)
# Train on 1619 samples, validate on 180 samples
# Epoch 1/200
# 1619/1619 [==============================] - 9s 6ms/step - loss: 1.3045 - mse: 1.3045 - val_loss: 0.8716 - val_mse: 0.8716
#
# Epoch 00001: val_loss improved from inf to 0.87159, saving model to gru_multistep_multivariate.h5
# Epoch 2/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.3024 - mse: 1.3024 - val_loss: 0.8703 - val_mse: 0.8703
#
# Epoch 00002: val_loss improved from 0.87159 to 0.87031, saving model to gru_multistep_multivariate.h5
# Epoch 3/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.3030 - mse: 1.3030 - val_loss: 0.8703 - val_mse: 0.8703
#
# Epoch 00003: val_loss did not improve from 0.87031
# Epoch 4/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2958 - mse: 1.2958 - val_loss: 0.8627 - val_mse: 0.8627
#
# Epoch 00004: val_loss improved from 0.87031 to 0.86271, saving model to gru_multistep_multivariate.h5
# Epoch 5/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2954 - mse: 1.2954 - val_loss: 0.8583 - val_mse: 0.8583
#
# Epoch 00005: val_loss improved from 0.86271 to 0.85832, saving model to gru_multistep_multivariate.h5
# Epoch 6/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2890 - mse: 1.2890 - val_loss: 0.8695 - val_mse: 0.8695
#
# Epoch 00006: val_loss did not improve from 0.85832
# Epoch 7/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2887 - mse: 1.2887 - val_loss: 0.8671 - val_mse: 0.8671
#
# Epoch 00007: val_loss did not improve from 0.85832
# Epoch 8/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2843 - mse: 1.2843 - val_loss: 0.8408 - val_mse: 0.8408
#
# Epoch 00008: val_loss improved from 0.85832 to 0.84080, saving model to gru_multistep_multivariate.h5
# Epoch 9/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2764 - mse: 1.2764 - val_loss: 0.8398 - val_mse: 0.8398
#
# Epoch 00009: val_loss improved from 0.84080 to 0.83982, saving model to gru_multistep_multivariate.h5
# Epoch 10/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2794 - mse: 1.2794 - val_loss: 0.8635 - val_mse: 0.8635
#
# Epoch 00010: val_loss did not improve from 0.83982
# Epoch 11/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2770 - mse: 1.2770 - val_loss: 0.8368 - val_mse: 0.8368
#
# Epoch 00011: val_loss improved from 0.83982 to 0.83681, saving model to gru_multistep_multivariate.h5
# Epoch 12/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2793 - mse: 1.2793 - val_loss: 0.8510 - val_mse: 0.8510
#
# Epoch 00012: val_loss did not improve from 0.83681
# Epoch 13/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2755 - mse: 1.2755 - val_loss: 0.8398 - val_mse: 0.8398
#
# Epoch 00013: val_loss did not improve from 0.83681
# Epoch 14/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2715 - mse: 1.2715 - val_loss: 0.8339 - val_mse: 0.8339
#
# Epoch 00014: val_loss improved from 0.83681 to 0.83390, saving model to gru_multistep_multivariate.h5
# Epoch 15/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2636 - mse: 1.2636 - val_loss: 0.8405 - val_mse: 0.8405
#
# Epoch 00015: val_loss did not improve from 0.83390
# Epoch 16/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2615 - mse: 1.2615 - val_loss: 0.8552 - val_mse: 0.8552
#
# Epoch 00016: val_loss did not improve from 0.83390
# Epoch 17/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2626 - mse: 1.2626 - val_loss: 0.8486 - val_mse: 0.8486
#
# Epoch 00017: val_loss did not improve from 0.83390
# Epoch 18/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2737 - mse: 1.2737 - val_loss: 0.8441 - val_mse: 0.8441
#
# Epoch 00018: val_loss did not improve from 0.83390
# Epoch 19/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2661 - mse: 1.2661 - val_loss: 0.8413 - val_mse: 0.8413
#
# Epoch 00019: val_loss did not improve from 0.83390
# Epoch 20/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2564 - mse: 1.2564 - val_loss: 0.8355 - val_mse: 0.8355
#
# Epoch 00020: val_loss did not improve from 0.83390
# Epoch 21/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2612 - mse: 1.2612 - val_loss: 0.8322 - val_mse: 0.8322
#
# Epoch 00021: val_loss improved from 0.83390 to 0.83224, saving model to gru_multistep_multivariate.h5
# Epoch 22/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2542 - mse: 1.2542 - val_loss: 0.8136 - val_mse: 0.8136
#
# Epoch 00022: val_loss improved from 0.83224 to 0.81360, saving model to gru_multistep_multivariate.h5
# Epoch 23/200
# 1619/1619 [==============================] - 7s 4ms/step - loss: 1.2491 - mse: 1.2491 - val_loss: 0.8627 - val_mse: 0.8627
#
# Epoch 00023: val_loss did not improve from 0.81360
# Epoch 24/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.2411 - mse: 1.2411 - val_loss: 0.7869 - val_mse: 0.7869
#
# Epoch 00024: val_loss improved from 0.81360 to 0.78687, saving model to gru_multistep_multivariate.h5
# Epoch 25/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.2382 - mse: 1.2382 - val_loss: 0.7848 - val_mse: 0.7848
#
# Epoch 00025: val_loss improved from 0.78687 to 0.78479, saving model to gru_multistep_multivariate.h5
# Epoch 26/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.2318 - mse: 1.2318 - val_loss: 0.7794 - val_mse: 0.7794
#
# Epoch 00026: val_loss improved from 0.78479 to 0.77939, saving model to gru_multistep_multivariate.h5
# Epoch 27/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.2272 - mse: 1.2272 - val_loss: 0.7863 - val_mse: 0.7863
#
# Epoch 00027: val_loss did not improve from 0.77939
# Epoch 28/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2274 - mse: 1.2274 - val_loss: 0.8650 - val_mse: 0.8650
#
# Epoch 00028: val_loss did not improve from 0.77939
# Epoch 29/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2243 - mse: 1.2243 - val_loss: 0.7774 - val_mse: 0.7774
#
# Epoch 00029: val_loss improved from 0.77939 to 0.77745, saving model to gru_multistep_multivariate.h5
# Epoch 30/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2146 - mse: 1.2146 - val_loss: 0.7696 - val_mse: 0.7696
#
# Epoch 00030: val_loss improved from 0.77745 to 0.76961, saving model to gru_multistep_multivariate.h5
# Epoch 31/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2101 - mse: 1.2101 - val_loss: 0.7392 - val_mse: 0.7392
#
# Epoch 00031: val_loss improved from 0.76961 to 0.73922, saving model to gru_multistep_multivariate.h5
# Epoch 32/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.2033 - mse: 1.2033 - val_loss: 0.7420 - val_mse: 0.7420
#
# Epoch 00032: val_loss did not improve from 0.73922
# Epoch 33/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1976 - mse: 1.1976 - val_loss: 0.7330 - val_mse: 0.7330
#
# Epoch 00033: val_loss improved from 0.73922 to 0.73302, saving model to gru_multistep_multivariate.h5
# Epoch 34/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1926 - mse: 1.1926 - val_loss: 0.7370 - val_mse: 0.7370
#
# Epoch 00034: val_loss did not improve from 0.73302
# Epoch 35/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1902 - mse: 1.1902 - val_loss: 0.7427 - val_mse: 0.7427
#
# Epoch 00035: val_loss did not improve from 0.73302
# Epoch 36/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1799 - mse: 1.1799 - val_loss: 0.7306 - val_mse: 0.7306
#
# Epoch 00036: val_loss improved from 0.73302 to 0.73060, saving model to gru_multistep_multivariate.h5
# Epoch 37/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1735 - mse: 1.1735 - val_loss: 0.7256 - val_mse: 0.7256
#
# Epoch 00037: val_loss improved from 0.73060 to 0.72556, saving model to gru_multistep_multivariate.h5
# Epoch 38/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1674 - mse: 1.1674 - val_loss: 0.7285 - val_mse: 0.7285
#
# Epoch 00038: val_loss did not improve from 0.72556
# Epoch 39/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1595 - mse: 1.1595 - val_loss: 0.7160 - val_mse: 0.7160
#
# Epoch 00039: val_loss improved from 0.72556 to 0.71596, saving model to gru_multistep_multivariate.h5
# Epoch 40/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1525 - mse: 1.1525 - val_loss: 0.7214 - val_mse: 0.7214
#
# Epoch 00040: val_loss did not improve from 0.71596
# Epoch 41/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1544 - mse: 1.1544 - val_loss: 0.7149 - val_mse: 0.7149
#
# Epoch 00041: val_loss improved from 0.71596 to 0.71492, saving model to gru_multistep_multivariate.h5
# Epoch 42/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1425 - mse: 1.1425 - val_loss: 0.7066 - val_mse: 0.7066
#
# Epoch 00042: val_loss improved from 0.71492 to 0.70656, saving model to gru_multistep_multivariate.h5
# Epoch 43/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1360 - mse: 1.1360 - val_loss: 0.7157 - val_mse: 0.7157
#
# Epoch 00043: val_loss did not improve from 0.70656
# Epoch 44/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1549 - mse: 1.1549 - val_loss: 0.7328 - val_mse: 0.7328
#
# Epoch 00044: val_loss did not improve from 0.70656
# Epoch 45/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.2064 - mse: 1.2064 - val_loss: 0.7140 - val_mse: 0.7140
#
# Epoch 00045: val_loss did not improve from 0.70656
# Epoch 46/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.1480 - mse: 1.1480 - val_loss: 0.7088 - val_mse: 0.7088
#
# Epoch 00046: val_loss did not improve from 0.70656
# Epoch 47/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1244 - mse: 1.1244 - val_loss: 0.7078 - val_mse: 0.7078
#
# Epoch 00047: val_loss did not improve from 0.70656
# Epoch 48/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1092 - mse: 1.1092 - val_loss: 0.6810 - val_mse: 0.6810
#
# Epoch 00048: val_loss improved from 0.70656 to 0.68105, saving model to gru_multistep_multivariate.h5
# Epoch 49/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1007 - mse: 1.1007 - val_loss: 0.6840 - val_mse: 0.6840
#
# Epoch 00049: val_loss did not improve from 0.68105
# Epoch 50/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.1069 - mse: 1.1069 - val_loss: 0.6592 - val_mse: 0.6592
#
# Epoch 00050: val_loss improved from 0.68105 to 0.65924, saving model to gru_multistep_multivariate.h5
# Epoch 51/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0929 - mse: 1.0929 - val_loss: 0.6624 - val_mse: 0.6624
#
# Epoch 00051: val_loss did not improve from 0.65924
# Epoch 52/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0783 - mse: 1.0783 - val_loss: 0.6442 - val_mse: 0.6442
#
# Epoch 00052: val_loss improved from 0.65924 to 0.64417, saving model to gru_multistep_multivariate.h5
# Epoch 53/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0723 - mse: 1.0723 - val_loss: 0.6651 - val_mse: 0.6651
#
# Epoch 00053: val_loss did not improve from 0.64417
# Epoch 54/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0784 - mse: 1.0784 - val_loss: 0.6499 - val_mse: 0.6499
#
# Epoch 00054: val_loss did not improve from 0.64417
# Epoch 55/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.0647 - mse: 1.0647 - val_loss: 0.6536 - val_mse: 0.6536
#
# Epoch 00055: val_loss did not improve from 0.64417
# Epoch 56/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0593 - mse: 1.0593 - val_loss: 0.6656 - val_mse: 0.6656
#
# Epoch 00056: val_loss did not improve from 0.64417
# Epoch 57/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0493 - mse: 1.0493 - val_loss: 0.6728 - val_mse: 0.6728
#
# Epoch 00057: val_loss did not improve from 0.64417
# Epoch 58/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0438 - mse: 1.0438 - val_loss: 0.6482 - val_mse: 0.6482
#
# Epoch 00058: val_loss did not improve from 0.64417
# Epoch 59/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0393 - mse: 1.0393 - val_loss: 0.6863 - val_mse: 0.6863
#
# Epoch 00059: val_loss did not improve from 0.64417
# Epoch 60/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0353 - mse: 1.0353 - val_loss: 0.6551 - val_mse: 0.6551
#
# Epoch 00060: val_loss did not improve from 0.64417
# Epoch 61/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0411 - mse: 1.0411 - val_loss: 0.6199 - val_mse: 0.6199
#
# Epoch 00061: val_loss improved from 0.64417 to 0.61992, saving model to gru_multistep_multivariate.h5
# Epoch 62/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0316 - mse: 1.0316 - val_loss: 0.6910 - val_mse: 0.6910
#
# Epoch 00062: val_loss did not improve from 0.61992
# Epoch 63/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0369 - mse: 1.0369 - val_loss: 0.6253 - val_mse: 0.6253
#
# Epoch 00063: val_loss did not improve from 0.61992
# Epoch 64/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0277 - mse: 1.0277 - val_loss: 0.6563 - val_mse: 0.6563
#
# Epoch 00064: val_loss did not improve from 0.61992
# Epoch 65/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0230 - mse: 1.0230 - val_loss: 0.7168 - val_mse: 0.7168
#
# Epoch 00065: val_loss did not improve from 0.61992
# Epoch 66/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0259 - mse: 1.0259 - val_loss: 0.6235 - val_mse: 0.6235
#
# Epoch 00066: val_loss did not improve from 0.61992
# Epoch 67/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0201 - mse: 1.0201 - val_loss: 0.6026 - val_mse: 0.6026
#
# Epoch 00067: val_loss improved from 0.61992 to 0.60263, saving model to gru_multistep_multivariate.h5
# Epoch 68/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0260 - mse: 1.0260 - val_loss: 0.6122 - val_mse: 0.6122
#
# Epoch 00068: val_loss did not improve from 0.60263
# Epoch 69/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0184 - mse: 1.0184 - val_loss: 0.5989 - val_mse: 0.5989
#
# Epoch 00069: val_loss improved from 0.60263 to 0.59892, saving model to gru_multistep_multivariate.h5
# Epoch 70/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0109 - mse: 1.0109 - val_loss: 0.6052 - val_mse: 0.6052
#
# Epoch 00070: val_loss did not improve from 0.59892
# Epoch 71/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0102 - mse: 1.0102 - val_loss: 0.6255 - val_mse: 0.6255
#
# Epoch 00071: val_loss did not improve from 0.59892
# Epoch 72/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0119 - mse: 1.0119 - val_loss: 0.6322 - val_mse: 0.6322
#
# Epoch 00072: val_loss did not improve from 0.59892
# Epoch 73/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.0088 - mse: 1.0088 - val_loss: 0.5986 - val_mse: 0.5986
#
# Epoch 00073: val_loss improved from 0.59892 to 0.59861, saving model to gru_multistep_multivariate.h5
# Epoch 74/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0084 - mse: 1.0084 - val_loss: 0.6616 - val_mse: 0.6616
#
# Epoch 00074: val_loss did not improve from 0.59861
# Epoch 75/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.0139 - mse: 1.0139 - val_loss: 0.6212 - val_mse: 0.6212
#
# Epoch 00075: val_loss did not improve from 0.59861
# Epoch 76/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0093 - mse: 1.0093 - val_loss: 0.7364 - val_mse: 0.7364
#
# Epoch 00076: val_loss did not improve from 0.59861
# Epoch 77/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0835 - mse: 1.0835 - val_loss: 0.8781 - val_mse: 0.8781
#
# Epoch 00077: val_loss did not improve from 0.59861
# Epoch 78/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0444 - mse: 1.0444 - val_loss: 0.6842 - val_mse: 0.6842
#
# Epoch 00078: val_loss did not improve from 0.59861
# Epoch 79/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.0377 - mse: 1.0377 - val_loss: 0.6299 - val_mse: 0.6299
#
# Epoch 00079: val_loss did not improve from 0.59861
# Epoch 80/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0235 - mse: 1.0235 - val_loss: 0.6389 - val_mse: 0.6389
#
# Epoch 00080: val_loss did not improve from 0.59861
# Epoch 81/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0193 - mse: 1.0193 - val_loss: 0.7214 - val_mse: 0.7214
#
# Epoch 00081: val_loss did not improve from 0.59861
# Epoch 82/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0162 - mse: 1.0162 - val_loss: 0.6607 - val_mse: 0.6607
#
# Epoch 00082: val_loss did not improve from 0.59861
# Epoch 83/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0619 - mse: 1.0619 - val_loss: 0.6141 - val_mse: 0.6141
#
# Epoch 00083: val_loss did not improve from 0.59861
# Epoch 84/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0131 - mse: 1.0131 - val_loss: 0.6043 - val_mse: 0.6043
#
# Epoch 00084: val_loss did not improve from 0.59861
# Epoch 85/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0220 - mse: 1.0220 - val_loss: 0.6160 - val_mse: 0.6160
#
# Epoch 00085: val_loss did not improve from 0.59861
# Epoch 86/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0125 - mse: 1.0125 - val_loss: 0.6481 - val_mse: 0.6481
#
# Epoch 00086: val_loss did not improve from 0.59861
# Epoch 87/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0181 - mse: 1.0181 - val_loss: 0.6107 - val_mse: 0.6107
#
# Epoch 00087: val_loss did not improve from 0.59861
# Epoch 88/200
# 1619/1619 [==============================] - 8s 5ms/step - loss: 1.0078 - mse: 1.0078 - val_loss: 0.6558 - val_mse: 0.6558
#
# Epoch 00088: val_loss did not improve from 0.59861
# Epoch 89/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0060 - mse: 1.0060 - val_loss: 0.6482 - val_mse: 0.6482
#
# Epoch 00089: val_loss did not improve from 0.59861
# Epoch 90/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0065 - mse: 1.0065 - val_loss: 0.6097 - val_mse: 0.6097
#
# Epoch 00090: val_loss did not improve from 0.59861
# Epoch 91/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0011 - mse: 1.0011 - val_loss: 0.6280 - val_mse: 0.6280
#
# Epoch 00091: val_loss did not improve from 0.59861
# Epoch 92/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0002 - mse: 1.0002 - val_loss: 0.6634 - val_mse: 0.6634
#
# Epoch 00092: val_loss did not improve from 0.59861
# Epoch 93/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0015 - mse: 1.0015 - val_loss: 0.6031 - val_mse: 0.6031
#
# Epoch 00093: val_loss did not improve from 0.59861
# Epoch 94/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 0.9959 - mse: 0.9959 - val_loss: 0.6245 - val_mse: 0.6245
#
# Epoch 00094: val_loss did not improve from 0.59861
# Epoch 95/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 0.9935 - mse: 0.9935 - val_loss: 0.6306 - val_mse: 0.6306
#
# Epoch 00095: val_loss did not improve from 0.59861
# Epoch 96/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0077 - mse: 1.0077 - val_loss: 0.6283 - val_mse: 0.6283
#
# Epoch 00096: val_loss did not improve from 0.59861
# Epoch 97/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 0.9992 - mse: 0.9992 - val_loss: 0.6784 - val_mse: 0.6784
#
# Epoch 00097: val_loss did not improve from 0.59861
# Epoch 98/200
# 1619/1619 [==============================] - 7s 5ms/step - loss: 1.0157 - mse: 1.0157 - val_loss: 0.6161 - val_mse: 0.6161
#
# Epoch 00098: val_loss did not improve from 0.59861
# Epoch 00098: early stopping
# *** Model fitted ***
# training GRU took  896.3941497802734

# %%
# Real data
plot_frames = []
plot_frames.append(plot_real_data_train(df, n_history))
plot_frames.append(plot_real_data_test(df, pred_horizon))

# %%
plot_frames.append(forecast_gru(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
# ********MSE, RMSE******
# MSE: 1.908194
# RMSE: 1.381374

# %%
plot_frames.append(forecast_cnn(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
# ********MSE, RMSE******
# MSE: 0.710080
# RMSE: 0.842663

# %%
plot_frames.append(forecast_lstm(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
# ********MSE, RMSE******
# MSE: 0.699929
# RMSE: 0.836617

# %%
plot_frames.append(forecast_mlp(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
# ********MSE, RMSE******
# MSE: 10.357101
# RMSE: 3.218245

# %%
plot_frames.append(forecast_fbprophet_additiv(pred_horizon))
plot_frames.append(forecast_fbprophet_boxcox(pred_horizon, fbprophet_boxcox_lam))
# Out:
#    cpuusage_ps
# 0       11.592
# 1        0.357
# 2        0.409
# 3        0.335
# 4        0.885
# training sarima took  89.33058142662048
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-273763eccf29> in <module>
#       4 plot_frames.append(forecast_mlp(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
#       5 plot_frames.append(forecast_cnn(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# ----> 6 plot_frames.append(forecast_sarima(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
#
# <ipython-input-26-8cdee8b56296> in forecast_sarima(df, n_history, pred_horizon)
#      21     model = SARIMAXResults.load('sarima.pkl')
#      22
# ---> 23     predictions = model.predict(start=start, end=end, dynamic=False).rename('SARIMAX Predictions' % n_history)
#      24
#      25     df_forecast = pd.DataFrame(predictions.values, columns=['SARIMA Predictions (1, 3, 0)(1, 1, 1, n_history) ' % n_history])
#
# TypeError: not all arguments converted during string formatting

# %%
plot_frames.append(forecast_sarima(df.copy().reset_index(), n_history = n_history, pred_horizon = pred_horizon))
# Out:
#    cpuusage_ps
# 0       11.592
# 1        0.357
# 2        0.409
# 3        0.335
# 4        0.885
# training sarima took  87.22043108940125

# %%
# Plot
plot_data(pd.concat(plot_frames, sort=True),'Vergleich ML-Models')
