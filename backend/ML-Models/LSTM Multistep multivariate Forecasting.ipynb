# %% [markdown]
# #  LSTM Multistep multivariate Forecasting

# %%
import pandas as pd 
import tensorflow as tf
df = pd.read_csv('ISTATX_transformed.csv')
df.set_index('10MIN_TIMESTAMP')
# Out:
#                         TARGET_NAME                       TARGET_GUID  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-11 14:10:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-11 14:20:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-11 14:30:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-11 14:40:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# ...                             ...                               ...
# 2019-09-19 13:10:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-19 13:20:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-19 13:30:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-19 13:40:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
# 2019-09-19 13:50:00  ISTATX_istatx1  8268AEA46CC9AC6FE05312CAC582DD1E
#
#                      CPU Usage (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                 839.051
# 2019-09-11 14:10:00                1974.909
# 2019-09-11 14:20:00                 998.234
# 2019-09-11 14:30:00                1451.615
# 2019-09-11 14:40:00                3970.455
# ...                                     ...
# 2019-09-19 13:10:00                1840.426
# 2019-09-19 13:20:00                 549.790
# 2019-09-19 13:30:00                1087.638
# 2019-09-19 13:40:00                1919.131
# 2019-09-19 13:50:00                4773.310
#
#                      Parallel Execution Downgraded 50% or more (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                                0.0
# 2019-09-11 14:10:00                                                0.0
# 2019-09-11 14:20:00                                                0.0
# 2019-09-11 14:30:00                                                0.0
# 2019-09-11 14:40:00                                                0.0
# ...                                                                ...
# 2019-09-19 13:10:00                                                0.0
# 2019-09-19 13:20:00                                                0.0
# 2019-09-19 13:30:00                                                0.0
# 2019-09-19 13:40:00                                                0.0
# 2019-09-19 13:50:00                                                0.0
#
#                      Parallel Execution Downgraded to Serial (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                              0.000
# 2019-09-11 14:10:00                                              0.000
# 2019-09-11 14:20:00                                              0.000
# 2019-09-11 14:30:00                                              0.000
# 2019-09-11 14:40:00                                              0.013
# ...                                                                ...
# 2019-09-19 13:10:00                                              0.000
# 2019-09-19 13:20:00                                              0.000
# 2019-09-19 13:30:00                                              0.000
# 2019-09-19 13:40:00                                              0.017
# 2019-09-19 13:50:00                                              0.003
#
#                      Redo Log Allocation Hit (%)  Database CPU Time (%)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                      100.000                 97.371
# 2019-09-11 14:10:00                      100.000                 93.148
# 2019-09-11 14:20:00                      100.000                 98.669
# 2019-09-11 14:30:00                      100.000                 68.563
# 2019-09-11 14:40:00                      100.000                 86.197
# ...                                          ...                    ...
# 2019-09-19 13:10:00                       99.999                 88.219
# 2019-09-19 13:20:00                       99.999                 99.046
# 2019-09-19 13:30:00                       99.997                 79.040
# 2019-09-19 13:40:00                      100.000                 82.757
# 2019-09-19 13:50:00                       99.950                 64.160
#
#                      Buffer Cache Hit (%)  Library Cache Miss (%)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                35.435                   9.007
# 2019-09-11 14:10:00                43.160                   1.983
# 2019-09-11 14:20:00                52.094                   4.167
# 2019-09-11 14:30:00                91.018                  15.951
# 2019-09-11 14:40:00                62.206                   1.631
# ...                                   ...                     ...
# 2019-09-19 13:10:00                54.829                   1.726
# 2019-09-19 13:20:00                49.447                   1.180
# 2019-09-19 13:30:00                62.552                   3.782
# 2019-09-19 13:40:00                53.162                   7.394
# 2019-09-19 13:50:00                52.203                  10.475
#
#                      Sorts in Memory (%)  ...  \
# 10MIN_TIMESTAMP                           ...
# 2019-09-11 14:00:00              100.000  ...
# 2019-09-11 14:10:00              100.000  ...
# 2019-09-11 14:20:00              100.000  ...
# 2019-09-11 14:30:00               99.969  ...
# 2019-09-11 14:40:00               99.941  ...
# ...                                  ...  ...
# 2019-09-19 13:10:00               99.925  ...
# 2019-09-19 13:20:00              100.000  ...
# 2019-09-19 13:30:00              100.000  ...
# 2019-09-19 13:40:00              100.000  ...
# 2019-09-19 13:50:00               98.567  ...
#
#                      Scans on Long Tables (per transaction)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                  27.538
# 2019-09-11 14:10:00                                   2.949
# 2019-09-11 14:20:00                                   3.593
# 2019-09-11 14:30:00                                  30.746
# 2019-09-11 14:40:00                                   2.335
# ...                                                     ...
# 2019-09-19 13:10:00                                   1.572
# 2019-09-19 13:20:00                                   0.126
# 2019-09-19 13:30:00                                   1.500
# 2019-09-19 13:40:00                                   5.363
# 2019-09-19 13:50:00                                   3.711
#
#                      Consistent Read Blocks Created (per transaction)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                             0.488
# 2019-09-11 14:10:00                                             0.113
# 2019-09-11 14:20:00                                            29.400
# 2019-09-11 14:30:00                                            77.621
# 2019-09-11 14:40:00                                            45.502
# ...                                                               ...
# 2019-09-19 13:10:00                                             0.201
# 2019-09-19 13:20:00                                             0.154
# 2019-09-19 13:30:00                                             0.173
# 2019-09-19 13:40:00                                             0.149
# 2019-09-19 13:50:00                                             5.391
#
#                      Active Sessions Waiting: I/O  Enqueue Waits (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                         0.526                       6.078
# 2019-09-11 14:10:00                         1.561                       4.043
# 2019-09-11 14:20:00                         0.068                      65.871
# 2019-09-11 14:30:00                         4.527                      36.868
# 2019-09-11 14:40:00                         5.682                      17.806
# ...                                           ...                         ...
# 2019-09-19 13:10:00                         1.174                      23.743
# 2019-09-19 13:20:00                         0.327                       5.833
# 2019-09-19 13:30:00                         1.928                      21.497
# 2019-09-19 13:40:00                         3.949                      14.110
# 2019-09-19 13:50:00                           NaN                      69.003
#
#                      Consistent Read Blocks Created (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                        0.608
# 2019-09-11 14:10:00                                        0.127
# 2019-09-11 14:20:00                                      107.195
# 2019-09-11 14:30:00                                      124.272
# 2019-09-11 14:40:00                                      103.918
# ...                                                          ...
# 2019-09-19 13:10:00                                        5.811
# 2019-09-19 13:20:00                                        2.012
# 2019-09-19 13:30:00                                        1.935
# 2019-09-19 13:40:00                                        2.082
# 2019-09-19 13:50:00                                      101.250
#
#                      Physical Writes Direct (per transaction)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                   272.373
# 2019-09-11 14:10:00                                   254.470
# 2019-09-11 14:20:00                                   844.889
# 2019-09-11 14:30:00                                  9841.760
# 2019-09-11 14:40:00                                  2135.373
# ...                                                       ...
# 2019-09-19 13:10:00                                   466.551
# 2019-09-19 13:20:00                                   152.832
# 2019-09-19 13:30:00                                   912.089
# 2019-09-19 13:40:00                                   588.196
# 2019-09-19 13:50:00                                  2186.167
#
#                      Enqueue Deadlocks (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                             0.0
# 2019-09-11 14:10:00                             0.0
# 2019-09-11 14:20:00                             0.0
# 2019-09-11 14:30:00                             0.0
# 2019-09-11 14:40:00                             0.0
# ...                                             ...
# 2019-09-19 13:10:00                             0.0
# 2019-09-19 13:20:00                             0.0
# 2019-09-19 13:30:00                             0.0
# 2019-09-19 13:40:00                             0.0
# 2019-09-19 13:50:00                             0.0
#
#                      Database Block Gets (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                           709.581
# 2019-09-11 14:10:00                           396.401
# 2019-09-11 14:20:00                        259430.422
# 2019-09-11 14:30:00                        158688.275
# 2019-09-11 14:40:00                         81412.382
# ...                                               ...
# 2019-09-19 13:10:00                         21035.396
# 2019-09-19 13:20:00                          1785.689
# 2019-09-19 13:30:00                         12552.082
# 2019-09-19 13:40:00                         17297.958
# 2019-09-19 13:50:00                         73773.501
#
#                      Physical Reads Direct (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                           79032.649
# 2019-09-11 14:10:00                            6913.292
# 2019-09-11 14:20:00                           20580.538
# 2019-09-11 14:30:00                           96763.853
# 2019-09-11 14:40:00                           13756.376
# ...                                                 ...
# 2019-09-19 13:10:00                           28952.743
# 2019-09-19 13:20:00                            2080.242
# 2019-09-19 13:30:00                           19619.102
# 2019-09-19 13:40:00                           35404.533
# 2019-09-19 13:50:00                           69039.531
#
#                      Enqueue Timeout (per second)
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                         1.254
# 2019-09-11 14:10:00                         1.058
# 2019-09-11 14:20:00                         1.636
# 2019-09-11 14:30:00                         1.684
# 2019-09-11 14:40:00                         1.416
# ...                                           ...
# 2019-09-19 13:10:00                         1.733
# 2019-09-19 13:20:00                         0.621
# 2019-09-19 13:30:00                         0.661
# 2019-09-19 13:40:00                         0.917
# 2019-09-19 13:50:00                         1.124
#
# [1152 rows x 116 columns]

# %%
df.dropna(inplace=True)
null_data = df[df.isnull().any(axis=1)]
null_data
# Out:
# Empty DataFrame
# Columns: [10MIN_TIMESTAMP, TARGET_NAME, TARGET_GUID, CPU Usage (per second), Parallel Execution Downgraded 50% or more (per second), Parallel Execution Downgraded to Serial (per second), Redo Log Allocation Hit (%), Database CPU Time (%), Buffer Cache Hit (%), Library Cache Miss (%), Sorts in Memory (%), Library Cache Hit (%), Parallel Execution Downgraded to Serial (per transaction), PGA Cache Hit (%), Data Dictionary Hit (%), Row Cache Miss Ratio (%), CPU Usage (per transaction), Parallel Execution Downgraded 75% or more (per second), Parallel Execution Downgraded 25% or more (per second), Response Time (per transaction), Full Index Scans (per transaction), Database Block Gets (per transaction), Wait Time (%), Soft Parse (%), User Commits (per transaction), Database Time (centiseconds per second), User Rollbacks (per transaction), Open Cursors (per transaction), User Commits (per second), Hard Parses (per transaction), Host CPU Utilization (%), Rows sorted (per transaction), Leaf Node Splits (per second), Consistent Read Gets (per transaction), Active Sessions Using CPU, Redo Writes (per transaction), Network Bytes (per second), Total Parses (per second), Recursive Calls (per second), Consistent Read Changes (per second), Total Index Scans (per second), Physical Writes Direct (per second), Consistent Read Undo Records Applied (per transaction), User Calls (per transaction), Executes (per second), Average Synchronous Single-Block Read Latency (ms), Consistent Read Changes (per transaction), Average Active Sessions, Full Index Scans (per second), Consistent Read Undo Records Applied (per second), Sorts to Disk (per transaction), Branch Node Splits (per transaction), Redo Generated (per second), Consistent Read Gets (per second), Physical Reads Direct (per transaction), Open Cursors (per second), Physical Reads Direct Lobs (per second), Physical Writes (per second), I/O Requests (per second), BG Checkpoints (per second), Enqueue Requests (per second), Parse Failure Count (per second), User Rollback Undo Records Applied (per second), Executes (per transaction), Parse Failure Count (per transaction), User Rollback Undo Records Applied (per transaction), Enqueue Requests (per transaction), Sorts in memory (per second), Sorts to Disk (per second), Sorts in memory (per transaction), Branch Node Splits (per second), I/O Megabytes (per second), Executes Performed without Parses (%), Session Logical Reads (per second), Database Time (centiseconds per transaction), Physical Reads (per second), Physical Writes Direct Lobs (per second), Cumulative Logons (per second), Physical Writes Direct Lobs (per transaction), Rows sorted (per second), Redo Generated (per transaction), Enqueue Deadlocks (per transaction), Total Table Scans (per second), Database Block Changes (per second), Response Time (centi-seconds per call), Rows Processed (per sort), Total Table Scans (per transaction), Physical Reads Direct Lobs (per transaction), User Calls (%), Enqueue Waits (per transaction), Physical Reads (per transaction), User Rollbacks (per second), Session Logical Reads (per transaction), User Calls (per second), DBWR Checkpoints (per second), Recursive Calls (per transaction), Hard Parses (per second), Average Instance CPU (%), Enqueue Timeout (per transaction), Total Index Scans (per transaction), ...]
# Index: []
#
# [0 rows x 117 columns]

# %% [markdown]
# ### Wahl der Auslastungswerte

# %%
features_considered=['CPU Usage (per second)','CPU Usage (per transaction)','Host CPU Utilization (%)','Average Instance CPU (%)','Database CPU Time (%)','Database Time (centiseconds per second)','Active Sessions Using CPU','Average Active Sessions','Active Sessions Waiting: I/O','Wait Time (%)','Enqueue Waits (per transaction)','Enqueue Waits (per second)','I/O Requests (per second)','Enqueue Requests (per second)','Enqueue Requests (per transaction)']
features = df[features_considered]
features.index = df['10MIN_TIMESTAMP']
features.head()
# Out:
#                      CPU Usage (per second)  CPU Usage (per transaction)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                 839.051                     4188.262
# 2019-09-11 14:10:00                1974.909                     1019.802
# 2019-09-11 14:20:00                 998.234                     2335.711
# 2019-09-11 14:30:00                1451.615                      291.882
# 2019-09-11 14:40:00                3970.455                    15544.463
#
#                      Host CPU Utilization (%)  Average Instance CPU (%)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                 13.068484                    11.373
# 2019-09-11 14:10:00                 25.589807                    22.457
# 2019-09-11 14:20:00                 12.095209                     9.927
# 2019-09-11 14:30:00                 21.329274                    18.015
# 2019-09-11 14:40:00                 46.546902                    42.265
#
#                      Database CPU Time (%)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                 97.371
# 2019-09-11 14:10:00                 93.148
# 2019-09-11 14:20:00                 98.669
# 2019-09-11 14:30:00                 68.563
# 2019-09-11 14:40:00                 86.197
#
#                      Database Time (centiseconds per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                                 2124.198
# 2019-09-11 14:10:00                                  834.111
# 2019-09-11 14:20:00                                 2207.380
# 2019-09-11 14:30:00                                 3987.869
# 2019-09-11 14:40:00                                 2132.914
#
#                      Active Sessions Using CPU  Average Active Sessions  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                     10.008                   21.242
# 2019-09-11 14:10:00                     19.762                    8.341
# 2019-09-11 14:20:00                      8.736                   22.074
# 2019-09-11 14:30:00                     15.853                   39.879
# 2019-09-11 14:40:00                     37.193                   21.329
#
#                      Active Sessions Waiting: I/O  Wait Time (%)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                         0.526       3.044403
# 2019-09-11 14:10:00                         1.561       4.912818
# 2019-09-11 14:20:00                         0.068       0.886582
# 2019-09-11 14:30:00                         4.527      25.318306
# 2019-09-11 14:40:00                         5.682      13.480704
#
#                      Enqueue Waits (per transaction)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                            4.881
# 2019-09-11 14:10:00                            3.615
# 2019-09-11 14:20:00                           18.066
# 2019-09-11 14:30:00                           23.028
# 2019-09-11 14:40:00                            7.797
#
#                      Enqueue Waits (per second)  I/O Requests (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                       6.078                   5658.987
# 2019-09-11 14:10:00                       4.043                    199.801
# 2019-09-11 14:20:00                      65.871                  13633.062
# 2019-09-11 14:30:00                      36.868                   9756.294
# 2019-09-11 14:40:00                      17.806                   5311.699
#
#                      Enqueue Requests (per second)  \
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                         70.536
# 2019-09-11 14:10:00                         36.841
# 2019-09-11 14:20:00                        245.708
# 2019-09-11 14:30:00                        132.322
# 2019-09-11 14:40:00                        124.000
#
#                      Enqueue Requests (per transaction)
# 10MIN_TIMESTAMP
# 2019-09-11 14:00:00                              56.637
# 2019-09-11 14:10:00                              32.937
# 2019-09-11 14:20:00                              67.390
# 2019-09-11 14:30:00                              82.650
# 2019-09-11 14:40:00                              54.295

# %%
features.plot(subplots=True,figsize=(12,25)); # 2 Mal ausführen wenn der Plot nicht aufs erste mal angeziegt wird

# %% [markdown]
# ## TRAIN/TEST SPLIT UND VORBEREITUNG DER DATEN

# %%
pred_horizon = 30 # steps
n_history  = 33

# %%
# Standardise
import numpy as np
from sklearn.preprocessing import StandardScaler

dataset = features.values

# standardise
scaler = StandardScaler()
scaler.fit(dataset[:-pred_horizon])
dataset = scaler.transform(dataset)

train=dataset[:-pred_horizon]
test= dataset[-pred_horizon:,[0]] # Host CPU Utilization (%)
dataset=np.append(dataset, dataset[:,[0]], axis=1)

# %%
train.shape
# Out:
# (1121, 15)

# %%
from numpy import array
def to_supervised(train, n_input, n_out):
    data=train
    X, y = list(), list()
    in_start = 0
    # step over the entire history one time step at a time
    for _ in range(len(data)):
        # define the end of the input sequence
        in_end = in_start + n_input
        out_end = in_end + n_out
        # ensure we have enough data for this instance
        if out_end <= len(data):
            X.append(data[in_start:in_end, :])
            y.append(data[in_end:out_end,[2]]) # 2 =  Host CPU Utilization (%)
        # move along one time step
        in_start += 1
    return array(X), array(y)

# %%
X_train , y_train = to_supervised(train, n_history, pred_horizon)

# %%
 y_train = y_train.reshape((y_train.shape[0], y_train.shape[1]))

# %%
print( X_train.shape , y_train.shape)
# Out:
# (1059, 33, 15) (1059, 30)

# %% [markdown]
# ## Model Definition

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import LSTM
from keras.layers import RepeatVector
from keras.layers import TimeDistributed
from keras.layers import Bidirectional
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_history, 15)))
model.add(Dense(pred_horizon))
model.compile(optimizer='adam', loss='mse', metrics= ['accuracy'])

# %%
# model.summary()

# %%
from keras.callbacks import EarlyStopping
from keras.callbacks import ModelCheckpoint
es = EarlyStopping(monitor='val_loss', mode='min', verbose = 1, patience=20)
mc = ModelCheckpoint('lstm_multistep_multivariate.h5', monitor = 'val_accuracy' , mode = 'max', verbose= 1, save_best_only=True)

# %% [markdown]
# ## Model Training

# %%
model.fit(X_train, y_train,  validation_split=0.1,epochs=100, callbacks=[es, mc])
# Out:
# Train on 953 samples, validate on 106 samples
# Epoch 1/100
# 953/953 [==============================] - 1s 2ms/step - loss: 0.8570 - accuracy: 0.0283 - val_loss: 0.4224 - val_accuracy: 0.0283
#
# Epoch 00001: val_accuracy improved from -inf to 0.02830, saving model to lstm_multistep_multivariate.h5
# Epoch 2/100
# 953/953 [==============================] - 1s 973us/step - loss: 0.7313 - accuracy: 0.0514 - val_loss: 0.4405 - val_accuracy: 0.0377
#
# Epoch 00002: val_accuracy improved from 0.02830 to 0.03774, saving model to lstm_multistep_multivariate.h5
# Epoch 3/100
# 953/953 [==============================] - 1s 940us/step - loss: 0.7754 - accuracy: 0.0535 - val_loss: 0.4414 - val_accuracy: 0.0189
#
# Epoch 00003: val_accuracy did not improve from 0.03774
# Epoch 4/100
# 953/953 [==============================] - 1s 938us/step - loss: 0.7073 - accuracy: 0.0567 - val_loss: 0.4394 - val_accuracy: 0.0189
#
# Epoch 00004: val_accuracy did not improve from 0.03774
# Epoch 5/100
# 953/953 [==============================] - 1s 938us/step - loss: 0.6454 - accuracy: 0.0598 - val_loss: 0.4403 - val_accuracy: 0.0377
#
# Epoch 00005: val_accuracy did not improve from 0.03774
# Epoch 6/100
# 953/953 [==============================] - 1s 951us/step - loss: 0.6255 - accuracy: 0.0651 - val_loss: 0.4539 - val_accuracy: 0.0094
#
# Epoch 00006: val_accuracy did not improve from 0.03774
# Epoch 7/100
# 953/953 [==============================] - 1s 943us/step - loss: 0.6065 - accuracy: 0.0766 - val_loss: 0.4360 - val_accuracy: 0.0377
#
# Epoch 00007: val_accuracy did not improve from 0.03774
# Epoch 8/100
# 953/953 [==============================] - 1s 940us/step - loss: 0.5809 - accuracy: 0.0787 - val_loss: 0.4304 - val_accuracy: 0.0566
#
# Epoch 00008: val_accuracy improved from 0.03774 to 0.05660, saving model to lstm_multistep_multivariate.h5
# Epoch 9/100
# 953/953 [==============================] - 1s 948us/step - loss: 0.5715 - accuracy: 0.0839 - val_loss: 0.4294 - val_accuracy: 0.0094
#
# Epoch 00009: val_accuracy did not improve from 0.05660
# Epoch 10/100
# 953/953 [==============================] - 1s 940us/step - loss: 0.5734 - accuracy: 0.0724 - val_loss: 0.4582 - val_accuracy: 0.0283
#
# Epoch 00010: val_accuracy did not improve from 0.05660
# Epoch 11/100
# 953/953 [==============================] - 1s 964us/step - loss: 0.5457 - accuracy: 0.0850 - val_loss: 0.4309 - val_accuracy: 0.0283
#
# Epoch 00011: val_accuracy did not improve from 0.05660
# Epoch 12/100
# 953/953 [==============================] - 1s 981us/step - loss: 0.5366 - accuracy: 0.0745 - val_loss: 0.4392 - val_accuracy: 0.0189
#
# Epoch 00012: val_accuracy did not improve from 0.05660
# Epoch 13/100
# 953/953 [==============================] - 1s 959us/step - loss: 0.5223 - accuracy: 0.0839 - val_loss: 0.4002 - val_accuracy: 0.0377
#
# Epoch 00013: val_accuracy did not improve from 0.05660
# Epoch 14/100
# 953/953 [==============================] - 1s 976us/step - loss: 0.5085 - accuracy: 0.0860 - val_loss: 0.4118 - val_accuracy: 0.0283
#
# Epoch 00014: val_accuracy did not improve from 0.05660
# Epoch 15/100
# 953/953 [==============================] - 1s 949us/step - loss: 0.4890 - accuracy: 0.0892 - val_loss: 0.3764 - val_accuracy: 0.0283
#
# Epoch 00015: val_accuracy did not improve from 0.05660
# Epoch 16/100
# 953/953 [==============================] - 1s 969us/step - loss: 0.4815 - accuracy: 0.0871 - val_loss: 0.3634 - val_accuracy: 0.0472
#
# Epoch 00016: val_accuracy did not improve from 0.05660
# Epoch 17/100
# 953/953 [==============================] - 1s 952us/step - loss: 0.4794 - accuracy: 0.0881 - val_loss: 0.3784 - val_accuracy: 0.0283
#
# Epoch 00017: val_accuracy did not improve from 0.05660
# Epoch 18/100
# 953/953 [==============================] - 1s 975us/step - loss: 0.4629 - accuracy: 0.0902 - val_loss: 0.3930 - val_accuracy: 0.0283
#
# Epoch 00018: val_accuracy did not improve from 0.05660
# Epoch 19/100
# 953/953 [==============================] - 1s 944us/step - loss: 0.4485 - accuracy: 0.0955 - val_loss: 0.4100 - val_accuracy: 0.0094
#
# Epoch 00019: val_accuracy did not improve from 0.05660
# Epoch 20/100
# 953/953 [==============================] - 1s 957us/step - loss: 0.4639 - accuracy: 0.0913 - val_loss: 0.4037 - val_accuracy: 0.0283
#
# Epoch 00020: val_accuracy did not improve from 0.05660
# Epoch 21/100
# 953/953 [==============================] - 1s 967us/step - loss: 0.4335 - accuracy: 0.0923 - val_loss: 0.3942 - val_accuracy: 0.0660
#
# Epoch 00021: val_accuracy improved from 0.05660 to 0.06604, saving model to lstm_multistep_multivariate.h5
# Epoch 22/100
# 953/953 [==============================] - 1s 958us/step - loss: 0.4228 - accuracy: 0.0997 - val_loss: 0.4196 - val_accuracy: 0.0094
#
# Epoch 00022: val_accuracy did not improve from 0.06604
# Epoch 23/100
# 953/953 [==============================] - 1s 959us/step - loss: 0.4158 - accuracy: 0.1039 - val_loss: 0.4260 - val_accuracy: 0.0189
#
# Epoch 00023: val_accuracy did not improve from 0.06604
# Epoch 24/100
# 953/953 [==============================] - 1s 974us/step - loss: 0.4077 - accuracy: 0.1028 - val_loss: 0.4064 - val_accuracy: 0.0377
#
# Epoch 00024: val_accuracy did not improve from 0.06604
# Epoch 25/100
# 953/953 [==============================] - 1s 956us/step - loss: 0.4027 - accuracy: 0.1070 - val_loss: 0.4573 - val_accuracy: 0.0283
#
# Epoch 00025: val_accuracy did not improve from 0.06604
# Epoch 26/100
# 953/953 [==============================] - ETA: 0s - loss: 0.3947 - accuracy: 0.11 - 1s 986us/step - loss: 0.3927 - accuracy: 0.1081 - val_loss: 0.4637 - val_accuracy: 0.0283
#
# Epoch 00026: val_accuracy did not improve from 0.06604
# Epoch 27/100
# 953/953 [==============================] - 1s 988us/step - loss: 0.3913 - accuracy: 0.1154 - val_loss: 0.4445 - val_accuracy: 0.0472
#
# Epoch 00027: val_accuracy did not improve from 0.06604
# Epoch 28/100
# 953/953 [==============================] - 1s 986us/step - loss: 0.3850 - accuracy: 0.1165 - val_loss: 0.4910 - val_accuracy: 0.0189
#
# Epoch 00028: val_accuracy did not improve from 0.06604
# Epoch 29/100
# 953/953 [==============================] - 1s 959us/step - loss: 0.3833 - accuracy: 0.1238 - val_loss: 0.5174 - val_accuracy: 0.0189
#
# Epoch 00029: val_accuracy did not improve from 0.06604
# Epoch 30/100
# 953/953 [==============================] - 1s 969us/step - loss: 0.3721 - accuracy: 0.1249 - val_loss: 0.4580 - val_accuracy: 0.0472
#
# Epoch 00030: val_accuracy did not improve from 0.06604
# Epoch 31/100
# 953/953 [==============================] - 1s 981us/step - loss: 0.3636 - accuracy: 0.1270 - val_loss: 0.5735 - val_accuracy: 0.0472
#
# Epoch 00031: val_accuracy did not improve from 0.06604
# Epoch 32/100
# 953/953 [==============================] - 1s 979us/step - loss: 0.3642 - accuracy: 0.1249 - val_loss: 0.4817 - val_accuracy: 0.0566
#
# Epoch 00032: val_accuracy did not improve from 0.06604
# Epoch 33/100
# 953/953 [==============================] - 1s 969us/step - loss: 0.3698 - accuracy: 0.1448 - val_loss: 0.4823 - val_accuracy: 0.0660
#
# Epoch 00033: val_accuracy did not improve from 0.06604
# Epoch 34/100
# 953/953 [==============================] - 1s 971us/step - loss: 0.3571 - accuracy: 0.1312 - val_loss: 0.5324 - val_accuracy: 0.0189
#
# Epoch 00034: val_accuracy did not improve from 0.06604
# Epoch 35/100
# 953/953 [==============================] - 1s 981us/step - loss: 0.3470 - accuracy: 0.1459 - val_loss: 0.5827 - val_accuracy: 0.0283
#
# Epoch 00035: val_accuracy did not improve from 0.06604
# Epoch 36/100
# 953/953 [==============================] - 1s 992us/step - loss: 0.3469 - accuracy: 0.1417 - val_loss: 0.5121 - val_accuracy: 0.0660
#
# Epoch 00036: val_accuracy did not improve from 0.06604
# Epoch 00036: early stopping

# %%
import matplotlib.pyplot as plt
plt.plot(model.history.history['loss'], label = 'train')
plt.plot(model.history.history['val_loss'], label = 'test')
plt.legend()

# %% [markdown]
# ## Vorhersage

# %%
from keras.models import load_model
model= load_model('lstm_multistep_multivariate.h5')

# %%
pred_input = train[-n_history:]
pred_input.shape
pred_input = pred_input.reshape((1, pred_input.shape[0],15))
prediction=model.predict(pred_input)
prediction
# Out:
# array([[ 1.5448036 ,  0.67510265,  0.5001256 ,  0.29188436,  0.5231406 ,
#         -0.2534957 ,  0.54578686,  1.4653424 ,  1.4901506 ,  1.7094711 ,
#          1.4546398 ,  1.5821406 ,  2.0703118 ,  1.7507883 ,  1.1166368 ,
#          1.8708841 ,  1.5870093 ,  1.6913122 ,  2.1783555 ,  2.0627208 ,
#          1.9283521 ,  1.1903282 ,  1.3868659 ,  1.5963957 ,  1.3866796 ,
#          0.6531579 ,  0.5720009 ,  0.46538436, -0.14837953,  0.277342  ]],
#       dtype=float32)

# %%
prediction.shape
# Out:
# (1, 30)

# %%
# prediction=prediction[0,:]

prediction=prediction.reshape((pred_horizon,1))
prediction = np.hstack((prediction, np.zeros((prediction.shape[0], 14), dtype=prediction.dtype)))
prediction=prediction = scaler.inverse_transform(prediction)
prediction=prediction[:,[0]]
prediction
# Out:
# array([[1799.7184],
#        [1201.0587],
#        [1080.613 ],
#        [ 937.27  ],
#        [1096.4554],
#        [ 561.857 ],
#        [1112.0441],
#        [1745.0212],
#        [1762.0979],
#        [1913.0675],
#        [1737.654 ],
#        [1825.4193],
#        [2161.4526],
#        [1941.5083],
#        [1504.9893],
#        [2024.1763],
#        [1828.7708],
#        [1900.5677],
#        [2235.8245],
#        [2156.2273],
#        [2063.7344],
#        [1555.7148],
#        [1691.0017],
#        [1835.2319],
#        [1690.8735],
#        [1185.953 ],
#        [1130.0885],
#        [1056.699 ],
#        [ 634.2138],
#        [ 927.2597]], dtype=float32)

# %%
test
test = np.hstack((test, np.zeros((test.shape[0], 14), dtype=test.dtype)))
test=scaler.inverse_transform(test)
test=test[:,[0]]

# %%
import matplotlib.pyplot as plt
plt.plot(test, label="real")
plt.plot(prediction,  label="prediction")
plt.legend(loc='best')
plt.show()

# %%
rmse=np.sqrt(np.mean((prediction-test)**2))
rmse
# Out:
# 860.0389978256362
